# %% [markdown]
# # Building MDPs
# A Markov Decision Process is an extended Markov Chain which
#
# * states
# * actions
# * transitions
#
# Where
#
# * actions are essentially 'decisions' which might be decided by *schedulers*/*policies*/*agents* (these terms are equivalent)
# * each state has a number of actions
# * actions have probabilistic transitions to states
#
# In general, for smaller models, the model API is more convenient, but for bigger models the pgc API becomes more convenient.
#
# Here we show how to construct a simple example mdp using the pgc API and the model builder API.
# The idea is that you can choose to study (you will likely pass the exam but you have less free time) or not to study (you will have more free time but risk failing the exam).

# %%
from stormvogel import pgc
from stormvogel.model import EmptyAction, ModelType
from stormvogel.show import show
from stormvogel.layout import Layout

init = pgc.State(x="")

def available_actions(s: pgc.State):
    if s == init: # If we are in the initial state, we have a choice.
        return [pgc.Action(["study"]), pgc.Action(["don't study"])]
    else: # Otherwise, we don't have any choice, we are just a Markov chain. 
        return [pgc.Action([])]

def delta(s: pgc.State, a: pgc.Action):
    if "study" in a.labels:
        return [(1, pgc.State(x=["studied"]))]
    elif "don't study" in a.labels:
        return [(1, pgc.State(x=["didn't study"]))]
    elif "studied" in s.x:
        return [(9/10, pgc.State(x=["pass test"])), (1/10, pgc.State(x=["fail test"]))]
    elif "didn't study" in s.x:
        return [(2/5, pgc.State(x=["pass test"])), (3/5, pgc.State(x=["fail test"]))]
    else:
        return [(1, pgc.State(x=["end"]))]

labels = lambda s: s.x

# For rewards, you have to provide a list. This enables multiple reward models if you use a non-singleton list.
def rewards(s: pgc.State, a: pgc.Action):
    if "pass test" in s.x:
        return {"r1":100}
    if "didn't study" in s.x:
        return {"r1":15}
    else:
        return {"r1":0}


pgc_study = pgc.build_pgc(
    delta=delta,
    initial_state_pgc=init,
    available_actions=available_actions,
    labels=labels,
    modeltype=ModelType.MDP,
    rewards=rewards
)
vis = show(pgc_study, layout=Layout("layouts/pinkgreen.json"))
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <title>Network</title>
#     <script
#       type="text/javascript"
#       src="https://unpkg.com/vis-network/standalone/umd/vis-network.min.js"
#     ></script>
#     <style type="text/css">
#       #modelwqAlFyaOzo {
#         width: 461px;
#         height: 358px;
#         border: 1px solid lightgray;
#       }
#     </style>
#   </head>
#   <body>
#     <div id="modelwqAlFyaOzo"></div>
#     <script type="text/javascript">
#
# class NetworkWrapper_modelwqAlFyaOzo{//js
#   constructor(nodes, edges, options, container) {
#     this.nodes = nodes;
#     this.edges = edges;
#     this.options = options;
#     this.container = container;
#     this.data = {
#       nodes: nodes,
#       edges: edges,
#     };
#     this.network = new vis.Network(container, this.data, options);
#     var this_ = this; // Events will not work if you use 'this' directly :))))) No idea why.
#
#     // Set user-triggered events.
#     this.network.on( 'click', function(properties) {
#       var nodeId = this_.network.getNodeAt({x:properties.event.srcEvent.offsetX, y:properties.event.srcEvent.offsetY});
#       this_.makeNeighborsVisible(nodeId);
#     });
#     this.network.on( 'doubleClick', function(properties) {
#         this_.network.setData(this_.data);
#     });
#   }
#
#   setNodeColor(id, color) {
#     var node = this.nodes.get(id);
#     node["x"] = this.network.getPosition(id)["x"];
#     node["y"] = this.network.getPosition(id)["y"];
#     node["color"] = color;
#     this.nodes.update(node);
#   }
#
#   makeNeighborsVisible(homeId) {
#     if (homeId === undefined) {
#       return;
#     }
#     var homeNode = this.nodes.get(homeId);
#
#     // Make outgoing nodes visible
#     var nodeIds = this.network.getConnectedNodes(homeId, "to");
#     for (let i = 0; i < nodeIds.length; i++) {
#       var toNodeId = nodeIds[i];
#       var toNode = this.nodes.get(toNodeId);
#       if (toNode["hidden"]) {
#         toNode["hidden"] = false;
#         toNode["physics"] = true;
#         toNode["x"] = this.network.getPosition(homeId)["x"];
#         toNode["y"] = this.network.getPosition(homeId)["y"];
#         this.nodes.update(toNode);
#       }
#     }
#     // Make edges visible, if both of the nodes are also visible
#     var edgeIds = this.network.getConnectedEdges(homeId);
#     for (let i = 0; i < edgeIds.length; i++) {
#       var edgeId = edgeIds[i];
#       var edge = this.edges.get(edgeId);
#       var fromNode = this.nodes.get(edge.from);
#       var toNode = this.nodes.get(edge.to);
#       if ((! fromNode["hidden"]) && (! toNode["hidden"])) {
#         edge["hidden"] = false;
#         edge["physics"] = true;
#         this.edges.update(edge);
#       }
#     }
#   }
# };
#
#     </script>
#     <script type="text/javascript">
#         //js
#     var nodes_local = new vis.DataSet([{ id: 0, label: `init`, group: "states", x: -200, y: -25 },
# { id: 1, label: `studied
# €	r1: 0`, group: "states", x: 3, y: -112 },
# { id: 2, label: `didn't study
# €	r1: 15`, group: "states", x: -17, y: 119 },
# { id: 3, label: `pass test
# €	r1: 100`, group: "states", x: 92, y: 27 },
# { id: 4, label: `fail test
# €	r1: 0`, group: "states", x: 8, y: -1 },
# { id: 5, label: `end
# €	r1: 0`, group: "states", x: 140, y: -58 },
# { id: 10000000000, label: `study
# €	r1: 0`, group: "actions", x: -124, y: -138 },
# { id: 10000000001, label: `don't study
# €	r1: 0`, group: "actions", x: -154, y: 103 },
# ]);
#     var edges_local = new vis.DataSet([{ from: 0, to: 10000000000 },
# { from: 10000000000, to: 1, label: "1" },
# { from: 0, to: 10000000001 },
# { from: 10000000001, to: 2, label: "1" },
# { from: 1, to: 3, label: "9/10" },
# { from: 1, to: 4, label: "1/10" },
# { from: 2, to: 3, label: "2/5" },
# { from: 2, to: 4, label: "3/5" },
# { from: 3, to: 5, label: "1" },
# { from: 4, to: 5, label: "1" },
# { from: 5, to: 5, label: "1" },
# ]);
#     var options_local = {
#   "__fake_macros": {
#     "__group_macro": {
#       "borderWidth": 1,
#       "color": {
#         "background": "white",
#         "border": "black",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "ellipse",
#       "mass": 1,
#       "font": {
#         "color": "black",
#         "size": 14
#       }
#     }
#   },
#   "edit_groups": {
#     "groups": [
#       "states",
#       "actions"
#     ]
#   },
#   "groups": {
#     "actions": {
#       "borderWidth": 1,
#       "color": {
#         "background": "#fbd0f5",
#         "border": "black",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "box",
#       "mass": 1,
#       "font": {
#         "color": "black",
#         "size": 14
#       }
#     },
#     "scheduled_actions": {
#       "shape": "box",
#       "color": {
#         "background": "pink",
#         "border": "red"
#       }
#     },
#     "states": {
#       "borderWidth": 1,
#       "color": {
#         "background": "#c9f9a9",
#         "border": "black",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "ellipse",
#       "mass": 1,
#       "font": {
#         "color": "black",
#         "size": 14
#       }
#     }
#   },
#   "reload_button": false,
#   "edges": {
#     "arrows": "to",
#     "font": {
#       "color": "black",
#       "size": 14,
#       "strokeColor": "white",
#       "strokeWidth": 2
#     },
#     "color": {
#       "color": "black"
#     },
#     "width": 1
#   },
#   "numbers": {
#     "fractions": true,
#     "digits": 5
#   },
#   "state_properties": {
#     "show_results": true,
#     "result_symbol": "\u2606",
#     "show_rewards": true,
#     "reward_symbol": "\u20ac",
#     "show_zero_rewards": true,
#     "show_observations": true,
#     "observation_symbol": "\u0298"
#   },
#   "layout": {
#     "randomSeed": 5
#   },
#   "misc": {
#     "enable_physics": true,
#     "width": 461,
#     "height": 358,
#     "explore": false
#   },
#   "saving": {
#     "relative_path": true,
#     "filename": "layouts/pinkgreen.json",
#     "save_button": false,
#     "load_button": false
#   },
#   "positions": {
#     "0": {
#       "x": -200,
#       "y": -25
#     },
#     "1": {
#       "x": 3,
#       "y": -112
#     },
#     "2": {
#       "x": -17,
#       "y": 119
#     },
#     "3": {
#       "x": 92,
#       "y": 27
#     },
#     "4": {
#       "x": 8,
#       "y": -1
#     },
#     "5": {
#       "x": 140,
#       "y": -58
#     },
#     "10000000000": {
#       "x": -124,
#       "y": -138
#     },
#     "10000000001": {
#       "x": -154,
#       "y": 103
#     }
#   },
#   "physics": true,
#   "autoResize": true
# };
#     var container_local = document.getElementById("modelwqAlFyaOzo");
#     var nw_modelwqAlFyaOzo = new NetworkWrapper_modelwqAlFyaOzo(nodes_local, edges_local, options_local, container_local)
#
#     </script>
#   </body>
# </html>

# %%
import stormvogel.model
from stormvogel.layout import Layout
from stormvogel.show import show
from stormvogel.model import EmptyAction

mdp = stormvogel.model.new_mdp("Study")

init = mdp.get_initial_state()
study = mdp.action("study")
not_study = mdp.action("don't study")

studied = mdp.new_state("studied")
not_studied = mdp.new_state("didn't study")
pass_test = mdp.new_state("pass test")
fail_test = mdp.new_state("fail test")
end = mdp.new_state("end")

init.set_transitions([
    (study, studied),
    (not_study, not_studied)
])

studied.set_transitions([
    (9/10, pass_test),
    (1/10, fail_test)
])

not_studied.set_transitions([
    (4/10, pass_test),
    (6/10, fail_test)
])

pass_test.set_transitions([(1, end)])
fail_test.set_transitions([(1, end)])

reward_model = mdp.add_rewards("R")
reward_model.set_state_action_reward(pass_test, EmptyAction, 100)
reward_model.set_state_action_reward(fail_test, EmptyAction, 0)
reward_model.set_state_action_reward(not_studied, EmptyAction, 15)
reward_model.set_unset_rewards(0)

vis = show(mdp, layout=Layout("layouts/pinkgreen.json"), name="study")
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <title>Network</title>
#     <script
#       type="text/javascript"
#       src="https://unpkg.com/vis-network/standalone/umd/vis-network.min.js"
#     ></script>
#     <style type="text/css">
#       #studydsYhjKVhLd {
#         width: 461px;
#         height: 358px;
#         border: 1px solid lightgray;
#       }
#     </style>
#   </head>
#   <body>
#     <div id="studydsYhjKVhLd"></div>
#     <script type="text/javascript">
#
# class NetworkWrapper_studydsYhjKVhLd{//js
#   constructor(nodes, edges, options, container) {
#     this.nodes = nodes;
#     this.edges = edges;
#     this.options = options;
#     this.container = container;
#     this.data = {
#       nodes: nodes,
#       edges: edges,
#     };
#     this.network = new vis.Network(container, this.data, options);
#     var this_ = this; // Events will not work if you use 'this' directly :))))) No idea why.
#
#     // Set user-triggered events.
#     this.network.on( 'click', function(properties) {
#       var nodeId = this_.network.getNodeAt({x:properties.event.srcEvent.offsetX, y:properties.event.srcEvent.offsetY});
#       this_.makeNeighborsVisible(nodeId);
#     });
#     this.network.on( 'doubleClick', function(properties) {
#         this_.network.setData(this_.data);
#     });
#   }
#
#   setNodeColor(id, color) {
#     var node = this.nodes.get(id);
#     node["x"] = this.network.getPosition(id)["x"];
#     node["y"] = this.network.getPosition(id)["y"];
#     node["color"] = color;
#     this.nodes.update(node);
#   }
#
#   makeNeighborsVisible(homeId) {
#     if (homeId === undefined) {
#       return;
#     }
#     var homeNode = this.nodes.get(homeId);
#
#     // Make outgoing nodes visible
#     var nodeIds = this.network.getConnectedNodes(homeId, "to");
#     for (let i = 0; i < nodeIds.length; i++) {
#       var toNodeId = nodeIds[i];
#       var toNode = this.nodes.get(toNodeId);
#       if (toNode["hidden"]) {
#         toNode["hidden"] = false;
#         toNode["physics"] = true;
#         toNode["x"] = this.network.getPosition(homeId)["x"];
#         toNode["y"] = this.network.getPosition(homeId)["y"];
#         this.nodes.update(toNode);
#       }
#     }
#     // Make edges visible, if both of the nodes are also visible
#     var edgeIds = this.network.getConnectedEdges(homeId);
#     for (let i = 0; i < edgeIds.length; i++) {
#       var edgeId = edgeIds[i];
#       var edge = this.edges.get(edgeId);
#       var fromNode = this.nodes.get(edge.from);
#       var toNode = this.nodes.get(edge.to);
#       if ((! fromNode["hidden"]) && (! toNode["hidden"])) {
#         edge["hidden"] = false;
#         edge["physics"] = true;
#         this.edges.update(edge);
#       }
#     }
#   }
# };
#
#     </script>
#     <script type="text/javascript">
#         //js
#     var nodes_local = new vis.DataSet([{ id: 0, label: `init`, group: "states", x: -200, y: -25 },
# { id: 1, label: `studied
# €	R: 0`, group: "states", x: 3, y: -112 },
# { id: 2, label: `didn't study
# €	R: 15`, group: "states", x: -17, y: 119 },
# { id: 3, label: `pass test
# €	R: 100`, group: "states", x: 92, y: 27 },
# { id: 4, label: `fail test
# €	R: 0`, group: "states", x: 8, y: -1 },
# { id: 5, label: `end
# €	R: 0`, group: "states", x: 140, y: -58 },
# { id: 10000000000, label: `study
# €	R: 0`, group: "actions", x: -124, y: -138 },
# { id: 10000000001, label: `don't study
# €	R: 0`, group: "actions", x: -154, y: 103 },
# ]);
#     var edges_local = new vis.DataSet([{ from: 0, to: 10000000000 },
# { from: 10000000000, to: 1, label: "1" },
# { from: 0, to: 10000000001 },
# { from: 10000000001, to: 2, label: "1" },
# { from: 1, to: 3, label: "9/10" },
# { from: 1, to: 4, label: "1/10" },
# { from: 2, to: 3, label: "2/5" },
# { from: 2, to: 4, label: "3/5" },
# { from: 3, to: 5, label: "1" },
# { from: 4, to: 5, label: "1" },
# ]);
#     var options_local = {
#   "__fake_macros": {
#     "__group_macro": {
#       "borderWidth": 1,
#       "color": {
#         "background": "white",
#         "border": "black",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "ellipse",
#       "mass": 1,
#       "font": {
#         "color": "black",
#         "size": 14
#       }
#     }
#   },
#   "edit_groups": {
#     "groups": [
#       "states",
#       "actions"
#     ]
#   },
#   "groups": {
#     "actions": {
#       "borderWidth": 1,
#       "color": {
#         "background": "#fbd0f5",
#         "border": "black",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "box",
#       "mass": 1,
#       "font": {
#         "color": "black",
#         "size": 14
#       }
#     },
#     "scheduled_actions": {
#       "shape": "box",
#       "color": {
#         "background": "pink",
#         "border": "red"
#       }
#     },
#     "states": {
#       "borderWidth": 1,
#       "color": {
#         "background": "#c9f9a9",
#         "border": "black",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "ellipse",
#       "mass": 1,
#       "font": {
#         "color": "black",
#         "size": 14
#       }
#     }
#   },
#   "reload_button": false,
#   "edges": {
#     "arrows": "to",
#     "font": {
#       "color": "black",
#       "size": 14,
#       "strokeColor": "white",
#       "strokeWidth": 2
#     },
#     "color": {
#       "color": "black"
#     },
#     "width": 1
#   },
#   "numbers": {
#     "fractions": true,
#     "digits": 5
#   },
#   "state_properties": {
#     "show_results": true,
#     "result_symbol": "\u2606",
#     "show_rewards": true,
#     "reward_symbol": "\u20ac",
#     "show_zero_rewards": true,
#     "show_observations": true,
#     "observation_symbol": "\u0298"
#   },
#   "layout": {
#     "randomSeed": 5
#   },
#   "misc": {
#     "enable_physics": true,
#     "width": 461,
#     "height": 358,
#     "explore": false
#   },
#   "saving": {
#     "relative_path": true,
#     "filename": "layouts/pinkgreen.json",
#     "save_button": false,
#     "load_button": false
#   },
#   "positions": {
#     "0": {
#       "x": -200,
#       "y": -25
#     },
#     "1": {
#       "x": 3,
#       "y": -112
#     },
#     "2": {
#       "x": -17,
#       "y": 119
#     },
#     "3": {
#       "x": 92,
#       "y": 27
#     },
#     "4": {
#       "x": 8,
#       "y": -1
#     },
#     "5": {
#       "x": 140,
#       "y": -58
#     },
#     "10000000000": {
#       "x": -124,
#       "y": -138
#     },
#     "10000000001": {
#       "x": -154,
#       "y": 103
#     }
#   },
#   "physics": true,
#   "autoResize": true
# };
#     var container_local = document.getElementById("studydsYhjKVhLd");
#     var nw_studydsYhjKVhLd = new NetworkWrapper_studydsYhjKVhLd(nodes_local, edges_local, options_local, container_local)
#
#     </script>
#   </body>
# </html>

# %% [markdown]
# A famous but more involved example of an MDP is the Monty Hall problem. We will show how to construct it using the pgc API.

# %%
from stormvogel import pgc
from stormvogel.model import EmptyAction, ModelType
from stormvogel.show import show
from stormvogel.layout import Layout

init = pgc.State(x="")

empty_action = pgc.Action([])

def available_actions(s: pgc.State):
    if "carchosen" in s.x:
        return [pgc.Action(["open", str(i)]) for i in range(1,4)]
    elif "opened" in s.x:
        return [pgc.Action(["stay"]), pgc.Action(["switch"])]
    return [empty_action]
    

def delta(s: pgc.State, a: pgc.Action):
    if s == init:
        return [(1/3, pgc.State(x=["carchosen", str(i)], car=i)) for i in range(1,4)]
    elif "open" in a.labels:
        return [(1, pgc.State(x=["open", str(a.labels[1])], car=s.car, chosen=a.labels[1]))]
    elif "open" in s.x:
        possible_goats = set([1,2,3]) - {s.car} - {s.chosen}
        return [(1/len(possible_goats), 
                pgc.State(x=["opened", str(s.chosen), f"goat,{i}"], 
                car=s.car, goat=i, chosen=s.chosen)) 
                for i in possible_goats]
    elif "stay" in a.labels:
        return [(1, pgc.State(x=["won"], pred=s))] if s.chosen == s.car else [(1, pgc.State(x=["lost"], pred=s))]
    elif "switch" in a.labels:
        return [(1, pgc.State(x=["won"], pred=s))] if s.chosen != s.car else [(1, pgc.State(x=["lost"], pred=s))]
    else:
        return [(1, s)]
        
labels = lambda s: s.x

pgc_die = pgc.build_pgc(
    delta=delta,
    initial_state_pgc=init,
    available_actions=available_actions,
    labels=labels,
    modeltype=ModelType.MDP
)

vis2 = show(pgc_die, layout=Layout("layouts/monty.json"))
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <title>Network</title>
#     <script
#       type="text/javascript"
#       src="https://unpkg.com/vis-network/standalone/umd/vis-network.min.js"
#     ></script>
#     <style type="text/css">
#       #modelEudDVttlYg {
#         width: 1010px;
#         height: 777px;
#         border: 1px solid lightgray;
#       }
#     </style>
#   </head>
#   <body>
#     <div id="modelEudDVttlYg"></div>
#     <script type="text/javascript">
#
# class NetworkWrapper_modelEudDVttlYg{//js
#   constructor(nodes, edges, options, container) {
#     this.nodes = nodes;
#     this.edges = edges;
#     this.options = options;
#     this.container = container;
#     this.data = {
#       nodes: nodes,
#       edges: edges,
#     };
#     this.network = new vis.Network(container, this.data, options);
#     var this_ = this; // Events will not work if you use 'this' directly :))))) No idea why.
#
#     // Set user-triggered events.
#     this.network.on( 'click', function(properties) {
#       var nodeId = this_.network.getNodeAt({x:properties.event.srcEvent.offsetX, y:properties.event.srcEvent.offsetY});
#       this_.makeNeighborsVisible(nodeId);
#     });
#     this.network.on( 'doubleClick', function(properties) {
#         this_.network.setData(this_.data);
#     });
#   }
#
#   setNodeColor(id, color) {
#     var node = this.nodes.get(id);
#     node["x"] = this.network.getPosition(id)["x"];
#     node["y"] = this.network.getPosition(id)["y"];
#     node["color"] = color;
#     this.nodes.update(node);
#   }
#
#   makeNeighborsVisible(homeId) {
#     if (homeId === undefined) {
#       return;
#     }
#     var homeNode = this.nodes.get(homeId);
#
#     // Make outgoing nodes visible
#     var nodeIds = this.network.getConnectedNodes(homeId, "to");
#     for (let i = 0; i < nodeIds.length; i++) {
#       var toNodeId = nodeIds[i];
#       var toNode = this.nodes.get(toNodeId);
#       if (toNode["hidden"]) {
#         toNode["hidden"] = false;
#         toNode["physics"] = true;
#         toNode["x"] = this.network.getPosition(homeId)["x"];
#         toNode["y"] = this.network.getPosition(homeId)["y"];
#         this.nodes.update(toNode);
#       }
#     }
#     // Make edges visible, if both of the nodes are also visible
#     var edgeIds = this.network.getConnectedEdges(homeId);
#     for (let i = 0; i < edgeIds.length; i++) {
#       var edgeId = edgeIds[i];
#       var edge = this.edges.get(edgeId);
#       var fromNode = this.nodes.get(edge.from);
#       var toNode = this.nodes.get(edge.to);
#       if ((! fromNode["hidden"]) && (! toNode["hidden"])) {
#         edge["hidden"] = false;
#         edge["physics"] = true;
#         this.edges.update(edge);
#       }
#     }
#   }
# };
#
#     </script>
#     <script type="text/javascript">
#         //js
#     var nodes_local = new vis.DataSet([{ id: 0, label: `init`, group: "states", x: 0, y: 0 },
# { id: 1, label: `carchosen,1`, group: "states", x: -279, y: 8 },
# { id: 2, label: `carchosen,2`, group: "states", x: 124, y: -257 },
# { id: 3, label: `carchosen,3`, group: "states", x: 127, y: 242 },
# { id: 4, label: `open,1`, group: "states", x: -671, y: 207 },
# { id: 5, label: `open,2`, group: "states", x: -596, y: -252 },
# { id: 6, label: `open,3`, group: "states", x: -259, y: 299 },
# { id: 7, label: `open,1`, group: "states", x: 536, y: -384 },
# { id: 8, label: `open,2`, group: "states", x: -132, y: -393 },
# { id: 9, label: `open,3`, group: "states", x: 150, y: -695 },
# { id: 10, label: `open,1`, group: "states", x: 82, y: 654 },
# { id: 11, label: `open,2`, group: "states", x: 507, y: 455 },
# { id: 12, label: `open,3`, group: "states", x: 294, y: 63 },
# { id: 13, label: `opened,1,goat,2`, group: "states", x: -740, y: 390 },
# { id: 14, label: `opened,1,goat,3`, group: "states", x: -849, y: 180 },
# { id: 15, label: `opened,2,goat,2`, group: "states", x: -649, y: -434 },
# { id: 16, label: `opened,2,goat,3`, group: "states", x: -767, y: -244 },
# { id: 17, label: `opened,3,goat,2`, group: "states", x: -348, y: 433 },
# { id: 18, label: `opened,3,goat,3`, group: "states", x: -122, y: 342 },
# { id: 19, label: `opened,1,goat,1`, group: "states", x: 620, y: -531 },
# { id: 20, label: `opened,1,goat,3`, group: "states", x: 721, y: -332 },
# { id: 21, label: `opened,2,goat,1`, group: "states", x: -210, y: -535 },
# { id: 22, label: `opened,2,goat,3`, group: "states", x: -199, y: -263 },
# { id: 23, label: `opened,3,goat,1`, group: "states", x: 47, y: -857 },
# { id: 24, label: `opened,3,goat,3`, group: "states", x: 280, y: -826 },
# { id: 25, label: `opened,1,goat,1`, group: "states", x: -43, y: 797 },
# { id: 26, label: `opened,1,goat,2`, group: "states", x: 189, y: 790 },
# { id: 27, label: `opened,2,goat,1`, group: "states", x: 693, y: 400 },
# { id: 28, label: `opened,2,goat,2`, group: "states", x: 591, y: 612 },
# { id: 29, label: `opened,3,goat,1`, group: "states", x: 444, y: 99 },
# { id: 30, label: `opened,3,goat,2`, group: "states", x: 315, y: -66 },
# { id: 31, label: `lost`, group: "states", x: -969, y: 582 },
# { id: 32, label: `won`, group: "states", x: -722, y: 687 },
# { id: 33, label: `lost`, group: "states", x: -1107, y: 55 },
# { id: 34, label: `won`, group: "states", x: -1112, y: 318 },
# { id: 35, label: `lost`, group: "states", x: -639, y: -725 },
# { id: 36, label: `won`, group: "states", x: -872, y: -634 },
# { id: 37, label: `lost`, group: "states", x: -1020, y: -400 },
# { id: 38, label: `won`, group: "states", x: -1025, y: -154 },
# { id: 39, label: `lost`, group: "states", x: -561, y: 320 },
# { id: 40, label: `won`, group: "states", x: -461, y: 700 },
# { id: 41, label: `lost`, group: "states", x: -53, y: 93 },
# { id: 42, label: `won`, group: "states", x: -174, y: 602 },
# { id: 43, label: `lost`, group: "states", x: 388, y: -611 },
# { id: 44, label: `won`, group: "states", x: 847, y: -722 },
# { id: 45, label: `lost`, group: "states", x: 1005, y: -424 },
# { id: 46, label: `won`, group: "states", x: 951, y: -150 },
# { id: 47, label: `lost`, group: "states", x: -407, y: -746 },
# { id: 48, label: `won`, group: "states", x: -193, y: -781 },
# { id: 49, label: `lost`, group: "states", x: -30, y: -74 },
# { id: 50, label: `won`, group: "states", x: -415, y: -387 },
# { id: 51, label: `lost`, group: "states", x: -201, y: -1023 },
# { id: 52, label: `won`, group: "states", x: 38, y: -1154 },
# { id: 53, label: `lost`, group: "states", x: 343, y: -1116 },
# { id: 54, label: `won`, group: "states", x: 552, y: -936 },
# { id: 55, label: `lost`, group: "states", x: -90, y: 1091 },
# { id: 56, label: `won`, group: "states", x: -306, y: 928 },
# { id: 57, label: `lost`, group: "states", x: 202, y: 1085 },
# { id: 58, label: `won`, group: "states", x: 414, y: 950 },
# { id: 59, label: `lost`, group: "states", x: 983, y: 470 },
# { id: 60, label: `won`, group: "states", x: 927, y: 218 },
# { id: 61, label: `lost`, group: "states", x: 860, y: 735 },
# { id: 62, label: `won`, group: "states", x: 641, y: 893 },
# { id: 63, label: `lost`, group: "states", x: 497, y: 308 },
# { id: 64, label: `won`, group: "states", x: 729, y: 61 },
# { id: 65, label: `lost`, group: "states", x: 382, y: -238 },
# { id: 66, label: `won`, group: "states", x: 588, y: -121 },
# { id: 10000000000, label: `open,1`, group: "actions", x: -479, y: 99 },
# { id: 10000000001, label: `open,2`, group: "actions", x: -438, y: -120 },
# { id: 10000000002, label: `open,3`, group: "actions", x: -259, y: 148 },
# { id: 10000000003, label: `open,1`, group: "actions", x: 324, y: -340 },
# { id: 10000000004, label: `open,2`, group: "actions", x: -4, y: -317 },
# { id: 10000000005, label: `open,3`, group: "actions", x: 137, y: -479 },
# { id: 10000000006, label: `open,1`, group: "actions", x: 106, y: 449 },
# { id: 10000000007, label: `open,2`, group: "actions", x: 308, y: 363 },
# { id: 10000000008, label: `open,3`, group: "actions", x: 170, y: 120 },
# { id: 10000000009, label: `stay`, group: "actions", x: -871, y: 483 },
# { id: 10000000010, label: `switch`, group: "actions", x: -714, y: 547 },
# { id: 10000000011, label: `stay`, group: "actions", x: -973, y: 92 },
# { id: 10000000012, label: `switch`, group: "actions", x: -983, y: 263 },
# { id: 10000000013, label: `stay`, group: "actions", x:

# %% [markdown]
# And here is a way to do it using the model API. Do note that this model is slightly different!

# %%
# We create the monty hall mdp
mdp = stormvogel.model.new_mdp("Monty Hall")

init = mdp.get_initial_state()

# first choose car position
init.set_transitions(
    [(1 / 3, mdp.new_state("carchosen", {"car_pos": i})) for i in range(3)]
)

# we choose a door in each case
for s in mdp.get_states_with_label("carchosen"):
    s.set_transitions(
        [
            (
                mdp.action(f"open{i}"),
                mdp.new_state("open", s.valuations | {"chosen_pos": i}),
            )
            for i in range(3)
        ]
    )

# the other goat is revealed
for s in mdp.get_states_with_label("open"):
    car_pos = s.valuations["car_pos"]
    chosen_pos = s.valuations["chosen_pos"]
    other_pos = {0, 1, 2} - {car_pos, chosen_pos}
    s.set_transitions(
        [
            (
                1 / len(other_pos),
                mdp.new_state("goatrevealed", s.valuations | {"reveal_pos": i}),
            )
            for i in other_pos
        ]
    )

# we must choose whether we want to switch
for s in mdp.get_states_with_label("goatrevealed"):
    car_pos = s.valuations["car_pos"]
    chosen_pos = s.valuations["chosen_pos"]
    reveal_pos = s.valuations["reveal_pos"]
    other_pos = list({0, 1, 2} - {reveal_pos, chosen_pos})[0]
    s.set_transitions(
        [
            (
                mdp.action("stay"),
                mdp.new_state(
                    ["done"] + (["target"] if chosen_pos == car_pos else []),
                    s.valuations | {"chosen_pos": chosen_pos},
                ),
            ),
            (
                mdp.action("switch"),
                mdp.new_state(
                    ["done"] + (["target"] if other_pos == car_pos else []),
                    s.valuations | {"chosen_pos": other_pos},
                ),
            ),
        ]
    )

# we add self loops to all states with no outgoing transitions
mdp.add_self_loops()
vis = show(mdp, layout=Layout("layouts/monty.json"))
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <title>Network</title>
#     <script
#       type="text/javascript"
#       src="https://unpkg.com/vis-network/standalone/umd/vis-network.min.js"
#     ></script>
#     <style type="text/css">
#       #modelkBYshIcNqh {
#         width: 1010px;
#         height: 777px;
#         border: 1px solid lightgray;
#       }
#     </style>
#   </head>
#   <body>
#     <div id="modelkBYshIcNqh"></div>
#     <script type="text/javascript">
#
# class NetworkWrapper_modelkBYshIcNqh{//js
#   constructor(nodes, edges, options, container) {
#     this.nodes = nodes;
#     this.edges = edges;
#     this.options = options;
#     this.container = container;
#     this.data = {
#       nodes: nodes,
#       edges: edges,
#     };
#     this.network = new vis.Network(container, this.data, options);
#     var this_ = this; // Events will not work if you use 'this' directly :))))) No idea why.
#
#     // Set user-triggered events.
#     this.network.on( 'click', function(properties) {
#       var nodeId = this_.network.getNodeAt({x:properties.event.srcEvent.offsetX, y:properties.event.srcEvent.offsetY});
#       this_.makeNeighborsVisible(nodeId);
#     });
#     this.network.on( 'doubleClick', function(properties) {
#         this_.network.setData(this_.data);
#     });
#   }
#
#   setNodeColor(id, color) {
#     var node = this.nodes.get(id);
#     node["x"] = this.network.getPosition(id)["x"];
#     node["y"] = this.network.getPosition(id)["y"];
#     node["color"] = color;
#     this.nodes.update(node);
#   }
#
#   makeNeighborsVisible(homeId) {
#     if (homeId === undefined) {
#       return;
#     }
#     var homeNode = this.nodes.get(homeId);
#
#     // Make outgoing nodes visible
#     var nodeIds = this.network.getConnectedNodes(homeId, "to");
#     for (let i = 0; i < nodeIds.length; i++) {
#       var toNodeId = nodeIds[i];
#       var toNode = this.nodes.get(toNodeId);
#       if (toNode["hidden"]) {
#         toNode["hidden"] = false;
#         toNode["physics"] = true;
#         toNode["x"] = this.network.getPosition(homeId)["x"];
#         toNode["y"] = this.network.getPosition(homeId)["y"];
#         this.nodes.update(toNode);
#       }
#     }
#     // Make edges visible, if both of the nodes are also visible
#     var edgeIds = this.network.getConnectedEdges(homeId);
#     for (let i = 0; i < edgeIds.length; i++) {
#       var edgeId = edgeIds[i];
#       var edge = this.edges.get(edgeId);
#       var fromNode = this.nodes.get(edge.from);
#       var toNode = this.nodes.get(edge.to);
#       if ((! fromNode["hidden"]) && (! toNode["hidden"])) {
#         edge["hidden"] = false;
#         edge["physics"] = true;
#         this.edges.update(edge);
#       }
#     }
#   }
# };
#
#     </script>
#     <script type="text/javascript">
#         //js
#     var nodes_local = new vis.DataSet([{ id: 0, label: `init`, group: "states", x: 0, y: 0 },
# { id: 1, label: `carchosen`, group: "states", x: -279, y: 8 },
# { id: 2, label: `carchosen`, group: "states", x: 124, y: -257 },
# { id: 3, label: `carchosen`, group: "states", x: 127, y: 242 },
# { id: 4, label: `open`, group: "states", x: -671, y: 207 },
# { id: 5, label: `open`, group: "states", x: -596, y: -252 },
# { id: 6, label: `open`, group: "states", x: -259, y: 299 },
# { id: 7, label: `open`, group: "states", x: 536, y: -384 },
# { id: 8, label: `open`, group: "states", x: -132, y: -393 },
# { id: 9, label: `open`, group: "states", x: 150, y: -695 },
# { id: 10, label: `open`, group: "states", x: 82, y: 654 },
# { id: 11, label: `open`, group: "states", x: 507, y: 455 },
# { id: 12, label: `open`, group: "states", x: 294, y: 63 },
# { id: 13, label: `goatrevealed`, group: "states", x: -740, y: 390 },
# { id: 14, label: `goatrevealed`, group: "states", x: -849, y: 180 },
# { id: 15, label: `goatrevealed`, group: "states", x: -649, y: -434 },
# { id: 16, label: `goatrevealed`, group: "states", x: -767, y: -244 },
# { id: 17, label: `goatrevealed`, group: "states", x: -348, y: 433 },
# { id: 18, label: `goatrevealed`, group: "states", x: -122, y: 342 },
# { id: 19, label: `goatrevealed`, group: "states", x: 620, y: -531 },
# { id: 20, label: `goatrevealed`, group: "states", x: 721, y: -332 },
# { id: 21, label: `goatrevealed`, group: "states", x: -210, y: -535 },
# { id: 22, label: `goatrevealed`, group: "states", x: -199, y: -263 },
# { id: 23, label: `goatrevealed`, group: "states", x: 47, y: -857 },
# { id: 24, label: `goatrevealed`, group: "states", x: 280, y: -826 },
# { id: 25, label: `done,target`, group: "states", x: -43, y: 797 },
# { id: 26, label: `done`, group: "states", x: 189, y: 790 },
# { id: 27, label: `done,target`, group: "states", x: 693, y: 400 },
# { id: 28, label: `done`, group: "states", x: 591, y: 612 },
# { id: 29, label: `done`, group: "states", x: 444, y: 99 },
# { id: 30, label: `done,target`, group: "states", x: 315, y: -66 },
# { id: 31, label: `done`, group: "states", x: -969, y: 582 },
# { id: 32, label: `done,target`, group: "states", x: -722, y: 687 },
# { id: 33, label: `done`, group: "states", x: -1107, y: 55 },
# { id: 34, label: `done,target`, group: "states", x: -1112, y: 318 },
# { id: 35, label: `done,target`, group: "states", x: -639, y: -725 },
# { id: 36, label: `done`, group: "states", x: -872, y: -634 },
# { id: 37, label: `done,target`, group: "states", x: -1020, y: -400 },
# { id: 38, label: `done`, group: "states", x: -1025, y: -154 },
# { id: 39, label: `done`, group: "states", x: -561, y: 320 },
# { id: 40, label: `done,target`, group: "states", x: -461, y: 700 },
# { id: 41, label: `done`, group: "states", x: -53, y: 93 },
# { id: 42, label: `done,target`, group: "states", x: -174, y: 602 },
# { id: 43, label: `done`, group: "states", x: 388, y: -611 },
# { id: 44, label: `done,target`, group: "states", x: 847, y: -722 },
# { id: 45, label: `done,target`, group: "states", x: 1005, y: -424 },
# { id: 46, label: `done`, group: "states", x: 951, y: -150 },
# { id: 47, label: `done,target`, group: "states", x: -407, y: -746 },
# { id: 48, label: `done`, group: "states", x: -193, y: -781 },
# { id: 10000000000, label: `open0`, group: "actions", x: -479, y: 99 },
# { id: 10000000001, label: `open1`, group: "actions", x: -438, y: -120 },
# { id: 10000000002, label: `open2`, group: "actions", x: -259, y: 148 },
# { id: 10000000003, label: `open0`, group: "actions", x: 324, y: -340 },
# { id: 10000000004, label: `open1`, group: "actions", x: -4, y: -317 },
# { id: 10000000005, label: `open2`, group: "actions", x: 137, y: -479 },
# { id: 10000000006, label: `open0`, group: "actions", x: 106, y: 449 },
# { id: 10000000007, label: `open1`, group: "actions", x: 308, y: 363 },
# { id: 10000000008, label: `open2`, group: "actions", x: 170, y: 120 },
# { id: 10000000009, label: `stay`, group: "actions", x: -871, y: 483 },
# { id: 10000000010, label: `switch`, group: "actions", x: -714, y: 547 },
# { id: 10000000011, label: `stay`, group: "actions", x: -973, y: 92 },
# { id: 10000000012, label: `switch`, group: "actions", x: -983, y: 263 },
# { id: 10000000013, label: `stay`, group: "actions", x: -620, y: -587 },
# { id: 10000000014, label: `switch`, group: "actions", x: -776, y: -532 },
# { id: 10000000015, label: `stay`, group: "actions", x: -895, y: -337 },
# { id: 10000000016, label: `switch`, group: "actions", x: -889, y: -163 },
# { id: 10000000017, label: `stay`, group: "actions", x: -452, y: 354 },
# { id: 10000000018, label: `switch`, group: "actions", x: -403, y: 576 },
# { id: 10000000019, label: `stay`, group: "actions", x: -60, y: 220 },
# { id: 10000000020, label: `switch`, group: "actions", x: -119, y: 482 },
# { id: 10000000021, label: `stay`, group: "actions", x: 515, y: -618 },
# { id: 10000000022, label: `switch`, group: "actions", x: 744, y: -630 },
# { id: 10000000023, label: `stay`, group: "actions", x: 869, y: -392 },
# { id: 10000000024, label: `switch`, group: "actions", x: 832, y: -221 },
# { id: 10000000025, label: `stay`, group: "actions", x: -331, y: -630 },
# { id: 10000000026, label: `switch`, group: "actions", x: -151, y: -658 },
# { id: 10000000027, label: `stay`, group: "actions", x: -132, y: -146 },
# { id: 10000000028, label: `switch`, group: "actions", x: -330, y: -292 },
# { id: 10000000029, lab
