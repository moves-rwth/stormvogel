# %% [markdown]
# # Building MDPs
# A Markov Decision Process is an extended Markov Chain which
#
# * states
# * actions
# * transitions
#
# Where
#
# * actions are essentially 'decisions' which might be decided by *schedulers*
# * each state has a number of actions
# * actions have probabilistic transitions to states
#
# A famous example of an MDP is the Monty Hall problem. We will show how to construct it using the pgc API.

# %%
from stormvogel import pgc
from stormvogel.model import EmptyAction, ModelType
from stormvogel.show import show
from stormvogel.layout import Layout, DEFAULT

init = pgc.State(x="")

empty_action = pgc.Action(["emp"])

def available_actions(s: pgc.State):
    if "carchosen" in s.x:
        return [pgc.Action(["choosedoor"]) for i in range(1,4)]
    elif "chosen" in s.x:
        return [pgc.Action(["stay"]), pgc.Action(["switch"])]
    return [empty_action]
    

def delta(s: pgc.State, a: pgc.Action):
    # empty actions
    if s == init:
        return [(1/3, pgc.State(x=["carchosen"], car=i)) for i in range(1,4)]
    elif "choosedoor" in a.labels:
        return [(1/3, pgc.State(x=["chose", str(i)], car=s.car, chosen=i)) for i in [1,2,3]]
    elif "chose" in s.x:
        possible_goats = set([1,2,3]) - {s.car} - {s.chosen}
        return [(1/len(possible_goats), 
                pgc.State(x=["chosen", str(s.chosen), f"goat,{i}"], 
                car=s.car, goat=i, chosen=s.chosen)) 
                for i in possible_goats]
    elif "stay" in a.labels:
        return [(1, pgc.State(x=["won"], pred=s))] if s.chosen == s.car else [(1, pgc.State(x=["lost"], pred=s))]
    elif "switch" in a.labels:
        return [(1, pgc.State(x=["won"], pred=s))] if s.chosen != s.car else [(1, pgc.State(x=["lost"], pred=s))]
    else:
        return [(1, s)]
        
# Labels is a function that tells the pgc API to use x as the label.
# It is written as a lambda here, but it means exactly the same as
# def labels(s):
#    return s.x
labels = lambda s: s.x

pgc_die = pgc.build_pgc(
    delta=delta,
    initial_state_pgc=init,
    available_actions=available_actions,
    labels=labels,
    modeltype=ModelType.MDP
)

vis2 = show(pgc_die)
# TODO finish this example once we know how to specify emtpy actions.
# Out:
#           <iframe
#                 id="modelCzdWeiwIpI"
#                 width="820"
#                 height="620"
#                 frameborder="0"
#                 srcdoc="
# &lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#   &lt;head&gt;
#     &lt;title&gt;Network&lt;/title&gt;
#     &lt;script
#       type=&quot;text/javascript&quot;
#       src=&quot;https://unpkg.com/vis-network/standalone/umd/vis-network.min.js&quot;
#     &gt;&lt;/script&gt;
#     &lt;style type=&quot;text/css&quot;&gt;
#       #mynetwork {
#
#         width: 800px;
#         height: 600px;
#         border: 1px solid lightgray;
#
#       }
#     &lt;/style&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;mynetwork&quot;&gt;&lt;/div&gt;
#     &lt;script type=&quot;text/javascript&quot;&gt;
#
#         var nodes = new vis.DataSet([{ id: 0, label: `init`, group: &quot;states&quot; },
# { id: 1, label: `carchosen`, group: &quot;states&quot; },
# { id: 2, label: `carchosen`, group: &quot;states&quot; },
# { id: 3, label: `carchosen`, group: &quot;states&quot; },
# { id: 4, label: `chose,1`, group: &quot;states&quot; },
# { id: 5, label: `chose,2`, group: &quot;states&quot; },
# { id: 6, label: `chose,3`, group: &quot;states&quot; },
# { id: 7, label: `chose,1`, group: &quot;states&quot; },
# { id: 8, label: `chose,2`, group: &quot;states&quot; },
# { id: 9, label: `chose,3`, group: &quot;states&quot; },
# { id: 10, label: `chose,1`, group: &quot;states&quot; },
# { id: 11, label: `chose,2`, group: &quot;states&quot; },
# { id: 12, label: `chose,3`, group: &quot;states&quot; },
# { id: 13, label: `chosen,1,goat,2`, group: &quot;states&quot; },
# { id: 14, label: `chosen,1,goat,3`, group: &quot;states&quot; },
# { id: 15, label: `chosen,2,goat,3`, group: &quot;states&quot; },
# { id: 16, label: `chosen,3,goat,2`, group: &quot;states&quot; },
# { id: 17, label: `chosen,1,goat,3`, group: &quot;states&quot; },
# { id: 18, label: `chosen,2,goat,1`, group: &quot;states&quot; },
# { id: 19, label: `chosen,2,goat,3`, group: &quot;states&quot; },
# { id: 20, label: `chosen,3,goat,1`, group: &quot;states&quot; },
# { id: 21, label: `chosen,1,goat,2`, group: &quot;states&quot; },
# { id: 22, label: `chosen,2,goat,1`, group: &quot;states&quot; },
# { id: 23, label: `chosen,3,goat,1`, group: &quot;states&quot; },
# { id: 24, label: `chosen,3,goat,2`, group: &quot;states&quot; },
# { id: 25, label: `won`, group: &quot;states&quot; },
# { id: 26, label: `lost`, group: &quot;states&quot; },
# { id: 27, label: `won`, group: &quot;states&quot; },
# { id: 28, label: `lost`, group: &quot;states&quot; },
# { id: 29, label: `lost`, group: &quot;states&quot; },
# { id: 30, label: `won`, group: &quot;states&quot; },
# { id: 31, label: `lost`, group: &quot;states&quot; },
# { id: 32, label: `won`, group: &quot;states&quot; },
# { id: 33, label: `lost`, group: &quot;states&quot; },
# { id: 34, label: `won`, group: &quot;states&quot; },
# { id: 35, label: `won`, group: &quot;states&quot; },
# { id: 36, label: `lost`, group: &quot;states&quot; },
# { id: 37, label: `won`, group: &quot;states&quot; },
# { id: 38, label: `lost`, group: &quot;states&quot; },
# { id: 39, label: `lost`, group: &quot;states&quot; },
# { id: 40, label: `won`, group: &quot;states&quot; },
# { id: 41, label: `lost`, group: &quot;states&quot; },
# { id: 42, label: `won`, group: &quot;states&quot; },
# { id: 43, label: `lost`, group: &quot;states&quot; },
# { id: 44, label: `won`, group: &quot;states&quot; },
# { id: 45, label: `won`, group: &quot;states&quot; },
# { id: 46, label: `lost`, group: &quot;states&quot; },
# { id: 47, label: `won`, group: &quot;states&quot; },
# { id: 48, label: `lost`, group: &quot;states&quot; },
# { id: 10000000000, label: `emp`, group: &quot;actions&quot; },
# { id: 10000000001, label: `choosedoor`, group: &quot;actions&quot; },
# { id: 10000000002, label: `choosedoor`, group: &quot;actions&quot; },
# { id: 10000000003, label: `choosedoor`, group: &quot;actions&quot; },
# { id: 10000000004, label: `emp`, group: &quot;actions&quot; },
# { id: 10000000005, label: `emp`, group: &quot;actions&quot; },
# { id: 10000000006, label: `emp`, group: &quot;actions&quot; },
# { id: 10000000007, label: `emp`, group: &quot;actions&quot; },
# { id: 10000000008, label: `emp`, group: &quot;actions&quot; },
# { id: 10000000009, label: `emp`, group: &quot;actions&quot; },
# { id: 10000000010, label: `emp`, group: &quot;actions&quot; },
# { id: 10000000011, label: `emp`, group: &quot;actions&quot; },
# { id: 10000000012, label: `emp`, group: &quot;actions&quot; },
# { id: 10000000013, label: `stay`, group: &quot;actions&quot; },
# { id: 10000000014, label: `switch`, group: &quot;actions&quot; },
# { id: 10000000015, label: `stay`, group: &quot;actions&quot; },
# { id: 10000000016, label: `switch`, group: &quot;actions&quot; },
# { id: 10000000017, label: `stay`, group: &quot;actions&quot; },
# { id: 10000000018, label: `switch`, group: &quot;actions&quot; },
# { id: 10000000019, label: `stay`, group: &quot;actions&quot; },
# { id: 10000000020, label: `switch`, group: &quot;actions&quot; },
# { id: 10000000021, label: `stay`, group: &quot;actions&quot; },
# { id: 10000000022, label: `switch`, group: &quot;actions&quot; },
# { id: 10000000023, label: `stay`, group: &quot;actions&quot; },
# { id: 10000000024, label: `switch`, group: &quot;actions&quot; },
# { id: 10000000025, label: `stay`, group: &quot;actions&quot; },
# { id: 10000000026, label: `switch`, group: &quot;actions&quot; },
# { id: 10000000027, label: `stay`, group: &quot;actions&quot; },
# { id: 10000000028, label: `switch`, group: &quot;actions&quot; },
# { id: 10000000029, label: `stay`, group: &quot;actions&quot; },
# { id: 10000000030, label: `switch`, group: &quot;actions&quot; },
# { id: 10000000031, label: `stay`, group: &quot;actions&quot; },
# { id: 10000000032, label: `switch`, group: &quot;actions&quot; },
# { id: 10000000033, label: `stay`, group: &quot;actions&quot; },
# { id: 10000000034, label: `switch`, group: &quot;actions&quot; },
# { id: 10000000035, label: `stay`, group: &quot;actions&quot; },
# { id: 10000000036, label: `switch`, group: &quot;actions&quot; },
# { id: 10000000037, label: `emp`, group: &quot;actions&quot; },
# { id: 10000000038, label: `emp`, group: &quot;actions&quot; },
# { id: 10000000039, label: `emp`, group: &quot;actions&quot; },
# { id: 10000000040, label: `emp`, group: &quot;actions&quot; },
# { id: 10000000041, label: `emp`, group: &quot;actions&quot; },
# { id: 10000000042, label: `emp`, group: &quot;actions&quot; },
# { id: 10000000043, label: `emp`, group: &quot;actions&quot; },
# { id: 10000000044, label: `emp`, group: &quot;actions&quot; },
# { id: 10000000045, label: `emp`, group: &quot;actions&quot; },
# { id: 10000000046, label: `emp`, group: &quot;actions&quot; },
# { id: 10000000047, label: `emp`, group: &quot;actions&quot; },
# { id: 10000000048, label: `emp`, group: &quot;actions&quot; },
# { id: 10000000049, label: `emp`, group: &quot;actions&quot; },
# { id: 10000000050, label: `emp`, group: &quot;actions&quot; },
# { id: 10000000051, label: `emp`, group: &quot;actions&quot; },
# { id: 10000000052, label: `emp`, group: &quot;actions&quot; },
# { id: 10000000053, label: `emp`, group: &quot;actions&quot; },
# { id: 10000000054, label: `emp`, group: &quot;actions&quot; },
# { id: 10000000055, label: `emp`, group: &quot;actions&quot; },
# { id: 10000000056, label: `emp`, group: &quot;actions&quot; },
# { id: 10000000057, label: `emp`, group: &quot;actions&quot; },
# { id: 10000000058, label: `emp`, group: &quot;actions&quot; },
# { id: 10000000059, label: `emp`, group: &quot;actions&quot; },
# { id: 10000000060, label: `emp`, group: &quot;actions&quot; },
# ]);
#         var edges = new vis.DataSet([{ from: 0, to: 10000000000 },
# { from: 10000000000, to: 1, label: &quot;1/3&quot; },
# { from: 10000000000, to: 2, label: &quot;1/3&quot; },
# { from: 10000000000, to: 3, label: &quot;1/3&quot; },
# { from: 1, to: 10000000001 },
# { from: 10000000001, to: 4, label: &quot;1/3&quot; },
# { from: 10000000001, to: 5, label: &quot;1/3&quot; },
# { from: 10000000001, to: 6, label: &quot;1/3&quot; },
# { from: 2, to: 10000000002 },
# { from: 10000000002,
