# %% [markdown]
# # Model checking (using Storm)
# In this notebook, we will show how to do model checking in stormvogel. Behind the scenes, we use stormpy for this.<br>
# We first use the simple study model. The idea is that if you do not study, then you save some time, hence you will gain 15 reward. If you pass the test you get 100 reward because you want to graduate eventually. If you study, then the chance of passing the test becomes higher. Now should you study?

# %%
from stormvogel.examples.study import create_study_mdp
from stormvogel.show import show
from stormvogel.layout import Layout

study = create_study_mdp()
vis = show(study, layout=Layout("layouts/pinkgreen.json"))
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <title>Network</title>
#     <script
#       type="text/javascript"
#       src="https://unpkg.com/vis-network/standalone/umd/vis-network.min.js"
#     ></script>
#     <style type="text/css">
#       #modelBHaFtQTFKs {
#         width: 461px;
#         height: 358px;
#         border: 1px solid lightgray;
#       }
#     </style>
#   </head>
#   <body>
#     <div id="modelBHaFtQTFKs"></div>
#     <script type="text/javascript">
#         //js
# class NetworkWrapper {
#   constructor(nodes, edges, options, container) {
#     this.nodes = nodes;
#     this.edges = edges;
#     this.options = options;
#     this.container = container;
#     this.data = {
#       nodes: nodes,
#       edges: edges,
#     };
#     this.network = new vis.Network(container, this.data, options);
#     var this_ = this; // Events will not work if you use 'this' directly :))))) No idea why.
#
#     // Set user-triggered events.
#     this.network.on( 'click', function(properties) {
#       var nodeId = this_.network.getNodeAt({x:properties.event.srcEvent.offsetX, y:properties.event.srcEvent.offsetY});
#       this_.makeNeighborsVisible(nodeId);
#     });
#     this.network.on( 'doubleClick', function(properties) {
#         this_.network.setData(this_.data);
#     });
#   }
#
#   setNodeColor(id, color) {
#     var node = this.nodes.get(id);
#     node["color"] = color
#     this.nodes.update(node);
#   }
#
#   makeNeighborsVisible(homeId) {
#     if (homeId === undefined) {
#       return;
#     }
#     var homeNode = this.nodes.get(homeId);
#
#     // Make outgoing nodes visible
#     var nodeIds = this.network.getConnectedNodes(homeId, "to");
#     for (let i = 0; i < nodeIds.length; i++) {
#       var toNodeId = nodeIds[i];
#       var toNode = this.nodes.get(toNodeId);
#       if (toNode["hidden"]) {
#         toNode["hidden"] = false;
#         toNode["physics"] = true;
#         toNode["x"] = this.network.getPosition(homeId)["x"];
#         toNode["y"] = this.network.getPosition(homeId)["y"];
#         this.nodes.update(toNode);
#       }
#     }
#     // Make edges visible, if both of the nodes are also visible
#     var edgeIds = this.network.getConnectedEdges(homeId);
#     for (let i = 0; i < edgeIds.length; i++) {
#       var edgeId = edgeIds[i];
#       var edge = this.edges.get(edgeId);
#       var fromNode = this.nodes.get(edge.from);
#       var toNode = this.nodes.get(edge.to);
#       if ((! fromNode["hidden"]) && (! toNode["hidden"])) {
#         edge["hidden"] = false;
#         edge["physics"] = true;
#         this.edges.update(edge);
#       }
#     }
#   }
# };
#
#     </script>
#     <script type="text/javascript">
#         //js
#     var nodes_local = new vis.DataSet([{ id: 0, label: `init`, group: "states", x: -200, y: -25 },
# { id: 1, label: `studied
# €	R: 0`, group: "states", x: 3, y: -112 },
# { id: 2, label: `didn't study
# €	R: 15`, group: "states", x: -17, y: 119 },
# { id: 3, label: `pass test
# €	R: 100`, group: "states", x: 92, y: 27 },
# { id: 4, label: `fail test
# €	R: 0`, group: "states", x: 8, y: -1 },
# { id: 5, label: `end
# €	R: 0`, group: "states", x: 140, y: -58 },
# { id: 10000000000, label: `study
# €	R: 0`, group: "actions", x: -124, y: -138 },
# { id: 10000000001, label: `don't study
# €	R: 0`, group: "actions", x: -154, y: 103 },
# ]);
#     var edges_local = new vis.DataSet([{ from: 0, to: 10000000000 },
# { from: 10000000000, to: 1, label: "1" },
# { from: 0, to: 10000000001 },
# { from: 10000000001, to: 2, label: "1" },
# { from: 1, to: 3, label: "9/10" },
# { from: 1, to: 4, label: "1/10" },
# { from: 2, to: 3, label: "2/5" },
# { from: 2, to: 4, label: "3/5" },
# { from: 3, to: 5, label: "1" },
# { from: 4, to: 5, label: "1" },
# { from: 5, to: 5, label: "1" },
# ]);
#     var options_local = {
#   "__fake_macros": {
#     "__group_macro": {
#       "borderWidth": 1,
#       "color": {
#         "background": "white",
#         "border": "black",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "ellipse",
#       "mass": 1,
#       "font": {
#         "color": "black",
#         "size": 14
#       }
#     }
#   },
#   "edit_groups": {
#     "groups": [
#       "states",
#       "actions"
#     ]
#   },
#   "groups": {
#     "actions": {
#       "borderWidth": 1,
#       "color": {
#         "background": "#fbd0f5",
#         "border": "black",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "box",
#       "mass": 1,
#       "font": {
#         "color": "black",
#         "size": 14
#       }
#     },
#     "scheduled_actions": {
#       "shape": "box",
#       "color": {
#         "background": "pink",
#         "border": "red"
#       }
#     },
#     "states": {
#       "borderWidth": 1,
#       "color": {
#         "background": "#c9f9a9",
#         "border": "black",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "ellipse",
#       "mass": 1,
#       "font": {
#         "color": "black",
#         "size": 14
#       }
#     }
#   },
#   "reload_button": false,
#   "edges": {
#     "arrows": "to",
#     "font": {
#       "color": "black",
#       "size": 14,
#       "strokeColor": "white",
#       "strokeWidth": 2
#     },
#     "color": {
#       "color": "black"
#     },
#     "width": 1
#   },
#   "numbers": {
#     "fractions": true,
#     "digits": 5
#   },
#   "state_properties": {
#     "show_results": true,
#     "result_symbol": "\u2606",
#     "show_rewards": true,
#     "reward_symbol": "\u20ac",
#     "show_zero_rewards": true,
#     "show_observations": true,
#     "observation_symbol": "\u0298"
#   },
#   "layout": {
#     "randomSeed": 5
#   },
#   "misc": {
#     "enable_physics": true,
#     "width": 461,
#     "height": 358,
#     "explore": false
#   },
#   "saving": {
#     "relative_path": true,
#     "filename": "layouts/pinkgreen.json",
#     "save_button": false,
#     "load_button": false
#   },
#   "positions": {
#     "0": {
#       "x": -200,
#       "y": -25
#     },
#     "1": {
#       "x": 3,
#       "y": -112
#     },
#     "2": {
#       "x": -17,
#       "y": 119
#     },
#     "3": {
#       "x": 92,
#       "y": 27
#     },
#     "4": {
#       "x": 8,
#       "y": -1
#     },
#     "5": {
#       "x": 140,
#       "y": -58
#     },
#     "10000000000": {
#       "x": -124,
#       "y": -138
#     },
#     "10000000001": {
#       "x": -154,
#       "y": 103
#     }
#   },
#   "physics": true,
#   "autoResize": true
# };
#     var container_local = document.getElementById("modelBHaFtQTFKs");
#     var nw_modelBHaFtQTFKs = new NetworkWrapper(nodes_local, edges_local, options_local, container_local)
#
#     </script>
#   </body>
# </html>

# %% [markdown]
# Now we let stormpy solve the question whether you should study. Model checking requires a *property string*. This is a string that specifies what result the model checker should aim for. Stormvogel has a graphical interface that makes it easier to create these. Try to create a property that maximizes the reward at the end. The result should be `Rmax=? [F "end"]`.

# %%
from stormvogel.property_builder import build_property_string
build_property_string(study)
# Out:
# Output()
# Output()

# %% [markdown]
# Now we run our model checking, and then display the result on the model. The action that is chosen to maximize the reward is marked in red. In conclusion, you should study!<br>
# The red action is called the *scheduled action*. The star symbol indicates the *result* of a state. In this case, the result can be seen as the expected reward. The scheduler finds that going to the state with 'didn't study' results in an expected reward of 55, while the state with 'studied' results in an expected value of 90.

# %%
from stormvogel.model_checking import model_checking
import stormvogel.mapping as mapping
import stormpy

result = model_checking(study,'Rmax=? [F "end"]', True) #true lets it return a scheduler as well
vis = show(study, layout=Layout("layouts/pinkgreen.json"), result=result)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <title>Network</title>
#     <script
#       type="text/javascript"
#       src="https://unpkg.com/vis-network/standalone/umd/vis-network.min.js"
#     ></script>
#     <style type="text/css">
#       #modelOwpqVGlBiG {
#         width: 461px;
#         height: 358px;
#         border: 1px solid lightgray;
#       }
#     </style>
#   </head>
#   <body>
#     <div id="modelOwpqVGlBiG"></div>
#     <script type="text/javascript">
#         //js
# class NetworkWrapper {
#   constructor(nodes, edges, options, container) {
#     this.nodes = nodes;
#     this.edges = edges;
#     this.options = options;
#     this.container = container;
#     this.data = {
#       nodes: nodes,
#       edges: edges,
#     };
#     this.network = new vis.Network(container, this.data, options);
#     var this_ = this; // Events will not work if you use 'this' directly :))))) No idea why.
#
#     // Set user-triggered events.
#     this.network.on( 'click', function(properties) {
#       var nodeId = this_.network.getNodeAt({x:properties.event.srcEvent.offsetX, y:properties.event.srcEvent.offsetY});
#       this_.makeNeighborsVisible(nodeId);
#     });
#     this.network.on( 'doubleClick', function(properties) {
#         this_.network.setData(this_.data);
#     });
#   }
#
#   setNodeColor(id, color) {
#     var node = this.nodes.get(id);
#     node["color"] = color
#     this.nodes.update(node);
#   }
#
#   makeNeighborsVisible(homeId) {
#     if (homeId === undefined) {
#       return;
#     }
#     var homeNode = this.nodes.get(homeId);
#
#     // Make outgoing nodes visible
#     var nodeIds = this.network.getConnectedNodes(homeId, "to");
#     for (let i = 0; i < nodeIds.length; i++) {
#       var toNodeId = nodeIds[i];
#       var toNode = this.nodes.get(toNodeId);
#       if (toNode["hidden"]) {
#         toNode["hidden"] = false;
#         toNode["physics"] = true;
#         toNode["x"] = this.network.getPosition(homeId)["x"];
#         toNode["y"] = this.network.getPosition(homeId)["y"];
#         this.nodes.update(toNode);
#       }
#     }
#     // Make edges visible, if both of the nodes are also visible
#     var edgeIds = this.network.getConnectedEdges(homeId);
#     for (let i = 0; i < edgeIds.length; i++) {
#       var edgeId = edgeIds[i];
#       var edge = this.edges.get(edgeId);
#       var fromNode = this.nodes.get(edge.from);
#       var toNode = this.nodes.get(edge.to);
#       if ((! fromNode["hidden"]) && (! toNode["hidden"])) {
#         edge["hidden"] = false;
#         edge["physics"] = true;
#         this.edges.update(edge);
#       }
#     }
#   }
# };
#
#     </script>
#     <script type="text/javascript">
#         //js
#     var nodes_local = new vis.DataSet([{ id: 0, label: `init
# ☆ 90`, group: "states", x: -200, y: -25 },
# { id: 1, label: `studied
# €	R: 0
# ☆ 90`, group: "states", x: 3, y: -112 },
# { id: 2, label: `didn't study
# €	R: 15
# ☆ 55`, group: "states", x: -17, y: 119 },
# { id: 3, label: `pass test
# €	R: 100
# ☆ 100`, group: "states", x: 92, y: 27 },
# { id: 4, label: `fail test
# €	R: 0
# ☆ 0`, group: "states", x: 8, y: -1 },
# { id: 5, label: `end
# €	R: 0
# ☆ 0`, group: "states", x: 140, y: -58 },
# { id: 10000000000, label: `study
# €	R: 0`, group: "scheduled_actions", x: -124, y: -138 },
# { id: 10000000001, label: `don't study
# €	R: 0`, group: "actions", x: -154, y: 103 },
# ]);
#     var edges_local = new vis.DataSet([{ from: 0, to: 10000000000, color: "red" },
# { from: 10000000000, to: 1, label: "1", color: "red" },
# { from: 0, to: 10000000001 },
# { from: 10000000001, to: 2, label: "1" },
# { from: 1, to: 3, label: "9/10" },
# { from: 1, to: 4, label: "1/10" },
# { from: 2, to: 3, label: "2/5" },
# { from: 2, to: 4, label: "3/5" },
# { from: 3, to: 5, label: "1" },
# { from: 4, to: 5, label: "1" },
# { from: 5, to: 5, label: "1" },
# ]);
#     var options_local = {
#   "__fake_macros": {
#     "__group_macro": {
#       "borderWidth": 1,
#       "color": {
#         "background": "white",
#         "border": "black",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "ellipse",
#       "mass": 1,
#       "font": {
#         "color": "black",
#         "size": 14
#       }
#     }
#   },
#   "edit_groups": {
#     "groups": [
#       "states",
#       "actions",
#       "scheduled_actions"
#     ]
#   },
#   "groups": {
#     "actions": {
#       "borderWidth": 1,
#       "color": {
#         "background": "#fbd0f5",
#         "border": "black",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "box",
#       "mass": 1,
#       "font": {
#         "color": "black",
#         "size": 14
#       }
#     },
#     "scheduled_actions": {
#       "borderWidth": 1,
#       "color": {
#         "background": "pink",
#         "border": "red",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "box",
#       "mass": 1,
#       "font": {
#         "color": "black",
#         "size": 14
#       }
#     },
#     "states": {
#       "borderWidth": 1,
#       "color": {
#         "background": "#c9f9a9",
#         "border": "black",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "ellipse",
#       "mass": 1,
#       "font": {
#         "color": "black",
#         "size": 14
#       }
#     }
#   },
#   "reload_button": false,
#   "edges": {
#     "arrows": "to",
#     "font": {
#       "color": "black",
#       "size": 14,
#       "strokeColor": "white",
#       "strokeWidth": 2
#     },
#     "color": {
#       "color": "black"
#     },
#     "width": 1
#   },
#   "numbers": {
#     "fractions": true,
#     "digits": 5
#   },
#   "state_properties": {
#     "show_results": true,
#     "result_symbol": "\u2606",
#     "show_rewards": true,
#     "reward_symbol": "\u20ac",
#     "show_zero_rewards": true,
#     "show_observations": true,
#     "observation_symbol": "\u0298"
#   },
#   "layout": {
#     "randomSeed": 5
#   },
#   "misc": {
#     "enable_physics": true,
#     "width": 461,
#     "height": 358,
#     "explore": false
#   },
#   "saving": {
#     "relative_path": true,
#     "filename": "layouts/pinkgreen.json",
#     "save_button": false,
#     "load_button": false
#   },
#   "positions": {
#     "0": {
#       "x": -200,
#       "y": -25
#     },
#     "1": {
#       "x": 3,
#       "y": -112
#     },
#     "2": {
#       "x": -17,
#       "y": 119
#     },
#     "3": {
#       "x": 92,
#       "y": 27
#     },
#     "4": {
#       "x": 8,
#       "y": -1
#     },
#     "5": {
#       "x": 140,
#       "y": -58
#     },
#     "10000000000": {
#       "x": -124,
#       "y": -138
#     },
#     "10000000001": {
#       "x": -154,
#       "y": 103
#     }
#   },
#   "physics": true,
#   "autoResize": true
# };
#     var container_local = document.getElementById("modelOwpqVGlBiG");
#     var nw_modelOwpqVGlBiG = new NetworkWrapper(nodes_local, edges_local, options_local, container_local)
#
#     </script>
#   </body>
# </html>

# %% [markdown]
# Now, imagine that the exam is not so important after all. Say you only get 20 reward for passing. Is it still worth studying now? It turns out not to be the case! (The turning point is 30)

# %%
study2 = create_study_mdp()

reward_model = study2.get_rewards("R")
pass_test = study2.get_states_with_label("pass test")[0]
reward_model.set_state_reward(pass_test, 20)
result = model_checking(study2,'Rmax=? [F "end"]')
vis = show(study2, layout=Layout("layouts/pinkgreen.json"), result=result)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <title>Network</title>
#     <script
#       type="text/javascript"
#       src="https://unpkg.com/vis-network/standalone/umd/vis-network.min.js"
#     ></script>
#     <style type="text/css">
#       #modelEnXnsvdeWp {
#         width: 461px;
#         height: 358px;
#         border: 1px solid lightgray;
#       }
#     </style>
#   </head>
#   <body>
#     <div id="modelEnXnsvdeWp"></div>
#     <script type="text/javascript">
#         //js
# class NetworkWrapper {
#   constructor(nodes, edges, options, container) {
#     this.nodes = nodes;
#     this.edges = edges;
#     this.options = options;
#     this.container = container;
#     this.data = {
#       nodes: nodes,
#       edges: edges,
#     };
#     this.network = new vis.Network(container, this.data, options);
#     var this_ = this; // Events will not work if you use 'this' directly :))))) No idea why.
#
#     // Set user-triggered events.
#     this.network.on( 'click', function(properties) {
#       var nodeId = this_.network.getNodeAt({x:properties.event.srcEvent.offsetX, y:properties.event.srcEvent.offsetY});
#       this_.makeNeighborsVisible(nodeId);
#     });
#     this.network.on( 'doubleClick', function(properties) {
#         this_.network.setData(this_.data);
#     });
#   }
#
#   setNodeColor(id, color) {
#     var node = this.nodes.get(id);
#     node["color"] = color
#     this.nodes.update(node);
#   }
#
#   makeNeighborsVisible(homeId) {
#     if (homeId === undefined) {
#       return;
#     }
#     var homeNode = this.nodes.get(homeId);
#
#     // Make outgoing nodes visible
#     var nodeIds = this.network.getConnectedNodes(homeId, "to");
#     for (let i = 0; i < nodeIds.length; i++) {
#       var toNodeId = nodeIds[i];
#       var toNode = this.nodes.get(toNodeId);
#       if (toNode["hidden"]) {
#         toNode["hidden"] = false;
#         toNode["physics"] = true;
#         toNode["x"] = this.network.getPosition(homeId)["x"];
#         toNode["y"] = this.network.getPosition(homeId)["y"];
#         this.nodes.update(toNode);
#       }
#     }
#     // Make edges visible, if both of the nodes are also visible
#     var edgeIds = this.network.getConnectedEdges(homeId);
#     for (let i = 0; i < edgeIds.length; i++) {
#       var edgeId = edgeIds[i];
#       var edge = this.edges.get(edgeId);
#       var fromNode = this.nodes.get(edge.from);
#       var toNode = this.nodes.get(edge.to);
#       if ((! fromNode["hidden"]) && (! toNode["hidden"])) {
#         edge["hidden"] = false;
#         edge["physics"] = true;
#         this.edges.update(edge);
#       }
#     }
#   }
# };
#
#     </script>
#     <script type="text/javascript">
#         //js
#     var nodes_local = new vis.DataSet([{ id: 0, label: `init
# ☆ 23`, group: "states", x: -200, y: -25 },
# { id: 1, label: `studied
# €	R: 0
# ☆ 18`, group: "states", x: 3, y: -112 },
# { id: 2, label: `didn't study
# €	R: 15
# ☆ 23`, group: "states", x: -17, y: 119 },
# { id: 3, label: `pass test
# €	R: 20
# ☆ 20`, group: "states", x: 92, y: 27 },
# { id: 4, label: `fail test
# €	R: 0
# ☆ 0`, group: "states", x: 8, y: -1 },
# { id: 5, label: `end
# €	R: 0
# ☆ 0`, group: "states", x: 140, y: -58 },
# { id: 10000000000, label: `study
# €	R: 0`, group: "actions", x: -124, y: -138 },
# { id: 10000000001, label: `don't study
# €	R: 0`, group: "scheduled_actions", x: -154, y: 103 },
# ]);
#     var edges_local = new vis.DataSet([{ from: 0, to: 10000000000 },
# { from: 10000000000, to: 1, label: "1" },
# { from: 0, to: 10000000001, color: "red" },
# { from: 10000000001, to: 2, label: "1", color: "red" },
# { from: 1, to: 3, label: "9/10" },
# { from: 1, to: 4, label: "1/10" },
# { from: 2, to: 3, label: "2/5" },
# { from: 2, to: 4, label: "3/5" },
# { from: 3, to: 5, label: "1" },
# { from: 4, to: 5, label: "1" },
# { from: 5, to: 5, label: "1" },
# ]);
#     var options_local = {
#   "__fake_macros": {
#     "__group_macro": {
#       "borderWidth": 1,
#       "color": {
#         "background": "white",
#         "border": "black",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "ellipse",
#       "mass": 1,
#       "font": {
#         "color": "black",
#         "size": 14
#       }
#     }
#   },
#   "edit_groups": {
#     "groups": [
#       "states",
#       "actions",
#       "scheduled_actions"
#     ]
#   },
#   "groups": {
#     "actions": {
#       "borderWidth": 1,
#       "color": {
#         "background": "#fbd0f5",
#         "border": "black",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "box",
#       "mass": 1,
#       "font": {
#         "color": "black",
#         "size": 14
#       }
#     },
#     "scheduled_actions": {
#       "borderWidth": 1,
#       "color": {
#         "background": "pink",
#         "border": "red",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "box",
#       "mass": 1,
#       "font": {
#         "color": "black",
#         "size": 14
#       }
#     },
#     "states": {
#       "borderWidth": 1,
#       "color": {
#         "background": "#c9f9a9",
#         "border": "black",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "ellipse",
#       "mass": 1,
#       "font": {
#         "color": "black",
#         "size": 14
#       }
#     }
#   },
#   "reload_button": false,
#   "edges": {
#     "arrows": "to",
#     "font": {
#       "color": "black",
#       "size": 14,
#       "strokeColor": "white",
#       "strokeWidth": 2
#     },
#     "color": {
#       "color": "black"
#     },
#     "width": 1
#   },
#   "numbers": {
#     "fractions": true,
#     "digits": 5
#   },
#   "state_properties": {
#     "show_results": true,
#     "result_symbol": "\u2606",
#     "show_rewards": true,
#     "reward_symbol": "\u20ac",
#     "show_zero_rewards": true,
#     "show_observations": true,
#     "observation_symbol": "\u0298"
#   },
#   "layout": {
#     "randomSeed": 5
#   },
#   "misc": {
#     "enable_physics": true,
#     "width": 461,
#     "height": 358,
#     "explore": false
#   },
#   "saving": {
#     "relative_path": true,
#     "filename": "layouts/pinkgreen.json",
#     "save_button": false,
#     "load_button": false
#   },
#   "positions": {
#     "0": {
#       "x": -200,
#       "y": -25
#     },
#     "1": {
#       "x": 3,
#       "y": -112
#     },
#     "2": {
#       "x": -17,
#       "y": 119
#     },
#     "3": {
#       "x": 92,
#       "y": 27
#     },
#     "4": {
#       "x": 8,
#       "y": -1
#     },
#     "5": {
#       "x": 140,
#       "y": -58
#     },
#     "10000000000": {
#       "x": -124,
#       "y": -138
#     },
#     "10000000001": {
#       "x": -154,
#       "y": 103
#     }
#   },
#   "physics": true,
#   "autoResize": true
# };
#     var container_local = document.getElementById("modelEnXnsvdeWp");
#     var nw_modelEnXnsvdeWp = new NetworkWrapper(nodes_local, edges_local, options_local, container_local)
#
#     </script>
#   </body>
# </html>

# %% [markdown]
# Using the simulator, we can get a path from the scheduler that we found.

# %% [markdown]
# Let's do another example with the lion model from before. We want to minimize the chance that it dies. We do asking the model checker to minimize the chance of reaching 'dead'. It turns out that our lion is really screwed, it will always die eventually, no matter what it chooses... The result (☆) at the initial state is 1. This means that the probability of the forumula [F "dead"] (eventually, the model reaches a state with "dead"), is 1.

# %%
from stormvogel.examples.lion import create_lion_mdp
lion = create_lion_mdp()
result = model_checking(lion,'Pmin=? [F "dead"]', True)
vis = show(lion, layout=Layout("layouts/lion.json"), result=result)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <title>Network</title>
#     <script
#       type="text/javascript"
#       src="https://unpkg.com/vis-network/standalone/umd/vis-network.min.js"
#     ></script>
#     <style type="text/css">
#       #modelwLczryYEzS {
#         width: 687px;
#         height: 519px;
#         border: 1px solid lightgray;
#       }
#     </style>
#   </head>
#   <body>
#     <div id="modelwLczryYEzS"></div>
#     <script type="text/javascript">
#         //js
# class NetworkWrapper {
#   constructor(nodes, edges, options, container) {
#     this.nodes = nodes;
#     this.edges = edges;
#     this.options = options;
#     this.container = container;
#     this.data = {
#       nodes: nodes,
#       edges: edges,
#     };
#     this.network = new vis.Network(container, this.data, options);
#     var this_ = this; // Events will not work if you use 'this' directly :))))) No idea why.
#
#     // Set user-triggered events.
#     this.network.on( 'click', function(properties) {
#       var nodeId = this_.network.getNodeAt({x:properties.event.srcEvent.offsetX, y:properties.event.srcEvent.offsetY});
#       this_.makeNeighborsVisible(nodeId);
#     });
#     this.network.on( 'doubleClick', function(properties) {
#         this_.network.setData(this_.data);
#     });
#   }
#
#   setNodeColor(id, color) {
#     var node = this.nodes.get(id);
#     node["color"] = color
#     this.nodes.update(node);
#   }
#
#   makeNeighborsVisible(homeId) {
#     if (homeId === undefined) {
#       return;
#     }
#     var homeNode = this.nodes.get(homeId);
#
#     // Make outgoing nodes visible
#     var nodeIds = this.network.getConnectedNodes(homeId, "to");
#     for (let i = 0; i < nodeIds.length; i++) {
#       var toNodeId = nodeIds[i];
#       var toNode = this.nodes.get(toNodeId);
#       if (toNode["hidden"]) {
#         toNode["hidden"] = false;
#         toNode["physics"] = true;
#         toNode["x"] = this.network.getPosition(homeId)["x"];
#         toNode["y"] = this.network.getPosition(homeId)["y"];
#         this.nodes.update(toNode);
#       }
#     }
#     // Make edges visible, if both of the nodes are also visible
#     var edgeIds = this.network.getConnectedEdges(homeId);
#     for (let i = 0; i < edgeIds.length; i++) {
#       var edgeId = edgeIds[i];
#       var edge = this.edges.get(edgeId);
#       var fromNode = this.nodes.get(edge.from);
#       var toNode = this.nodes.get(edge.to);
#       if ((! fromNode["hidden"]) && (! toNode["hidden"])) {
#         edge["hidden"] = false;
#         edge["physics"] = true;
#         this.edges.update(edge);
#       }
#     }
#   }
# };
#
#     </script>
#     <script type="text/javascript">
#         //js
#     var nodes_local = new vis.DataSet([{ id: 0, label: `init
# ☆ 1`, group: "states", x: -278, y: -336 },
# { id: 1, label: `full
# ☆ 1`, group: "states", x: -125, y: 158 },
# { id: 2, label: `hungry :(
# ☆ 1`, group: "states", x: -112, y: -124 },
# { id: 3, label: `starving :((
# ☆ 1`, group: "states", x: 188, y: -93 },
# { id: 4, label: `dead
# €	R: 0
# ☆ 1`, group: "states", x: 290, y: 166 },
# { id: 10000000000, label: `hunt >:D
# €	R: 0`, group: "scheduled_actions", x: -184, y: 21 },
# { id: 10000000001, label: `rawr
# €	R: 0`, group: "actions", x: -254, y: 67 },
# { id: 10000000002, label: `hunt >:D
# €	R: 0`, group: "scheduled_actions", x: -19, y: -25 },
# { id: 10000000003, label: `rawr
# €	R: 100`, group: "actions", x: 31, y: -213 },
# { id: 10000000004, label: `hunt >:D
# €	R: 0`, group: "scheduled_actions", x: 81, y: 29 },
# { id: 10000000005, label: `rawr
# €	R: 0`, group: "actions", x: 331, y: -22 },
# { id: 10000000006, label: `hunt >:D
# €	R: 0`, group: "scheduled_actions", x: 75, y: 134 },
# { id: 10000000007, label: `rawr
# €	R: 0`, group: "actions", x: 288, y: 323 },
# ]);
#     var edges_local = new vis.DataSet([{ from: 0, to: 10000000000, color: "#ff0000" },
# { from: 10000000000, to: 0, label: "1/2", color: "#ff0000" },
# { from: 10000000000, to: 1, label: "3/10", color: "#ff0000" },
# { from: 10000000000, to: 2, label: "1/5", color: "#ff0000" },
# { from: 0, to: 10000000001 },
# { from: 10000000001, to: 0, label: "9/10" },
# { from: 10000000001, to: 2, label: "1/10" },
# { from: 1, to: 10000000002, color: "#ff0000" },
# { from: 10000000002, to: 0, label: "1/2", color: "#ff0000" },
# { from: 10000000002, to: 1, label: "1/2", color: "#ff0000" },
# { from: 1, to: 10000000003 },
# { from: 10000000003, to: 1, label: "9/10" },
# { from: 10000000003, to: 0, label: "1/10" },
# { from: 2, to: 10000000004, color: "#ff0000" },
# { from: 10000000004, to: 1, label: "1/5", color: "#ff0000" },
# { from: 10000000004, to: 0, label: "1/2", color: "#ff0000" },
# { from: 10000000004, to: 2, label: "1/10", color: "#ff0000" },
# { from: 10000000004, to: 3, label: "1/5", color: "#ff0000" },
# { from: 2, to: 10000000005 },
# { from: 10000000005, to: 2, label: "9/10" },
# { from: 10000000005, to: 3, label: "1/10" },
# { from: 3, to: 10000000006, color: "#ff0000" },
# { from: 10000000006, to: 1, label: "1/10", color: "#ff0000" },
# { from: 10000000006, to: 0, label: "1/2", color: "#ff0000" },
# { from: 10000000006, to: 2, label: "1/5", color: "#ff0000" },
# { from: 10000000006, to: 4, label: "1/5", color: "#ff0000" },
# { from: 3, to: 10000000007 },
# { from: 10000000007, to: 3, label: "9/10" },
# { from: 10000000007, to: 4, label: "1/10" },
# { from: 4, to: 4, label: "1" },
# ]);
#     var options_local = {
#   "__fake_macros": {
#     "__group_macro": {
#       "borderWidth": 1,
#       "color": {
#         "background": "white",
#         "border": "black",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "ellipse",
#       "mass": 1,
#       "font": {
#         "color": "black",
#         "size": 14
#       }
#     }
#   },
#   "edit_groups": {
#     "groups": [
#       "states",
#       "actions",
#       "scheduled_actions"
#     ]
#   },
#   "groups": {
#     "actions": {
#       "borderWidth": 1,
#       "color": {
#         "background": "lightblue",
#         "border": "black",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "box",
#       "mass": 1,
#       "font": {
#         "color": "black",
#         "size": 14
#       }
#     },
#     "scheduled_actions": {
#       "borderWidth": 1,
#       "color": {
#         "background": "pink",
#         "border": "#ff0000",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "box",
#       "mass": 1,
#       "font": {
#         "color": "black",
#         "size": 14
#       },
#       "schedColor": false
#     },
#     "states": {
#       "borderWidth": 1,
#       "color": {
#         "background": "#f5c211",
#         "border": "#c64600",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "ellipse",
#       "mass": 5,
#       "font": {
#         "color": "black",
#         "size": 14
#       }
#     },
#     "dead...": {
#       "borderWidth": 1,
#       "color": {
#         "background": "#c0bfbc",
#         "border": "black",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "ellipse",
#       "mass": 1,
#       "font": {
#         "color": "black",
#         "size": 14
#       }
#     },
#     "hunt_>:D": {
#       "borderWidth": 1,
#       "color": {
#         "background": "#2ec27e",
#         "border": "black",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "ellipse",
#       "mass": 1,
#       "font": {
#         "color": "black",
#         "size": 14
#       }
#     },
#     "desparate_hunt!": {
#       "borderWidth": 1,
#       "color": {
#         "background": "#ff7800",
#         "border": "black",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "ellipse",
#       "mass": 1,
#       "font": {
#         "color": "black",
#         "size": 14
#       }
#     },
#     "starving_:((": {
#       "borderWidth": 1,
#       "color": {
#         "background": "white",
#         "border": "black",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "ellipse",

# %% [markdown]
# On the other hand, our lion might as well have a good time while it's alive. All a lion really wants is to roar while being full. If it does this, it gets a reward of 100. Let's try to maximize this reward. The scheduler that is found always roars when it's full and hunts otherwise.

# %%
result2 = model_checking(lion,'Rmax=? [ F "dead" ]', True)
vis = show(lion, layout=Layout("layouts/lion.json"), result=result2)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <title>Network</title>
#     <script
#       type="text/javascript"
#       src="https://unpkg.com/vis-network/standalone/umd/vis-network.min.js"
#     ></script>
#     <style type="text/css">
#       #modelICGfEeajEV {
#         width: 687px;
#         height: 519px;
#         border: 1px solid lightgray;
#       }
#     </style>
#   </head>
#   <body>
#     <div id="modelICGfEeajEV"></div>
#     <script type="text/javascript">
#         //js
# class NetworkWrapper {
#   constructor(nodes, edges, options, container) {
#     this.nodes = nodes;
#     this.edges = edges;
#     this.options = options;
#     this.container = container;
#     this.data = {
#       nodes: nodes,
#       edges: edges,
#     };
#     this.network = new vis.Network(container, this.data, options);
#     var this_ = this; // Events will not work if you use 'this' directly :))))) No idea why.
#
#     // Set user-triggered events.
#     this.network.on( 'click', function(properties) {
#       var nodeId = this_.network.getNodeAt({x:properties.event.srcEvent.offsetX, y:properties.event.srcEvent.offsetY});
#       this_.makeNeighborsVisible(nodeId);
#     });
#     this.network.on( 'doubleClick', function(properties) {
#         this_.network.setData(this_.data);
#     });
#   }
#
#   setNodeColor(id, color) {
#     var node = this.nodes.get(id);
#     node["color"] = color
#     this.nodes.update(node);
#   }
#
#   makeNeighborsVisible(homeId) {
#     if (homeId === undefined) {
#       return;
#     }
#     var homeNode = this.nodes.get(homeId);
#
#     // Make outgoing nodes visible
#     var nodeIds = this.network.getConnectedNodes(homeId, "to");
#     for (let i = 0; i < nodeIds.length; i++) {
#       var toNodeId = nodeIds[i];
#       var toNode = this.nodes.get(toNodeId);
#       if (toNode["hidden"]) {
#         toNode["hidden"] = false;
#         toNode["physics"] = true;
#         toNode["x"] = this.network.getPosition(homeId)["x"];
#         toNode["y"] = this.network.getPosition(homeId)["y"];
#         this.nodes.update(toNode);
#       }
#     }
#     // Make edges visible, if both of the nodes are also visible
#     var edgeIds = this.network.getConnectedEdges(homeId);
#     for (let i = 0; i < edgeIds.length; i++) {
#       var edgeId = edgeIds[i];
#       var edge = this.edges.get(edgeId);
#       var fromNode = this.nodes.get(edge.from);
#       var toNode = this.nodes.get(edge.to);
#       if ((! fromNode["hidden"]) && (! toNode["hidden"])) {
#         edge["hidden"] = false;
#         edge["physics"] = true;
#         this.edges.update(edge);
#       }
#     }
#   }
# };
#
#     </script>
#     <script type="text/javascript">
#         //js
#     var nodes_local = new vis.DataSet([{ id: 0, label: `init
# ☆ 36487455/967`, group: "states", x: -278, y: -336 },
# { id: 1, label: `full
# ☆ 30947067/799`, group: "states", x: -125, y: 158 },
# { id: 2, label: `hungry :(
# ☆ 28515607/787`, group: "states", x: -112, y: -124 },
# { id: 3, label: `starving :((
# ☆ 5787331/193`, group: "states", x: 188, y: -93 },
# { id: 4, label: `dead
# €	R: 0
# ☆ 0`, group: "states", x: 290, y: 166 },
# { id: 10000000000, label: `hunt >:D
# €	R: 0`, group: "scheduled_actions", x: -184, y: 21 },
# { id: 10000000001, label: `rawr
# €	R: 0`, group: "actions", x: -254, y: 67 },
# { id: 10000000002, label: `hunt >:D
# €	R: 0`, group: "actions", x: -19, y: -25 },
# { id: 10000000003, label: `rawr
# €	R: 100`, group: "scheduled_actions", x: 31, y: -213 },
# { id: 10000000004, label: `hunt >:D
# €	R: 0`, group: "scheduled_actions", x: 81, y: 29 },
# { id: 10000000005, label: `rawr
# €	R: 0`, group: "actions", x: 331, y: -22 },
# { id: 10000000006, label: `hunt >:D
# €	R: 0`, group: "scheduled_actions", x: 75, y: 134 },
# { id: 10000000007, label: `rawr
# €	R: 0`, group: "actions", x: 288, y: 323 },
# ]);
#     var edges_local = new vis.DataSet([{ from: 0, to: 10000000000, color: "#ff0000" },
# { from: 10000000000, to: 0, label: "1/2", color: "#ff0000" },
# { from: 10000000000, to: 1, label: "3/10", color: "#ff0000" },
# { from: 10000000000, to: 2, label: "1/5", color: "#ff0000" },
# { from: 0, to: 10000000001 },
# { from: 10000000001, to: 0, label: "9/10" },
# { from: 10000000001, to: 2, label: "1/10" },
# { from: 1, to: 10000000002 },
# { from: 10000000002, to: 0, label: "1/2" },
# { from: 10000000002, to: 1, label: "1/2" },
# { from: 1, to: 10000000003, color: "#ff0000" },
# { from: 10000000003, to: 1, label: "9/10", color: "#ff0000" },
# { from: 10000000003, to: 0, label: "1/10", color: "#ff0000" },
# { from: 2, to: 10000000004, color: "#ff0000" },
# { from: 10000000004, to: 1, label: "1/5", color: "#ff0000" },
# { from: 10000000004, to: 0, label: "1/2", color: "#ff0000" },
# { from: 10000000004, to: 2, label: "1/10", color: "#ff0000" },
# { from: 10000000004, to: 3, label: "1/5", color: "#ff0000" },
# { from: 2, to: 10000000005 },
# { from: 10000000005, to: 2, label: "9/10" },
# { from: 10000000005, to: 3, label: "1/10" },
# { from: 3, to: 10000000006, color: "#ff0000" },
# { from: 10000000006, to: 1, label: "1/10", color: "#ff0000" },
# { from: 10000000006, to: 0, label: "1/2", color: "#ff0000" },
# { from: 10000000006, to: 2, label: "1/5", color: "#ff0000" },
# { from: 10000000006, to: 4, label: "1/5", color: "#ff0000" },
# { from: 3, to: 10000000007 },
# { from: 10000000007, to: 3, label: "9/10" },
# { from: 10000000007, to: 4, label: "1/10" },
# { from: 4, to: 4, label: "1" },
# ]);
#     var options_local = {
#   "__fake_macros": {
#     "__group_macro": {
#       "borderWidth": 1,
#       "color": {
#         "background": "white",
#         "border": "black",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "ellipse",
#       "mass": 1,
#       "font": {
#         "color": "black",
#         "size": 14
#       }
#     }
#   },
#   "edit_groups": {
#     "groups": [
#       "states",
#       "actions",
#       "scheduled_actions"
#     ]
#   },
#   "groups": {
#     "actions": {
#       "borderWidth": 1,
#       "color": {
#         "background": "lightblue",
#         "border": "black",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "box",
#       "mass": 1,
#       "font": {
#         "color": "black",
#         "size": 14
#       }
#     },
#     "scheduled_actions": {
#       "borderWidth": 1,
#       "color": {
#         "background": "pink",
#         "border": "#ff0000",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "box",
#       "mass": 1,
#       "font": {
#         "color": "black",
#         "size": 14
#       },
#       "schedColor": false
#     },
#     "states": {
#       "borderWidth": 1,
#       "color": {
#         "background": "#f5c211",
#         "border": "#c64600",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "ellipse",
#       "mass": 5,
#       "font": {
#         "color": "black",
#         "size": 14
#       }
#     },
#     "dead...": {
#       "borderWidth": 1,
#       "color": {
#         "background": "#c0bfbc",
#         "border": "black",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "ellipse",
#       "mass": 1,
#       "font": {
#         "color": "black",
#         "size": 14
#       }
#     },
#     "hunt_>:D": {
#       "borderWidth": 1,
#       "color": {
#         "background": "#2ec27e",
#         "border": "black",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "ellipse",
#       "mass": 1,
#       "font": {
#         "color": "black",
#         "size": 14
#       }
#     },
#     "desparate_hunt!": {
#       "borderWidth": 1,
#       "color": {
#         "background": "#ff7800",
#         "border": "black",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "ellipse",
#       "mass": 1,
#       "font": {
#         "color": "black",
#         "size": 14
#       }
#     },
#     "starving_:((": {
#       "borderWidth": 1,
#       "color": {
#         "background": "white",
#         "border": "black",
#         "highlight": {
#           "background": "white",
#           "border": "red"

# %% [markdown]
# Do you remember our Monty Hall model?

# %%
from stormvogel.examples.monty_hall import create_monty_hall_mdp
mdp = create_monty_hall_mdp()
vis = show(mdp, layout=Layout("layouts/monty2.json"))
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <title>Network</title>
#     <script
#       type="text/javascript"
#       src="https://unpkg.com/vis-network/standalone/umd/vis-network.min.js"
#     ></script>
#     <style type="text/css">
#       #modelUosnUZmtUh {
#         width: 929px;
#         height: 745px;
#         border: 1px solid lightgray;
#       }
#     </style>
#   </head>
#   <body>
#     <div id="modelUosnUZmtUh"></div>
#     <script type="text/javascript">
#         //js
# class NetworkWrapper {
#   constructor(nodes, edges, options, container) {
#     this.nodes = nodes;
#     this.edges = edges;
#     this.options = options;
#     this.container = container;
#     this.data = {
#       nodes: nodes,
#       edges: edges,
#     };
#     this.network = new vis.Network(container, this.data, options);
#     var this_ = this; // Events will not work if you use 'this' directly :))))) No idea why.
#
#     // Set user-triggered events.
#     this.network.on( 'click', function(properties) {
#       var nodeId = this_.network.getNodeAt({x:properties.event.srcEvent.offsetX, y:properties.event.srcEvent.offsetY});
#       this_.makeNeighborsVisible(nodeId);
#     });
#     this.network.on( 'doubleClick', function(properties) {
#         this_.network.setData(this_.data);
#     });
#   }
#
#   setNodeColor(id, color) {
#     var node = this.nodes.get(id);
#     node["color"] = color
#     this.nodes.update(node);
#   }
#
#   makeNeighborsVisible(homeId) {
#     if (homeId === undefined) {
#       return;
#     }
#     var homeNode = this.nodes.get(homeId);
#
#     // Make outgoing nodes visible
#     var nodeIds = this.network.getConnectedNodes(homeId, "to");
#     for (let i = 0; i < nodeIds.length; i++) {
#       var toNodeId = nodeIds[i];
#       var toNode = this.nodes.get(toNodeId);
#       if (toNode["hidden"]) {
#         toNode["hidden"] = false;
#         toNode["physics"] = true;
#         toNode["x"] = this.network.getPosition(homeId)["x"];
#         toNode["y"] = this.network.getPosition(homeId)["y"];
#         this.nodes.update(toNode);
#       }
#     }
#     // Make edges visible, if both of the nodes are also visible
#     var edgeIds = this.network.getConnectedEdges(homeId);
#     for (let i = 0; i < edgeIds.length; i++) {
#       var edgeId = edgeIds[i];
#       var edge = this.edges.get(edgeId);
#       var fromNode = this.nodes.get(edge.from);
#       var toNode = this.nodes.get(edge.to);
#       if ((! fromNode["hidden"]) && (! toNode["hidden"])) {
#         edge["hidden"] = false;
#         edge["physics"] = true;
#         this.edges.update(edge);
#       }
#     }
#   }
# };
#
#     </script>
#     <script type="text/javascript">
#         //js
#     var nodes_local = new vis.DataSet([{ id: 0, label: `init`, group: "states", x: 13, y: -7 },
# { id: 1, label: `carchosen`, group: "states", x: -162, y: 44 },
# { id: 2, label: `carchosen`, group: "states", x: 153, y: 116 },
# { id: 3, label: `carchosen`, group: "states", x: 62, y: -189 },
# { id: 4, label: `open`, group: "states", x: -500, y: 175 },
# { id: 5, label: `open`, group: "states", x: -416, y: -150 },
# { id: 6, label: `open`, group: "states", x: -176, y: 322 },
# { id: 7, label: `open`, group: "states", x: 347, y: 369 },
# { id: 8, label: `open`, group: "states", x: 511, y: 88 },
# { id: 9, label: `open`, group: "states", x: 77, y: 413 },
# { id: 10, label: `open`, group: "states", x: 342, y: -310 },
# { id: 11, label: `open`, group: "states", x: 173, y: -510 },
# { id: 12, label: `open`, group: "states", x: -120, y: -474 },
# { id: 13, label: `goatrevealed`, group: "states", x: -587, y: 325 },
# { id: 14, label: `goatrevealed`, group: "states", x: -653, y: 99 },
# { id: 15, label: `goatrevealed`, group: "states", x: -547, y: -255 },
# { id: 16, label: `goatrevealed`, group: "states", x: -234, y: 463 },
# { id: 17, label: `goatrevealed`, group: "states", x: 446, y: 496 },
# { id: 18, label: `goatrevealed`, group: "states", x: 592, y: -52 },
# { id: 19, label: `goatrevealed`, group: "states", x: 673, y: 159 },
# { id: 20, label: `goatrevealed`, group: "states", x: 83, y: 576 },
# { id: 21, label: `goatrevealed`, group: "states", x: 476, y: -407 },
# { id: 22, label: `goatrevealed`, group: "states", x: 228, y: -670 },
# { id: 23, label: `goatrevealed`, group: "states", x: -265, y: -433 },
# { id: 24, label: `goatrevealed`, group: "states", x: -146, y: -650 },
# { id: 25, label: `done,target`, group: "states", x: -647, y: 606 },
# { id: 26, label: `done,lost`, group: "states", x: -859, y: 431 },
# { id: 27, label: `done,target`, group: "states", x: -941, y: 146 },
# { id: 28, label: `done,lost`, group: "states", x: -856, y: -91 },
# { id: 29, label: `done,lost`, group: "states", x: -669, y: -514 },
# { id: 30, label: `done,target`, group: "states", x: -826, y: -327 },
# { id: 31, label: `done,lost`, group: "states", x: -432, y: 648 },
# { id: 32, label: `done,target`, group: "states", x: -242, y: 743 },
# { id: 33, label: `done,lost`, group: "states", x: 709, y: 595 },
# { id: 34, label: `done,target`, group: "states", x: 473, y: 779 },
# { id: 35, label: `done,target`, group: "states", x: 842, y: -208 },
# { id: 36, label: `done,lost`, group: "states", x: 345, y: -100 },
# { id: 37, label: `done,target`, group: "states", x: 875, y: 357 },
# { id: 38, label: `done,lost`, group: "states", x: 949, y: 59 },
# { id: 39, label: `done,lost`, group: "states", x: 214, y: 826 },
# { id: 40, label: `done,target`, group: "states", x: -38, y: 836 },
# { id: 41, label: `done,lost`, group: "states", x: 602, y: -658 },
# { id: 42, label: `done,target`, group: "states", x: 755, y: -462 },
# { id: 43, label: `done,lost`, group: "states", x: 184, y: -954 },
# { id: 44, label: `done,target`, group: "states", x: 446, y: -860 },
# { id: 45, label: `done,target`, group: "states", x: -474, y: -630 },
# { id: 46, label: `done,lost`, group: "states", x: -169, y: -181 },
# { id: 47, label: `done,target`, group: "states", x: -341, y: -870 },
# { id: 48, label: `done,lost`, group: "states", x: -73, y: -922 },
# { id: 10000000000, label: `open0`, group: "actions", x: -329, y: 115 },
# { id: 10000000001, label: `open1`, group: "actions", x: -282, y: -60 },
# { id: 10000000002, label: `open2`, group: "actions", x: -134, y: 184 },
# { id: 10000000003, label: `open0`, group: "actions", x: 250, y: 245 },
# { id: 10000000004, label: `open1`, group: "actions", x: 328, y: 92 },
# { id: 10000000005, label: `open2`, group: "actions", x: 83, y: 255 },
# { id: 10000000006, label: `open0`, group: "actions", x: 213, y: -217 },
# { id: 10000000007, label: `open1`, group: "actions", x: 120, y: -352 },
# { id: 10000000008, label: `open2`, group: "actions", x: -39, y: -321 },
# { id: 10000000009, label: `stay`, group: "actions", x: -597, y: 477 },
# { id: 10000000010, label: `switch`, group: "actions", x: -735, y: 371 },
# { id: 10000000011, label: `stay`, group: "actions", x: -803, y: 137 },
# { id: 10000000012, label: `switch`, group: "actions", x: -738, y: -22 },
# { id: 10000000013, label: `stay`, group: "actions", x: -592, y: -399 },
# { id: 10000000014, label: `switch`, group: "actions", x: -698, y: -273 },
# { id: 10000000015, label: `stay`, group: "actions", x: -359, y: 533 },
# { id: 10000000016, label: `switch`, group: "actions", x: -211, y: 609 },
# { id: 10000000017, label: `stay`, group: "actions", x: 590, y: 528 },
# { id: 10000000018, label: `switch`, group: "actions", x: 443, y: 645 },
# { id: 10000000019, label: `stay`, group: "actions", x: 725, y: -133 },
# { id: 10000000020, label: `switch`, group: "actions", x: 473, y: -119 },
# { id: 10000000021, label: `stay`, group: "actions", x: 762, y: 280 },
# { id: 10000000022, label: `switch`, group: "actions", x: 817, y: 102 },
# { id: 10000000023, label: `stay`, group: "actions", x: 174, y: 695 },
# { id: 10000000024, label: `switch`, group: "actions", x: 3, y: 704 },
# { id: 10000000025, label: `stay`, group: "actions", x: 519, y: -549 },
# { id: 10000000026, label: `switch`, group: "actions", x: 627, y: -413 },
# { id: 10000000027, label: `stay`, group: "actions", x: 187, y: -816 },
# { id: 10000000028, label: `switch`, group: "actions", x: 354, y: -757 },
# { id: 10000000029, label: `stay`, group: "actions", x: -381, y: -529 },
# { id: 10000000030, label: `sw

# %% [markdown]
# Model checking requires a PRISM property string. In this string, it is specified what property of the model should be used for model checking. In this example, we want a property that maximizes our winning chances.<br>
# We provide a *property builder* to make it easy to construct PRISM property strings.

# %%
from stormvogel.property_builder import build_property_string
build_property_string(mdp)
# Out:
# Output()
# Output()

# %%
from stormvogel.model_checking import model_checking
result = model_checking(mdp,'Pmax=? [F "target"]')

# %%
vis = show(mdp, result=result, layout=Layout("layouts/monty2.json"))
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <title>Network</title>
#     <script
#       type="text/javascript"
#       src="https://unpkg.com/vis-network/standalone/umd/vis-network.min.js"
#     ></script>
#     <style type="text/css">
#       #modelCfclfSdbdg {
#         width: 929px;
#         height: 745px;
#         border: 1px solid lightgray;
#       }
#     </style>
#   </head>
#   <body>
#     <div id="modelCfclfSdbdg"></div>
#     <script type="text/javascript">
#         //js
# class NetworkWrapper {
#   constructor(nodes, edges, options, container) {
#     this.nodes = nodes;
#     this.edges = edges;
#     this.options = options;
#     this.container = container;
#     this.data = {
#       nodes: nodes,
#       edges: edges,
#     };
#     this.network = new vis.Network(container, this.data, options);
#     var this_ = this; // Events will not work if you use 'this' directly :))))) No idea why.
#
#     // Set user-triggered events.
#     this.network.on( 'click', function(properties) {
#       var nodeId = this_.network.getNodeAt({x:properties.event.srcEvent.offsetX, y:properties.event.srcEvent.offsetY});
#       this_.makeNeighborsVisible(nodeId);
#     });
#     this.network.on( 'doubleClick', function(properties) {
#         this_.network.setData(this_.data);
#     });
#   }
#
#   setNodeColor(id, color) {
#     var node = this.nodes.get(id);
#     node["color"] = color
#     this.nodes.update(node);
#   }
#
#   makeNeighborsVisible(homeId) {
#     if (homeId === undefined) {
#       return;
#     }
#     var homeNode = this.nodes.get(homeId);
#
#     // Make outgoing nodes visible
#     var nodeIds = this.network.getConnectedNodes(homeId, "to");
#     for (let i = 0; i < nodeIds.length; i++) {
#       var toNodeId = nodeIds[i];
#       var toNode = this.nodes.get(toNodeId);
#       if (toNode["hidden"]) {
#         toNode["hidden"] = false;
#         toNode["physics"] = true;
#         toNode["x"] = this.network.getPosition(homeId)["x"];
#         toNode["y"] = this.network.getPosition(homeId)["y"];
#         this.nodes.update(toNode);
#       }
#     }
#     // Make edges visible, if both of the nodes are also visible
#     var edgeIds = this.network.getConnectedEdges(homeId);
#     for (let i = 0; i < edgeIds.length; i++) {
#       var edgeId = edgeIds[i];
#       var edge = this.edges.get(edgeId);
#       var fromNode = this.nodes.get(edge.from);
#       var toNode = this.nodes.get(edge.to);
#       if ((! fromNode["hidden"]) && (! toNode["hidden"])) {
#         edge["hidden"] = false;
#         edge["physics"] = true;
#         this.edges.update(edge);
#       }
#     }
#   }
# };
#
#     </script>
#     <script type="text/javascript">
#         //js
#     var nodes_local = new vis.DataSet([{ id: 0, label: `init
# ☆ 1`, group: "states", x: 13, y: -7 },
# { id: 1, label: `carchosen
# ☆ 1`, group: "states", x: -162, y: 44 },
# { id: 2, label: `carchosen
# ☆ 1`, group: "states", x: 153, y: 116 },
# { id: 3, label: `carchosen
# ☆ 1`, group: "states", x: 62, y: -189 },
# { id: 4, label: `open
# ☆ 1`, group: "states", x: -500, y: 175 },
# { id: 5, label: `open
# ☆ 1`, group: "states", x: -416, y: -150 },
# { id: 6, label: `open
# ☆ 1`, group: "states", x: -176, y: 322 },
# { id: 7, label: `open
# ☆ 1`, group: "states", x: 347, y: 369 },
# { id: 8, label: `open
# ☆ 1`, group: "states", x: 511, y: 88 },
# { id: 9, label: `open
# ☆ 1`, group: "states", x: 77, y: 413 },
# { id: 10, label: `open
# ☆ 1`, group: "states", x: 342, y: -310 },
# { id: 11, label: `open
# ☆ 1`, group: "states", x: 173, y: -510 },
# { id: 12, label: `open
# ☆ 1`, group: "states", x: -120, y: -474 },
# { id: 13, label: `goatrevealed
# ☆ 1`, group: "states", x: -587, y: 325 },
# { id: 14, label: `goatrevealed
# ☆ 1`, group: "states", x: -653, y: 99 },
# { id: 15, label: `goatrevealed
# ☆ 1`, group: "states", x: -547, y: -255 },
# { id: 16, label: `goatrevealed
# ☆ 1`, group: "states", x: -234, y: 463 },
# { id: 17, label: `goatrevealed
# ☆ 1`, group: "states", x: 446, y: 496 },
# { id: 18, label: `goatrevealed
# ☆ 1`, group: "states", x: 592, y: -52 },
# { id: 19, label: `goatrevealed
# ☆ 1`, group: "states", x: 673, y: 159 },
# { id: 20, label: `goatrevealed
# ☆ 1`, group: "states", x: 83, y: 576 },
# { id: 21, label: `goatrevealed
# ☆ 1`, group: "states", x: 476, y: -407 },
# { id: 22, label: `goatrevealed
# ☆ 1`, group: "states", x: 228, y: -670 },
# { id: 23, label: `goatrevealed
# ☆ 1`, group: "states", x: -265, y: -433 },
# { id: 24, label: `goatrevealed
# ☆ 1`, group: "states", x: -146, y: -650 },
# { id: 25, label: `done,target
# ☆ 1`, group: "states", x: -647, y: 606 },
# { id: 26, label: `done,lost
# ☆ 0`, group: "states", x: -859, y: 431 },
# { id: 27, label: `done,target
# ☆ 1`, group: "states", x: -941, y: 146 },
# { id: 28, label: `done,lost
# ☆ 0`, group: "states", x: -856, y: -91 },
# { id: 29, label: `done,lost
# ☆ 0`, group: "states", x: -669, y: -514 },
# { id: 30, label: `done,target
# ☆ 1`, group: "states", x: -826, y: -327 },
# { id: 31, label: `done,lost
# ☆ 0`, group: "states", x: -432, y: 648 },
# { id: 32, label: `done,target
# ☆ 1`, group: "states", x: -242, y: 743 },
# { id: 33, label: `done,lost
# ☆ 0`, group: "states", x: 709, y: 595 },
# { id: 34, label: `done,target
# ☆ 1`, group: "states", x: 473, y: 779 },
# { id: 35, label: `done,target
# ☆ 1`, group: "states", x: 842, y: -208 },
# { id: 36, label: `done,lost
# ☆ 0`, group: "states", x: 345, y: -100 },
# { id: 37, label: `done,target
# ☆ 1`, group: "states", x: 875, y: 357 },
# { id: 38, label: `done,lost
# ☆ 0`, group: "states", x: 949, y: 59 },
# { id: 39, label: `done,lost
# ☆ 0`, group: "states", x: 214, y: 826 },
# { id: 40, label: `done,target
# ☆ 1`, group: "states", x: -38, y: 836 },
# { id: 41, label: `done,lost
# ☆ 0`, group: "states", x: 602, y: -658 },
# { id: 42, label: `done,target
# ☆ 1`, group: "states", x: 755, y: -462 },
# { id: 43, label: `done,lost
# ☆ 0`, group: "states", x: 184, y: -954 },
# { id: 44, label: `done,target
# ☆ 1`, group: "states", x: 446, y: -860 },
# { id: 45, label: `done,target
# ☆ 1`, group: "states", x: -474, y: -630 },
# { id: 46, label: `done,lost
# ☆ 0`, group: "states", x: -169, y: -181 },
# { id: 47, label: `done,target
# ☆ 1`, group: "states", x: -341, y: -870 },
# { id: 48, label: `done,lost
# ☆ 0`, group: "states", x: -73, y: -922 },
# { id: 10000000000, label: `open0`, group: "actions", x: -329, y: 115 },
# { id: 10000000001, label: `open1`, group: "actions", x: -282, y: -60 },
# { id: 10000000002, label: `open2`, group: "scheduled_actions", x: -134, y: 184 },
# { id: 10000000003, label: `open0`, group: "actions", x: 250, y: 245 },
# { id: 10000000004, label: `open1`, group: "actions", x: 328, y: 92 },
# { id: 10000000005, label: `open2`, group: "scheduled_actions", x: 83, y: 255 },
# { id: 10000000006, label: `open0`, group: "actions", x: 213, y: -217 },
# { id: 10000000007, label: `open1`, group: "actions", x: 120, y: -352 },
# { id: 10000000008, label: `open2`, group: "scheduled_actions", x: -39, y: -321 },
# { id: 10000000009, label: `stay`, group: "scheduled_actions", x: -597, y: 477 },
# { id: 10000000010, label: `switch`, group: "actions", x: -735, y: 371 },
# { id: 10000000011, label: `stay`, group: "scheduled_actions", x: -803, y: 137 },
# { id: 10000000012, label: `switch`, group: "actions", x: -738, y: -22 },
# { id: 10000000013, label: `stay`, group: "actions", x: -592, y: -399 },
# { id: 10000000014, label: `switch`, group: "scheduled_actions", x: -698, y: -273 },
# { id: 10000000015, label: `stay`, group: "actions", x: -359, y: 533 },
# { id: 10000000016, label: `switch`, group: "scheduled_actions", x: -211, y: 609 },
# { id: 10000000017, label: `stay`, group: "actions", x: 590, y: 528 },
# { id: 10000000018, label: `switch`, group: "scheduled_actions", x: 443, y: 645 },
# { id: 10000000019, label: `stay`, group: "scheduled_actions", x: 725, y: -133 },
# { id: 10000000020, label: `switch`, group: "actions", x: 473, y: -119 },
# { id: 10000000021, label: `stay`, group: "scheduled_actions", x: 762, y: 280 },
# { id: 10000000022, label: `switch`, group: "actions", x: 817, y: 102 },
# { id: 10000000023, label: `stay`, group: "actions", x: 174, y: 695 },
# { id: 10000000024, label: `switch`, group: "scheduled_actions", x: 3, y: 704 },
# { id: 10000000025, label: `stay`, group: "actions", x: 519, y: -549 },
# { id: 100000

# %% [markdown]
# Now, the resulting scheduler chooses to stay when the car is already behind the door, and to switch when it is not, therefore it always wins... The agent always knows where the car is the whole time! This is because we used an MDP to model Monty Hall, and in an MDP, the agent always knows the current state. (See the notebook on POMPs for a simpler example.) Unfortunately, we cannot do model checking on POMDPs. A way to work around this in this example is to give states a label 'should stay' or 'should switch', and then calculate the probablity that you reach such a state.
#
# Now stormpy calculates the probablity that we reach a state where we should switch. It turns out to be 2/3rd (see inital state, ☆). Confirm that this still works if you choose another favorite door.
#
# Note that we are cheating a little bit here. You need to choose a door yourself, and then it is already calculated whether you should switch. In order to solve this properly you would need model checking on POMPs.

# %%
from stormvogel.examples.monty_hall_should import create_monty_hall_mdp
favorite_door = 2 # 0, 1, or 2
new_mdp = create_monty_hall_mdp()
result = model_checking(new_mdp,f'Pmax=? [((("init" | "carchosen" | "o_{favorite_door}") U "should_switch"))]')
vis = show(new_mdp, layout=Layout("layouts/monty2.json"), result=result)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <title>Network</title>
#     <script
#       type="text/javascript"
#       src="https://unpkg.com/vis-network/standalone/umd/vis-network.min.js"
#     ></script>
#     <style type="text/css">
#       #modelQaGiuKAlPn {
#         width: 929px;
#         height: 745px;
#         border: 1px solid lightgray;
#       }
#     </style>
#   </head>
#   <body>
#     <div id="modelQaGiuKAlPn"></div>
#     <script type="text/javascript">
#         //js
# class NetworkWrapper {
#   constructor(nodes, edges, options, container) {
#     this.nodes = nodes;
#     this.edges = edges;
#     this.options = options;
#     this.container = container;
#     this.data = {
#       nodes: nodes,
#       edges: edges,
#     };
#     this.network = new vis.Network(container, this.data, options);
#     var this_ = this; // Events will not work if you use 'this' directly :))))) No idea why.
#
#     // Set user-triggered events.
#     this.network.on( 'click', function(properties) {
#       var nodeId = this_.network.getNodeAt({x:properties.event.srcEvent.offsetX, y:properties.event.srcEvent.offsetY});
#       this_.makeNeighborsVisible(nodeId);
#     });
#     this.network.on( 'doubleClick', function(properties) {
#         this_.network.setData(this_.data);
#     });
#   }
#
#   setNodeColor(id, color) {
#     var node = this.nodes.get(id);
#     node["color"] = color
#     this.nodes.update(node);
#   }
#
#   makeNeighborsVisible(homeId) {
#     if (homeId === undefined) {
#       return;
#     }
#     var homeNode = this.nodes.get(homeId);
#
#     // Make outgoing nodes visible
#     var nodeIds = this.network.getConnectedNodes(homeId, "to");
#     for (let i = 0; i < nodeIds.length; i++) {
#       var toNodeId = nodeIds[i];
#       var toNode = this.nodes.get(toNodeId);
#       if (toNode["hidden"]) {
#         toNode["hidden"] = false;
#         toNode["physics"] = true;
#         toNode["x"] = this.network.getPosition(homeId)["x"];
#         toNode["y"] = this.network.getPosition(homeId)["y"];
#         this.nodes.update(toNode);
#       }
#     }
#     // Make edges visible, if both of the nodes are also visible
#     var edgeIds = this.network.getConnectedEdges(homeId);
#     for (let i = 0; i < edgeIds.length; i++) {
#       var edgeId = edgeIds[i];
#       var edge = this.edges.get(edgeId);
#       var fromNode = this.nodes.get(edge.from);
#       var toNode = this.nodes.get(edge.to);
#       if ((! fromNode["hidden"]) && (! toNode["hidden"])) {
#         edge["hidden"] = false;
#         edge["physics"] = true;
#         this.edges.update(edge);
#       }
#     }
#   }
# };
#
#     </script>
#     <script type="text/javascript">
#         //js
#     var nodes_local = new vis.DataSet([{ id: 0, label: `init
# ☆ 2/3`, group: "states", x: 13, y: -7 },
# { id: 1, label: `carchosen
# ☆ 1`, group: "states", x: -162, y: 44 },
# { id: 2, label: `carchosen
# ☆ 1`, group: "states", x: 153, y: 116 },
# { id: 3, label: `carchosen
# ☆ 0`, group: "states", x: 62, y: -189 },
# { id: 4, label: `open,o_0
# ☆ 0`, group: "states", x: -500, y: 175 },
# { id: 5, label: `open,o_1
# ☆ 0`, group: "states", x: -416, y: -150 },
# { id: 6, label: `open,o_2
# ☆ 1`, group: "states", x: -176, y: 322 },
# { id: 7, label: `open,o_0
# ☆ 0`, group: "states", x: 347, y: 369 },
# { id: 8, label: `open,o_1
# ☆ 0`, group: "states", x: 511, y: 88 },
# { id: 9, label: `open,o_2
# ☆ 1`, group: "states", x: 77, y: 413 },
# { id: 10, label: `open,o_0
# ☆ 0`, group: "states", x: 342, y: -310 },
# { id: 11, label: `open,o_1
# ☆ 0`, group: "states", x: 173, y: -510 },
# { id: 12, label: `open,o_2
# ☆ 0`, group: "states", x: -120, y: -474 },
# { id: 13, label: `gr,should_stay
# ☆ 0`, group: "states", x: -587, y: 325 },
# { id: 14, label: `gr,should_stay
# ☆ 0`, group: "states", x: -653, y: 99 },
# { id: 15, label: `gr,should_switch
# ☆ 1`, group: "states", x: -547, y: -255 },
# { id: 16, label: `gr,should_switch
# ☆ 1`, group: "states", x: -234, y: 463 },
# { id: 17, label: `gr,should_switch
# ☆ 1`, group: "states", x: 446, y: 496 },
# { id: 18, label: `gr,should_stay
# ☆ 0`, group: "states", x: 592, y: -52 },
# { id: 19, label: `gr,should_stay
# ☆ 0`, group: "states", x: 673, y: 159 },
# { id: 20, label: `gr,should_switch
# ☆ 1`, group: "states", x: 83, y: 576 },
# { id: 21, label: `gr,should_switch
# ☆ 1`, group: "states", x: 476, y: -407 },
# { id: 22, label: `gr,should_switch
# ☆ 1`, group: "states", x: 228, y: -670 },
# { id: 23, label: `gr,should_stay
# ☆ 0`, group: "states", x: -265, y: -433 },
# { id: 24, label: `gr,should_stay
# ☆ 0`, group: "states", x: -146, y: -650 },
# { id: 25, label: `done,target
# ☆ 0`, group: "states", x: -647, y: 606 },
# { id: 26, label: `done,lost
# ☆ 0`, group: "states", x: -859, y: 431 },
# { id: 27, label: `done,target
# ☆ 0`, group: "states", x: -941, y: 146 },
# { id: 28, label: `done,lost
# ☆ 0`, group: "states", x: -856, y: -91 },
# { id: 29, label: `done,lost
# ☆ 0`, group: "states", x: -669, y: -514 },
# { id: 30, label: `done,target
# ☆ 0`, group: "states", x: -826, y: -327 },
# { id: 31, label: `done,lost
# ☆ 0`, group: "states", x: -432, y: 648 },
# { id: 32, label: `done,target
# ☆ 0`, group: "states", x: -242, y: 743 },
# { id: 33, label: `done,lost
# ☆ 0`, group: "states", x: 709, y: 595 },
# { id: 34, label: `done,target
# ☆ 0`, group: "states", x: 473, y: 779 },
# { id: 35, label: `done,target
# ☆ 0`, group: "states", x: 842, y: -208 },
# { id: 36, label: `done,lost
# ☆ 0`, group: "states", x: 345, y: -100 },
# { id: 37, label: `done,target
# ☆ 0`, group: "states", x: 875, y: 357 },
# { id: 38, label: `done,lost
# ☆ 0`, group: "states", x: 949, y: 59 },
# { id: 39, label: `done,lost
# ☆ 0`, group: "states", x: 214, y: 826 },
# { id: 40, label: `done,target
# ☆ 0`, group: "states", x: -38, y: 836 },
# { id: 41, label: `done,lost
# ☆ 0`, group: "states", x: 602, y: -658 },
# { id: 42, label: `done,target
# ☆ 0`, group: "states", x: 755, y: -462 },
# { id: 43, label: `done,lost
# ☆ 0`, group: "states", x: 184, y: -954 },
# { id: 44, label: `done,target
# ☆ 0`, group: "states", x: 446, y: -860 },
# { id: 45, label: `done,target
# ☆ 0`, group: "states", x: -474, y: -630 },
# { id: 46, label: `done,lost
# ☆ 0`, group: "states", x: -169, y: -181 },
# { id: 47, label: `done,target
# ☆ 0`, group: "states", x: -341, y: -870 },
# { id: 48, label: `done,lost
# ☆ 0`, group: "states", x: -73, y: -922 },
# { id: 10000000000, label: `open0`, group: "actions", x: -329, y: 115 },
# { id: 10000000001, label: `open1`, group: "actions", x: -282, y: -60 },
# { id: 10000000002, label: `open2`, group: "scheduled_actions", x: -134, y: 184 },
# { id: 10000000003, label: `open0`, group: "actions", x: 250, y: 245 },
# { id: 10000000004, label: `open1`, group: "actions", x: 328, y: 92 },
# { id: 10000000005, label: `open2`, group: "scheduled_actions", x: 83, y: 255 },
# { id: 10000000006, label: `open0`, group: "scheduled_actions", x: 213, y: -217 },
# { id: 10000000007, label: `open1`, group: "actions", x: 120, y: -352 },
# { id: 10000000008, label: `open2`, group: "actions", x: -39, y: -321 },
# { id: 10000000009, label: `stay`, group: "scheduled_actions", x: -597, y: 477 },
# { id: 10000000010, label: `switch`, group: "actions", x: -735, y: 371 },
# { id: 10000000011, label: `stay`, group: "scheduled_actions", x: -803, y: 137 },
# { id: 10000000012, label: `switch`, group: "actions", x: -738, y: -22 },
# { id: 10000000013, label: `stay`, group: "scheduled_actions", x: -592, y: -399 },
# { id: 10000000014, label: `switch`, group: "actions", x: -698, y: -273 },
# { id: 10000000015, label: `stay`, group: "scheduled_actions", x: -359, y: 533 },
# { id: 10000000016, label: `switch`, group: "actions", x: -211, y: 609 },
# { id: 10000000017, label: `stay`, group: "scheduled_actions", x: 590, y: 528 },
# { id: 10000000018, label: `switch`, group: "actions", x: 443, y: 645 },
# { id: 10000000019, label: `stay`, group: "scheduled_actions", x: 725, y: -133 },
# { id: 10000000020, label: `switch`, group: "actions", x: 473, y: -119 },
# { id: 10000000021, label: `stay`, group: "scheduled_actions", x: 762, y: 280 },
# { id: 10000000022, label: `switch`, group: "actions", x: 817, y: 102 },
# { id: 10000000023, label: `stay`, group: "scheduled_actions", x: 174, y: 695 },
# { id: 10000000024, label: `switch`, group: "actions", x: 3, y: 704 },
# { id: 100
