# %% [markdown]
# # Strompy conversion
# Models can be converted back and forth between stormvogel and stormpy with ease using the `mapping` module.<br>
# This is useful, because this allows you to combine both APIs. For example, you could create a model in stormvogel becuase it has an easy API, do some model checking in stormpy, and then convert it back to display the results. (Note that there is also a direct model checking function available that uses stormpy behind the scenes.)

# %%
import stormvogel.show, stormvogel.examples.car, stormvogel.show
stormvogel_model = stormvogel.examples.car.car
vis = stormvogel.show.show(stormvogel_model, layout=stormvogel.layout.Layout("layouts/car.json"))
# Out:
#           <iframe
#                 id="modelnyNhSKAgOf"
#                 width="675"
#                 height="395"
#                 frameborder="0"
#                 srcdoc="
# &lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#   &lt;head&gt;
#     &lt;title&gt;Network&lt;/title&gt;
#     &lt;script
#       type=&quot;text/javascript&quot;
#       src=&quot;https://unpkg.com/vis-network/standalone/umd/vis-network.min.js&quot;
#     &gt;&lt;/script&gt;
#     &lt;style type=&quot;text/css&quot;&gt;
#       #mynetwork {
#
#         width: 655px;
#         height: 375px;
#         border: 1px solid lightgray;
#
#       }
#     &lt;/style&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;mynetwork&quot;&gt;&lt;/div&gt;
#     &lt;script type=&quot;text/javascript&quot;&gt;
#
#         var nodes = new vis.DataSet([{ id: 0, label: `init,green light,still`, group: &quot;green_light&quot;, x: 194, y: -96 },
# { id: 1, label: `red light,still`, group: &quot;red_light&quot;, x: -51, y: -142 },
# { id: 2, label: `green light,moving`, group: &quot;green_light&quot;, x: 186, y: 153 },
# { id: 3, label: `red light,moving`, group: &quot;red_light&quot;, x: -108, y: 98 },
# { id: 4, label: `accident`, group: &quot;states&quot;, x: -367, y: 177 },
# { id: 10000000000, label: `accelerate`, group: &quot;actions&quot;, x: 144, y: 35 },
# { id: 10000000001, label: `wait`, group: &quot;actions&quot;, x: 68, y: -99 },
# { id: 10000000002, label: `accelerate`, group: &quot;actions&quot;, x: -158, y: -50 },
# { id: 10000000003, label: `wait`, group: &quot;actions&quot;, x: 87, y: -212 },
# { id: 10000000004, label: `brake`, group: &quot;actions&quot;, x: 275, y: 33 },
# { id: 10000000005, label: `wait`, group: &quot;actions&quot;, x: 33, y: 176 },
# { id: 10000000006, label: `brake`, group: &quot;actions&quot;, x: -25, y: -3 },
# { id: 10000000007, label: `wait`, group: &quot;actions&quot;, x: -238, y: 163 },
# ]);
#         var edges = new vis.DataSet([{ from: 0, to: 10000000000 },
# { from: 10000000000, to: 2, label: &quot;1&quot; },
# { from: 0, to: 10000000001 },
# { from: 10000000001, to: 1, label: &quot;1&quot; },
# { from: 1, to: 10000000002 },
# { from: 10000000002, to: 3, label: &quot;1&quot; },
# { from: 1, to: 10000000003 },
# { from: 10000000003, to: 0, label: &quot;1&quot; },
# { from: 2, to: 10000000004 },
# { from: 10000000004, to: 0, label: &quot;1&quot; },
# { from: 2, to: 10000000005 },
# { from: 10000000005, to: 3, label: &quot;1&quot; },
# { from: 3, to: 10000000006 },
# { from: 10000000006, to: 1, label: &quot;1&quot; },
# { from: 3, to: 10000000007 },
# { from: 10000000007, to: 4, label: &quot;1&quot; },
# { from: 4, to: 4, label: &quot;1&quot; },
# ]);
#         var options = {
#   &quot;__fake_macros&quot;: {
#     &quot;__group_macro&quot;: {
#       &quot;borderWidth&quot;: 1,
#       &quot;color&quot;: {
#         &quot;background&quot;: &quot;white&quot;,
#         &quot;border&quot;: &quot;black&quot;,
#         &quot;highlight&quot;: {
#           &quot;background&quot;: &quot;white&quot;,
#           &quot;border&quot;: &quot;red&quot;
#         }
#       },
#       &quot;shape&quot;: &quot;ellipse&quot;,
#       &quot;mass&quot;: 1,
#       &quot;font&quot;: {
#         &quot;color&quot;: &quot;black&quot;,
#         &quot;size&quot;: 14
#       }
#     }
#   },
#   &quot;edit_groups&quot;: {
#     &quot;groups&quot;: [
#       &quot;green_light&quot;,
#       &quot;red_light&quot;,
#       &quot;states&quot;,
#       &quot;actions&quot;
#     ]
#   },
#   &quot;groups&quot;: {
#     &quot;actions&quot;: {
#       &quot;borderWidth&quot;: 1,
#       &quot;color&quot;: {
#         &quot;background&quot;: &quot;lightblue&quot;,
#         &quot;border&quot;: &quot;black&quot;,
#         &quot;highlight&quot;: {
#           &quot;background&quot;: &quot;white&quot;,
#           &quot;border&quot;: &quot;red&quot;
#         }
#       },
#       &quot;shape&quot;: &quot;box&quot;,
#       &quot;mass&quot;: 1,
#       &quot;font&quot;: {
#         &quot;color&quot;: &quot;black&quot;,
#         &quot;size&quot;: 20
#       }
#     },
#     &quot;scheduled_actions&quot;: {
#       &quot;shape&quot;: &quot;box&quot;,
#       &quot;color&quot;: {
#         &quot;background&quot;: &quot;pink&quot;,
#         &quot;border&quot;: &quot;black&quot;,
#         &quot;highlight&quot;: {
#           &quot;background&quot;: &quot;white&quot;,
#           &quot;border&quot;: &quot;red&quot;
#         }
#       },
#       &quot;borderWidth&quot;: 1,
#       &quot;mass&quot;: 1,
#       &quot;font&quot;: {
#         &quot;color&quot;: &quot;black&quot;,
#         &quot;size&quot;: 14
#       },
#       &quot;schedColor&quot;: false
#     },
#     &quot;states&quot;: {
#       &quot;borderWidth&quot;: 1,
#       &quot;color&quot;: {
#         &quot;background&quot;: &quot;#000000&quot;,
#         &quot;border&quot;: &quot;black&quot;,
#         &quot;highlight&quot;: {
#           &quot;background&quot;: &quot;white&quot;,
#           &quot;border&quot;: &quot;red&quot;
#         }
#       },
#       &quot;shape&quot;: &quot;ellipse&quot;,
#       &quot;mass&quot;: 1,
#       &quot;font&quot;: {
#         &quot;color&quot;: &quot;#ffffff&quot;,
#         &quot;size&quot;: 20
#       }
#     },
#     &quot;red_light&quot;: {
#       &quot;borderWidth&quot;: 1,
#       &quot;color&quot;: {
#         &quot;background&quot;: &quot;#ec9393&quot;,
#         &quot;border&quot;: &quot;black&quot;,
#         &quot;highlight&quot;: {
#           &quot;background&quot;: &quot;white&quot;,
#           &quot;border&quot;: &quot;red&quot;
#         }
#       },
#       &quot;shape&quot;: &quot;ellipse&quot;,
#       &quot;mass&quot;: 1,
#       &quot;font&quot;: {
#         &quot;color&quot;: &quot;black&quot;,
#         &quot;size&quot;: 20
#       }
#     },
#     &quot;green_light&quot;: {
#       &quot;borderWidth&quot;: 1,
#       &quot;color&quot;: {
#         &quot;background&quot;: &quot;#bcfe58&quot;,
#         &quot;border&quot;: &quot;black&quot;,
#         &quot;highlight&quot;: {
#           &quot;background&quot;: &quot;white&quot;,
#           &quot;border&quot;: &quot;red&quot;
#         }
#       },
#       &quot;shape&quot;: &quot;ellipse&quot;,
#       &quot;mass&quot;: 1,
#       &quot;font&quot;: {
#         &quot;color&quot;: &quot;black&quot;,
#         &quot;size&quot;: 20
#       }
#     },
#     &quot;init&quot;: {
#       &quot;borderWidth&quot;: 1,
#       &quot;color&quot;: {
#         &quot;background&quot;: &quot;#bcfe58&quot;,
#         &quot;border&quot;: &quot;black&quot;,
#         &quot;highlight&quot;: {
#           &quot;background&quot;: &quot;white&quot;,
#           &quot;border&quot;: &quot;red&quot;
#         }
#       },
#       &quot;shape&quot;: &quot;ellipse&quot;,
#       &quot;mass&quot;: 1,
#       &quot;font&quot;: {
#         &quot;color&quot;: &quot;black&quot;,
#         &quot;size&quot;: 20
#       }
#     }
#   },
#   &quot;reload_button&quot;: false,
#   &quot;edges&quot;: {
#     &quot;arrows&quot;: &quot;to&quot;,
#     &quot;font&quot;: {
#       &quot;color&quot;: &quot;black&quot;,
#       &quot;size&quot;: 14
#     },
#     &quot;color&quot;: {
#       &quot;color&quot;: &quot;black&quot;
#     }
#   },
#   &quot;numbers&quot;: {
#     &quot;fractions&quot;: true,
#     &quot;digits&quot;: 5
#   },
#   &quot;state_properties&quot;: {
#     &quot;show_results&quot;: true,
#     &quot;result_symbol&quot;: &quot;\u2606&quot;,
#     &quot;show_rewards&quot;: true,
#     &quot;reward_symbol&quot;: &quot;\u20ac&quot;,
#     &quot;show_zero_rewards&quot;: true,
#     &quot;show_observations&quot;: true,
#     &quot;observation_symbol&quot;: &quot;\u0298&quot;
#   },
#   &quot;layout&quot;: {
#     &quot;randomSeed&quot;: 5
#   },
#   &quot;misc&quot;: {
#     &quot;enable_physics&quot;: true,
#     &quot;width&quot;: 655,
#     &quot;height&quot;: 375,
#     &quot;explore&quot;: false
#   },
#   &quot;saving&quot;: {
#     &quot;relative_path&quot;: true,
#     &quot;filename&quot;: &quot;layouts/car.json&quot;,
#     &quot;save_button&quot;: false,
#     &quot;load_button&quot;: false
#   },
#   &quot;positions&quot;: {
#     &quot;0&quot;: {
#       &quot;x&quot;: 194,
#       &quot;y&quot;: -96
#     },
#     &quot;1&quot;: {
#       &quot;x&quot;: -51,
#       &quot;y&quot;: -142
#     },
#     &quot;2&quot;: {
#       &quot;x&quot;: 186,

# %% [markdown]
# First, let's convert the stormvogel model to the same model in stormpy.

# %%
import stormvogel.mapping

stormpy_model = stormvogel.mapping.stormvogel_to_stormpy(stormvogel_model)
print(stormpy_model)
# Out:
# --------------------------------------------------------------
# Model type: 	MDP (sparse)
# States: 	5
# Transitions: 	9
# Choices: 	9
# Reward Models:  none
# State Labels: 	6 labels
#    * red light -> 2 item(s)
#    * green light -> 2 item(s)
#    * moving -> 2 item(s)
#    * still -> 2 item(s)
#    * init -> 1 item(s)
#    * accident -> 1 item(s)
# Choice Labels: 	3 labels
#    * accelerate -> 2 item(s)
#    * brake -> 2 item(s)
#    * wait -> 4 item(s)
# --------------------------------------------------------------

# %% [markdown]
# And now we convert it back.

# %%
stormvogel_model2 = stormvogel.mapping.stormpy_to_stormvogel(stormpy_model)
vis = stormvogel.show.show(stormvogel_model2, layout=stormvogel.layout.Layout("layouts/car.json"))
# Out:
#           <iframe
#                 id="modeluFxFyNAYPj"
#                 width="675"
#                 height="395"
#                 frameborder="0"
#                 srcdoc="
# &lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#   &lt;head&gt;
#     &lt;title&gt;Network&lt;/title&gt;
#     &lt;script
#       type=&quot;text/javascript&quot;
#       src=&quot;https://unpkg.com/vis-network/standalone/umd/vis-network.min.js&quot;
#     &gt;&lt;/script&gt;
#     &lt;style type=&quot;text/css&quot;&gt;
#       #mynetwork {
#
#         width: 655px;
#         height: 375px;
#         border: 1px solid lightgray;
#
#       }
#     &lt;/style&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;mynetwork&quot;&gt;&lt;/div&gt;
#     &lt;script type=&quot;text/javascript&quot;&gt;
#
#         var nodes = new vis.DataSet([{ id: 0, label: `init,green light,still`, group: &quot;green_light&quot;, x: 194, y: -96 },
# { id: 1, label: `still,red light`, group: &quot;red_light&quot;, x: -51, y: -142 },
# { id: 2, label: `green light,moving`, group: &quot;green_light&quot;, x: 186, y: 153 },
# { id: 3, label: `red light,moving`, group: &quot;red_light&quot;, x: -108, y: 98 },
# { id: 4, label: `accident`, group: &quot;states&quot;, x: -367, y: 177 },
# { id: 10000000000, label: `accelerate`, group: &quot;actions&quot;, x: 144, y: 35 },
# { id: 10000000001, label: `wait`, group: &quot;actions&quot;, x: 68, y: -99 },
# { id: 10000000002, label: `accelerate`, group: &quot;actions&quot;, x: -158, y: -50 },
# { id: 10000000003, label: `wait`, group: &quot;actions&quot;, x: 87, y: -212 },
# { id: 10000000004, label: `brake`, group: &quot;actions&quot;, x: 275, y: 33 },
# { id: 10000000005, label: `wait`, group: &quot;actions&quot;, x: 33, y: 176 },
# { id: 10000000006, label: `brake`, group: &quot;actions&quot;, x: -25, y: -3 },
# { id: 10000000007, label: `wait`, group: &quot;actions&quot;, x: -238, y: 163 },
# ]);
#         var edges = new vis.DataSet([{ from: 0, to: 10000000000 },
# { from: 10000000000, to: 2, label: &quot;1&quot; },
# { from: 0, to: 10000000001 },
# { from: 10000000001, to: 1, label: &quot;1&quot; },
# { from: 1, to: 10000000002 },
# { from: 10000000002, to: 3, label: &quot;1&quot; },
# { from: 1, to: 10000000003 },
# { from: 10000000003, to: 0, label: &quot;1&quot; },
# { from: 2, to: 10000000004 },
# { from: 10000000004, to: 0, label: &quot;1&quot; },
# { from: 2, to: 10000000005 },
# { from: 10000000005, to: 3, label: &quot;1&quot; },
# { from: 3, to: 10000000006 },
# { from: 10000000006, to: 1, label: &quot;1&quot; },
# { from: 3, to: 10000000007 },
# { from: 10000000007, to: 4, label: &quot;1&quot; },
# { from: 4, to: 4, label: &quot;1&quot; },
# ]);
#         var options = {
#   &quot;__fake_macros&quot;: {
#     &quot;__group_macro&quot;: {
#       &quot;borderWidth&quot;: 1,
#       &quot;color&quot;: {
#         &quot;background&quot;: &quot;white&quot;,
#         &quot;border&quot;: &quot;black&quot;,
#         &quot;highlight&quot;: {
#           &quot;background&quot;: &quot;white&quot;,
#           &quot;border&quot;: &quot;red&quot;
#         }
#       },
#       &quot;shape&quot;: &quot;ellipse&quot;,
#       &quot;mass&quot;: 1,
#       &quot;font&quot;: {
#         &quot;color&quot;: &quot;black&quot;,
#         &quot;size&quot;: 14
#       }
#     }
#   },
#   &quot;edit_groups&quot;: {
#     &quot;groups&quot;: [
#       &quot;green_light&quot;,
#       &quot;red_light&quot;,
#       &quot;states&quot;,
#       &quot;actions&quot;
#     ]
#   },
#   &quot;groups&quot;: {
#     &quot;actions&quot;: {
#       &quot;borderWidth&quot;: 1,
#       &quot;color&quot;: {
#         &quot;background&quot;: &quot;lightblue&quot;,
#         &quot;border&quot;: &quot;black&quot;,
#         &quot;highlight&quot;: {
#           &quot;background&quot;: &quot;white&quot;,
#           &quot;border&quot;: &quot;red&quot;
#         }
#       },
#       &quot;shape&quot;: &quot;box&quot;,
#       &quot;mass&quot;: 1,
#       &quot;font&quot;: {
#         &quot;color&quot;: &quot;black&quot;,
#         &quot;size&quot;: 20
#       }
#     },
#     &quot;scheduled_actions&quot;: {
#       &quot;shape&quot;: &quot;box&quot;,
#       &quot;color&quot;: {
#         &quot;background&quot;: &quot;pink&quot;,
#         &quot;border&quot;: &quot;black&quot;,
#         &quot;highlight&quot;: {
#           &quot;background&quot;: &quot;white&quot;,
#           &quot;border&quot;: &quot;red&quot;
#         }
#       },
#       &quot;borderWidth&quot;: 1,
#       &quot;mass&quot;: 1,
#       &quot;font&quot;: {
#         &quot;color&quot;: &quot;black&quot;,
#         &quot;size&quot;: 14
#       },
#       &quot;schedColor&quot;: false
#     },
#     &quot;states&quot;: {
#       &quot;borderWidth&quot;: 1,
#       &quot;color&quot;: {
#         &quot;background&quot;: &quot;#000000&quot;,
#         &quot;border&quot;: &quot;black&quot;,
#         &quot;highlight&quot;: {
#           &quot;background&quot;: &quot;white&quot;,
#           &quot;border&quot;: &quot;red&quot;
#         }
#       },
#       &quot;shape&quot;: &quot;ellipse&quot;,
#       &quot;mass&quot;: 1,
#       &quot;font&quot;: {
#         &quot;color&quot;: &quot;#ffffff&quot;,
#         &quot;size&quot;: 20
#       }
#     },
#     &quot;red_light&quot;: {
#       &quot;borderWidth&quot;: 1,
#       &quot;color&quot;: {
#         &quot;background&quot;: &quot;#ec9393&quot;,
#         &quot;border&quot;: &quot;black&quot;,
#         &quot;highlight&quot;: {
#           &quot;background&quot;: &quot;white&quot;,
#           &quot;border&quot;: &quot;red&quot;
#         }
#       },
#       &quot;shape&quot;: &quot;ellipse&quot;,
#       &quot;mass&quot;: 1,
#       &quot;font&quot;: {
#         &quot;color&quot;: &quot;black&quot;,
#         &quot;size&quot;: 20
#       }
#     },
#     &quot;green_light&quot;: {
#       &quot;borderWidth&quot;: 1,
#       &quot;color&quot;: {
#         &quot;background&quot;: &quot;#bcfe58&quot;,
#         &quot;border&quot;: &quot;black&quot;,
#         &quot;highlight&quot;: {
#           &quot;background&quot;: &quot;white&quot;,
#           &quot;border&quot;: &quot;red&quot;
#         }
#       },
#       &quot;shape&quot;: &quot;ellipse&quot;,
#       &quot;mass&quot;: 1,
#       &quot;font&quot;: {
#         &quot;color&quot;: &quot;black&quot;,
#         &quot;size&quot;: 20
#       }
#     },
#     &quot;init&quot;: {
#       &quot;borderWidth&quot;: 1,
#       &quot;color&quot;: {
#         &quot;background&quot;: &quot;#bcfe58&quot;,
#         &quot;border&quot;: &quot;black&quot;,
#         &quot;highlight&quot;: {
#           &quot;background&quot;: &quot;white&quot;,
#           &quot;border&quot;: &quot;red&quot;
#         }
#       },
#       &quot;shape&quot;: &quot;ellipse&quot;,
#       &quot;mass&quot;: 1,
#       &quot;font&quot;: {
#         &quot;color&quot;: &quot;black&quot;,
#         &quot;size&quot;: 20
#       }
#     }
#   },
#   &quot;reload_button&quot;: false,
#   &quot;edges&quot;: {
#     &quot;arrows&quot;: &quot;to&quot;,
#     &quot;font&quot;: {
#       &quot;color&quot;: &quot;black&quot;,
#       &quot;size&quot;: 14
#     },
#     &quot;color&quot;: {
#       &quot;color&quot;: &quot;black&quot;
#     }
#   },
#   &quot;numbers&quot;: {
#     &quot;fractions&quot;: true,
#     &quot;digits&quot;: 5
#   },
#   &quot;state_properties&quot;: {
#     &quot;show_results&quot;: true,
#     &quot;result_symbol&quot;: &quot;\u2606&quot;,
#     &quot;show_rewards&quot;: true,
#     &quot;reward_symbol&quot;: &quot;\u20ac&quot;,
#     &quot;show_zero_rewards&quot;: true,
#     &quot;show_observations&quot;: true,
#     &quot;observation_symbol&quot;: &quot;\u0298&quot;
#   },
#   &quot;layout&quot;: {
#     &quot;randomSeed&quot;: 5
#   },
#   &quot;misc&quot;: {
#     &quot;enable_physics&quot;: true,
#     &quot;width&quot;: 655,
#     &quot;height&quot;: 375,
#     &quot;explore&quot;: false
#   },
#   &quot;saving&quot;: {
#     &quot;relative_path&quot;: true,
#     &quot;filename&quot;: &quot;layouts/car.json&quot;,
#     &quot;save_button&quot;: false,
#     &quot;load_button&quot;: false
#   },
#   &quot;positions&quot;: {
#     &quot;0&quot;: {
#       &quot;x&quot;: 194,
#       &quot;y&quot;: -96
#     },
#     &quot;1&quot;: {
#       &quot;x&quot;: -51,
#       &quot;y&quot;: -142
#     },
#     &quot;2&quot;: {
#       &quot;x&quot;: 186,

# %% [markdown]
# The result of the double conversion is equal to the original model.

# %%
stormvogel_model == stormvogel_model2
# Out:
# True
