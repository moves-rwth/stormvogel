# %% [markdown]
# # Gymnasium integration
# [Gymnasium](https://gymnasium.farama.org/) is an API standard for reinforcement learning with a diverse collection of reference environments. Stormvogel supports some integration with gymnasium. In particular, you can construct explicit models from the gymnasium environmnents under Gymnasium's [ToyText](https://gymnasium.farama.org/environments/toy_text/) (except Blackjack).

# %% [markdown]
# ## FrozenLake
# Let us create one of these environments, called FrozenLake.
# Our agent wants to get to the present. Currently, it just chooses a random action.

# %%
import gymnasium as gym
from stormvogel.extensions.gym_grid import *

env = gym.make("FrozenLake-v1", render_mode="rgb_array", is_slippery=False)  # Set `is_slippery=True` for stochastic behavior
#embed_video(create_video(env, "./video", None))

# %% [markdown]
# We can convert it into an explicit MDP as follows. Each state has a label that relates to the coordinates of the tile.

# %%
from stormvogel.show import show
from stormvogel.layout import Layout
sv_model = gymnasium_to_stormvogel(env)
vis = show(sv_model, layout=Layout("layouts/frozenlake.json"))
# Out:
# Output()
# Output()
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <title>Network</title>
#     <script
#       type="text/javascript"
#       src="https://unpkg.com/vis-network/standalone/umd/vis-network.min.js"
#     ></script>
#     <style type="text/css">
#       #modelbrBkxIxXix {
#         width: 800px;
#         height: 600px;
#         border: 1px solid lightgray;
#       }
#     </style>
#   </head>
#   <body>
#     <div id="modelbrBkxIxXix"></div>
#     <script type="text/javascript">
#
# class NetworkWrapper_modelbrBkxIxXix{//js
#   constructor(nodes, edges, options, container) {
#     this.nodes = nodes;
#     this.edges = edges;
#     this.options = options;
#     this.container = container;
#     this.data = {
#       nodes: nodes,
#       edges: edges,
#     };
#     this.network = new vis.Network(container, this.data, options);
#     var this_ = this; // Events will not work if you use 'this' directly :))))) No idea why.
#
#     // Set user-triggered events.
#     this.network.on( 'click', function(properties) {
#       var nodeId = this_.network.getNodeAt({x:properties.event.srcEvent.offsetX, y:properties.event.srcEvent.offsetY});
#       this_.makeNeighborsVisible(nodeId);
#     });
#     this.network.on( 'doubleClick', function(properties) {
#         this_.network.setData(this_.data);
#     });
#   }
#
#   setNodeColor(id, color) {
#     var node = this.nodes.get(id);
#     node["x"] = this.network.getPosition(id)["x"];
#     node["y"] = this.network.getPosition(id)["y"];
#     node["color"] = color;
#     this.nodes.update(node);
#   }
#
#   makeNeighborsVisible(homeId) {
#     if (homeId === undefined) {
#       return;
#     }
#     var homeNode = this.nodes.get(homeId);
#
#     // Make outgoing nodes visible
#     var nodeIds = this.network.getConnectedNodes(homeId, "to");
#     for (let i = 0; i < nodeIds.length; i++) {
#       var toNodeId = nodeIds[i];
#       var toNode = this.nodes.get(toNodeId);
#       if (toNode["hidden"]) {
#         toNode["hidden"] = false;
#         toNode["physics"] = true;
#         toNode["x"] = this.network.getPosition(homeId)["x"];
#         toNode["y"] = this.network.getPosition(homeId)["y"];
#         this.nodes.update(toNode);
#       }
#     }
#     // Make edges visible, if both of the nodes are also visible
#     var edgeIds = this.network.getConnectedEdges(homeId);
#     for (let i = 0; i < edgeIds.length; i++) {
#       var edgeId = edgeIds[i];
#       var edge = this.edges.get(edgeId);
#       var fromNode = this.nodes.get(edge.from);
#       var toNode = this.nodes.get(edge.to);
#       if ((! fromNode["hidden"]) && (! toNode["hidden"])) {
#         edge["hidden"] = false;
#         edge["physics"] = true;
#         this.edges.update(edge);
#       }
#     }
#   }
# };
#
#     </script>
#     <script type="text/javascript">
#         //js
#     var nodes_local = new vis.DataSet([{ id: 0, label: `init,0,(0, 0)`, group: "states", x: -508, y: -454 },
# { id: 1, label: `4,(0, 1)`, group: "states", x: -511, y: -97 },
# { id: 2, label: `1,(1, 0)`, group: "states", x: -151, y: -504 },
# { id: 3, label: `8,(0, 2)`, group: "states", x: -448, y: 251 },
# { id: 4, label: `5,(1, 1),done`, group: "states", x: -72, y: -84 },
# { id: 5, label: `2,(2, 0)`, group: "states", x: 221, y: -484 },
# { id: 6, label: `12,(0, 3),done`, group: "states", x: -510, y: 690 },
# { id: 7, label: `9,(1, 2)`, group: "states", x: -76, y: 293 },
# { id: 8, label: `6,(2, 1)`, group: "states", x: 328, y: -117 },
# { id: 9, label: `3,(3, 0)`, group: "states", x: 539, y: -649 },
# { id: 10, label: `13,(1, 3)`, group: "states", x: -70, y: 642 },
# { id: 11, label: `10,(2, 2)`, group: "states", x: 309, y: 260 },
# { id: 12, label: `7,(3, 1),done`, group: "states", x: 749, y: -282 },
# { id: 13, label: `14,(2, 3)`, group: "states", x: 285, y: 636 },
# { id: 14, label: `11,(3, 2),done`, group: "states", x: 773, y: 330 },
# { id: 15, label: `15,(3, 3),target,done`, group: "states", x: 586, y: 974 },
# { id: 10000000000, label: `←`, group: "actions", x: -651, y: -462 },
# { id: 10000000001, label: `↓`, group: "actions", x: -571, y: -276 },
# { id: 10000000002, label: `→`, group: "actions", x: -338, y: -541 },
# { id: 10000000003, label: `↑`, group: "actions", x: -538, y: -595 },
# { id: 10000000004, label: `←`, group: "actions", x: -650, y: -86 },
# { id: 10000000005, label: `↓`, group: "actions", x: -542, y: 87 },
# { id: 10000000006, label: `→`, group: "actions", x: -303, y: -101 },
# { id: 10000000007, label: `↑`, group: "actions", x: -473, y: -274 },
# { id: 10000000008, label: `←`, group: "actions", x: -323, y: -445 },
# { id: 10000000009, label: `↓`, group: "actions", x: -140, y: -304 },
# { id: 10000000010, label: `→`, group: "actions", x: 31, y: -453 },
# { id: 10000000011, label: `↑`, group: "actions", x: -159, y: -642 },
# { id: 10000000012, label: `←`, group: "actions", x: -580, y: 281 },
# { id: 10000000013, label: `↓`, group: "actions", x: -499, y: 461 },
# { id: 10000000014, label: `→`, group: "actions", x: -271, y: 313 },
# { id: 10000000015, label: `↑`, group: "actions", x: -444, y: 69 },
# { id: 10000000016, label: `←`, group: "actions", x: 49, y: -156 },
# { id: 10000000017, label: `↓`, group: "actions", x: 18, y: 23 },
# { id: 10000000018, label: `→`, group: "actions", x: -72, y: -209 },
# { id: 10000000019, label: `↑`, group: "actions", x: -178, y: -5 },
# { id: 10000000020, label: `←`, group: "actions", x: 31, y: -548 },
# { id: 10000000021, label: `↓`, group: "actions", x: 319, y: -308 },
# { id: 10000000022, label: `→`, group: "actions", x: 405, y: -528 },
# { id: 10000000023, label: `↑`, group: "actions", x: 189, y: -618 },
# { id: 10000000024, label: `←`, group: "actions", x: -645, y: 634 },
# { id: 10000000025, label: `↓`, group: "actions", x: -450, y: 824 },
# { id: 10000000026, label: `→`, group: "actions", x: -426, y: 602 },
# { id: 10000000027, label: `↑`, group: "actions", x: -616, y: 800 },
# { id: 10000000028, label: `←`, group: "actions", x: -258, y: 224 },
# { id: 10000000029, label: `↓`, group: "actions", x: -128, y: 471 },
# { id: 10000000030, label: `→`, group: "actions", x: 113, y: 222 },
# { id: 10000000031, label: `↑`, group: "actions", x: -75, y: 117 },
# { id: 10000000032, label: `←`, group: "actions", x: 146, y: -80 },
# { id: 10000000033, label: `↓`, group: "actions", x: 376, y: 72 },
# { id: 10000000034, label: `→`, group: "actions", x: 534, y: -178 },
# { id: 10000000035, label: `↑`, group: "actions", x: 234, y: -286 },
# { id: 10000000036, label: `←`, group: "actions", x: 362, y: -617 },
# { id: 10000000037, label: `↓`, group: "actions", x: 658, y: -483 },
# { id: 10000000038, label: `→`, group: "actions", x: 667, y: -699 },
# { id: 10000000039, label: `↑`, group: "actions", x: 504, y: -785 },
# { id: 10000000040, label: `←`, group: "actions", x: -282, y: 686 },
# { id: 10000000041, label: `↓`, group: "actions", x: -97, y: 775 },
# { id: 10000000042, label: `→`, group: "actions", x: 106, y: 705 },
# { id: 10000000043, label: `↑`, group: "actions", x: -35, y: 466 },
# { id: 10000000044, label: `←`, group: "actions", x: 121, y: 307 },
# { id: 10000000045, label: `↓`, group: "actions", x: 272, y: 445 },
# { id: 10000000046, label: `→`, group: "actions", x: 539, y: 289 },
# { id: 10000000047, label: `↑`, group: "actions", x: 286, y: 68 },
# { id: 10000000048, label: `←`, group: "actions", x: 848, y: -389 },
# { id: 10000000049, label: `↓`, group: "actions", x: 894, y: -232 },
# { id: 10000000050, label: `→`, group: "actions", x: 754, y: -139 },
# { id: 10000000051, label: `↑`, group: "actions", x: 630, y: -321 },
# { id: 10000000052, label: `←`, group: "actions", x: 108, y: 608 },
# { id: 10000000053, label: `↓`, group: "actions", x: 295, y: 762 },
# { id: 10000000054, label: `→
# €	R: 1.0`, group: "actions", x: 448, y: 797 },
# { id: 10000000055, label: `↑`, group: "actions", x: 360, y: 452 },
# { id: 10000000056, label: `←`, group: "actions", x: 697, y: 445 },
# { id: 10000000057, label: `↓`, group: "actions", x: 741, y: 197 },
# { id: 10000000058, label: `→`, group: "actions", x: 831, y: 340 },
# { id: 10000000059, label: `↑`, group: "actions", x: 932, y: 363 },
# { id: 10000000060, label: `←`, group: "actions", x: 649, y: 852 },
# { id: 10000000061, label: `↓`, group: "actions", x: 729, y: 1010 },
# { id: 100

# %% [markdown]
# Now, let's do some model checking to calculate a strategy to solve the puzzle. We will tell the model checker to maximize the probability of getting to the target state (the present).

# %%
from stormvogel.model_checking import model_checking
target = get_target_state(env)
res = model_checking(sv_model, f'Pmax=? [F "target"]')
vis2 = show(sv_model, result=res, layout=Layout("layouts/frozenlake.json"))
# Out:
# Output()
# Output()
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <title>Network</title>
#     <script
#       type="text/javascript"
#       src="https://unpkg.com/vis-network/standalone/umd/vis-network.min.js"
#     ></script>
#     <style type="text/css">
#       #modeleRxJHbMwVC {
#         width: 800px;
#         height: 600px;
#         border: 1px solid lightgray;
#       }
#     </style>
#   </head>
#   <body>
#     <div id="modeleRxJHbMwVC"></div>
#     <script type="text/javascript">
#
# class NetworkWrapper_modeleRxJHbMwVC{//js
#   constructor(nodes, edges, options, container) {
#     this.nodes = nodes;
#     this.edges = edges;
#     this.options = options;
#     this.container = container;
#     this.data = {
#       nodes: nodes,
#       edges: edges,
#     };
#     this.network = new vis.Network(container, this.data, options);
#     var this_ = this; // Events will not work if you use 'this' directly :))))) No idea why.
#
#     // Set user-triggered events.
#     this.network.on( 'click', function(properties) {
#       var nodeId = this_.network.getNodeAt({x:properties.event.srcEvent.offsetX, y:properties.event.srcEvent.offsetY});
#       this_.makeNeighborsVisible(nodeId);
#     });
#     this.network.on( 'doubleClick', function(properties) {
#         this_.network.setData(this_.data);
#     });
#   }
#
#   setNodeColor(id, color) {
#     var node = this.nodes.get(id);
#     node["x"] = this.network.getPosition(id)["x"];
#     node["y"] = this.network.getPosition(id)["y"];
#     node["color"] = color;
#     this.nodes.update(node);
#   }
#
#   makeNeighborsVisible(homeId) {
#     if (homeId === undefined) {
#       return;
#     }
#     var homeNode = this.nodes.get(homeId);
#
#     // Make outgoing nodes visible
#     var nodeIds = this.network.getConnectedNodes(homeId, "to");
#     for (let i = 0; i < nodeIds.length; i++) {
#       var toNodeId = nodeIds[i];
#       var toNode = this.nodes.get(toNodeId);
#       if (toNode["hidden"]) {
#         toNode["hidden"] = false;
#         toNode["physics"] = true;
#         toNode["x"] = this.network.getPosition(homeId)["x"];
#         toNode["y"] = this.network.getPosition(homeId)["y"];
#         this.nodes.update(toNode);
#       }
#     }
#     // Make edges visible, if both of the nodes are also visible
#     var edgeIds = this.network.getConnectedEdges(homeId);
#     for (let i = 0; i < edgeIds.length; i++) {
#       var edgeId = edgeIds[i];
#       var edge = this.edges.get(edgeId);
#       var fromNode = this.nodes.get(edge.from);
#       var toNode = this.nodes.get(edge.to);
#       if ((! fromNode["hidden"]) && (! toNode["hidden"])) {
#         edge["hidden"] = false;
#         edge["physics"] = true;
#         this.edges.update(edge);
#       }
#     }
#   }
# };
#
#     </script>
#     <script type="text/javascript">
#         //js
#     var nodes_local = new vis.DataSet([{ id: 0, label: `init,0,(0, 0)
# ☆ 1`, group: "states", x: -508, y: -454 },
# { id: 1, label: `4,(0, 1)
# ☆ 1`, group: "states", x: -511, y: -97 },
# { id: 2, label: `1,(1, 0)
# ☆ 1`, group: "states", x: -151, y: -504 },
# { id: 3, label: `8,(0, 2)
# ☆ 1`, group: "states", x: -448, y: 251 },
# { id: 4, label: `5,(1, 1),done
# ☆ 0`, group: "states", x: -72, y: -84 },
# { id: 5, label: `2,(2, 0)
# ☆ 1`, group: "states", x: 221, y: -484 },
# { id: 6, label: `12,(0, 3),done
# ☆ 0`, group: "states", x: -510, y: 690 },
# { id: 7, label: `9,(1, 2)
# ☆ 1`, group: "states", x: -76, y: 293 },
# { id: 8, label: `6,(2, 1)
# ☆ 1`, group: "states", x: 328, y: -117 },
# { id: 9, label: `3,(3, 0)
# ☆ 1`, group: "states", x: 539, y: -649 },
# { id: 10, label: `13,(1, 3)
# ☆ 1`, group: "states", x: -70, y: 642 },
# { id: 11, label: `10,(2, 2)
# ☆ 1`, group: "states", x: 309, y: 260 },
# { id: 12, label: `7,(3, 1),done
# ☆ 0`, group: "states", x: 749, y: -282 },
# { id: 13, label: `14,(2, 3)
# ☆ 1`, group: "states", x: 285, y: 636 },
# { id: 14, label: `11,(3, 2),done
# ☆ 0`, group: "states", x: 773, y: 330 },
# { id: 15, label: `15,(3, 3),target,done
# ☆ 1`, group: "states", x: 586, y: 974 },
# { id: 10000000000, label: `←`, group: "actions", x: -651, y: -462 },
# { id: 10000000001, label: `↓`, group: "actions", x: -571, y: -276 },
# { id: 10000000002, label: `→`, group: "scheduled_actions", x: -338, y: -541 },
# { id: 10000000003, label: `↑`, group: "actions", x: -538, y: -595 },
# { id: 10000000004, label: `←`, group: "actions", x: -650, y: -86 },
# { id: 10000000005, label: `↓`, group: "actions", x: -542, y: 87 },
# { id: 10000000006, label: `→`, group: "actions", x: -303, y: -101 },
# { id: 10000000007, label: `↑`, group: "scheduled_actions", x: -473, y: -274 },
# { id: 10000000008, label: `←`, group: "actions", x: -323, y: -445 },
# { id: 10000000009, label: `↓`, group: "actions", x: -140, y: -304 },
# { id: 10000000010, label: `→`, group: "scheduled_actions", x: 31, y: -453 },
# { id: 10000000011, label: `↑`, group: "actions", x: -159, y: -642 },
# { id: 10000000012, label: `←`, group: "actions", x: -580, y: 281 },
# { id: 10000000013, label: `↓`, group: "actions", x: -499, y: 461 },
# { id: 10000000014, label: `→`, group: "scheduled_actions", x: -271, y: 313 },
# { id: 10000000015, label: `↑`, group: "actions", x: -444, y: 69 },
# { id: 10000000016, label: `←`, group: "scheduled_actions", x: 49, y: -156 },
# { id: 10000000017, label: `↓`, group: "actions", x: 18, y: 23 },
# { id: 10000000018, label: `→`, group: "actions", x: -72, y: -209 },
# { id: 10000000019, label: `↑`, group: "actions", x: -178, y: -5 },
# { id: 10000000020, label: `←`, group: "actions", x: 31, y: -548 },
# { id: 10000000021, label: `↓`, group: "scheduled_actions", x: 319, y: -308 },
# { id: 10000000022, label: `→`, group: "actions", x: 405, y: -528 },
# { id: 10000000023, label: `↑`, group: "actions", x: 189, y: -618 },
# { id: 10000000024, label: `←`, group: "scheduled_actions", x: -645, y: 634 },
# { id: 10000000025, label: `↓`, group: "actions", x: -450, y: 824 },
# { id: 10000000026, label: `→`, group: "actions", x: -426, y: 602 },
# { id: 10000000027, label: `↑`, group: "actions", x: -616, y: 800 },
# { id: 10000000028, label: `←`, group: "actions", x: -258, y: 224 },
# { id: 10000000029, label: `↓`, group: "scheduled_actions", x: -128, y: 471 },
# { id: 10000000030, label: `→`, group: "actions", x: 113, y: 222 },
# { id: 10000000031, label: `↑`, group: "actions", x: -75, y: 117 },
# { id: 10000000032, label: `←`, group: "actions", x: 146, y: -80 },
# { id: 10000000033, label: `↓`, group: "scheduled_actions", x: 376, y: 72 },
# { id: 10000000034, label: `→`, group: "actions", x: 534, y: -178 },
# { id: 10000000035, label: `↑`, group: "actions", x: 234, y: -286 },
# { id: 10000000036, label: `←`, group: "scheduled_actions", x: 362, y: -617 },
# { id: 10000000037, label: `↓`, group: "actions", x: 658, y: -483 },
# { id: 10000000038, label: `→`, group: "actions", x: 667, y: -699 },
# { id: 10000000039, label: `↑`, group: "actions", x: 504, y: -785 },
# { id: 10000000040, label: `←`, group: "actions", x: -282, y: 686 },
# { id: 10000000041, label: `↓`, group: "actions", x: -97, y: 775 },
# { id: 10000000042, label: `→`, group: "scheduled_actions", x: 106, y: 705 },
# { id: 10000000043, label: `↑`, group: "actions", x: -35, y: 466 },
# { id: 10000000044, label: `←`, group: "actions", x: 121, y: 307 },
# { id: 10000000045, label: `↓`, group: "scheduled_actions", x: 272, y: 445 },
# { id: 10000000046, label: `→`, group: "actions", x: 539, y: 289 },
# { id: 10000000047, label: `↑`, group: "actions", x: 286, y: 68 },
# { id: 10000000048, label: `←`, group: "scheduled_actions", x: 848, y: -389 },
# { id: 10000000049, label: `↓`, group: "actions", x: 894, y: -232 },
# { id: 10000000050, label: `→`, group: "actions", x: 754, y: -139 },
# { id: 10000000051, label: `↑`, group: "actions", x: 630, y: -321 },
# { id: 10000000052, label: `←`, group: "actions", x: 108, y: 608 },
# { id: 10000000053, label: `↓`, group: "actions", x: 295, y: 762 },
# { id: 10000000054, label: `→
# €	R: 1.0`, group: "scheduled_actions", x: 448, y: 797 },
# { id: 10000000055, label: `↑`, group: "actions", x: 360, y: 452 },
# { id: 10000000056, label: `←`, group: "scheduled_actions", x: 697, y: 445 },
# { id: 10000000057, label: `↓`, group: "actions", x: 741, y: 197 },
# { id: 10000000058, label: `→`, group: "actions", x: 831, y: 340

# %% [markdown]
# Let's highlight the path to see what the scheduler is doing.

# %%
from stormvogel.simulator import simulate_path
path = simulate_path(sv_model, scheduler=res.scheduler, steps=20)
#vis2.highlight_path(path, color="orange")

# %% [markdown]
# Alternatively, we can show what our scheduler does in the frozen lake environment itself.

# %%
from stormvogel.extensions.gym_grid import *
embed_video(create_video_scheduler(sv_model, env, "./video", res.scheduler))
# Out:
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#                 </video>

# %% [markdown]
# We can also define a function to act as the scheduler.

# %%
def my_scheduler(s: stormvogel.model.State):
    # "←" "↓" "→" "↑"
    return stormvogel.model.Action.create("→")

embed_video(create_video_scheduler(sv_model, env, "./video", my_scheduler))
# Out:
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#                 </video>

# %% [markdown]
# ## CliffWalking
# CliffWalking is a slightly more boring version of FrozenLake. You can apply the same principles that we just applied to FrozenLake.

# %%
import gymnasium as gym
from stormvogel.extensions.gym_grid import *

env = gym.make("CliffWalking-v0", render_mode="rgb_array")
#embed_video(create_video(env, "./video", None))

# %%
from stormvogel.show import show
from stormvogel.layout import Layout

sv_model = gymnasium_to_stormvogel(env)
vis = show(sv_model, layout=Layout("layouts/cliffwalking.json"))
# Out:
# Output()
# Output()
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <title>Network</title>
#     <script
#       type="text/javascript"
#       src="https://unpkg.com/vis-network/standalone/umd/vis-network.min.js"
#     ></script>
#     <style type="text/css">
#       #modelymJvYMPkkv {
#         width: 800px;
#         height: 600px;
#         border: 1px solid lightgray;
#       }
#     </style>
#   </head>
#   <body>
#     <div id="modelymJvYMPkkv"></div>
#     <script type="text/javascript">
#
# class NetworkWrapper_modelymJvYMPkkv{//js
#   constructor(nodes, edges, options, container) {
#     this.nodes = nodes;
#     this.edges = edges;
#     this.options = options;
#     this.container = container;
#     this.data = {
#       nodes: nodes,
#       edges: edges,
#     };
#     this.network = new vis.Network(container, this.data, options);
#     var this_ = this; // Events will not work if you use 'this' directly :))))) No idea why.
#
#     // Set user-triggered events.
#     this.network.on( 'click', function(properties) {
#       var nodeId = this_.network.getNodeAt({x:properties.event.srcEvent.offsetX, y:properties.event.srcEvent.offsetY});
#       this_.makeNeighborsVisible(nodeId);
#     });
#     this.network.on( 'doubleClick', function(properties) {
#         this_.network.setData(this_.data);
#     });
#   }
#
#   setNodeColor(id, color) {
#     var node = this.nodes.get(id);
#     node["x"] = this.network.getPosition(id)["x"];
#     node["y"] = this.network.getPosition(id)["y"];
#     node["color"] = color;
#     this.nodes.update(node);
#   }
#
#   makeNeighborsVisible(homeId) {
#     if (homeId === undefined) {
#       return;
#     }
#     var homeNode = this.nodes.get(homeId);
#
#     // Make outgoing nodes visible
#     var nodeIds = this.network.getConnectedNodes(homeId, "to");
#     for (let i = 0; i < nodeIds.length; i++) {
#       var toNodeId = nodeIds[i];
#       var toNode = this.nodes.get(toNodeId);
#       if (toNode["hidden"]) {
#         toNode["hidden"] = false;
#         toNode["physics"] = true;
#         toNode["x"] = this.network.getPosition(homeId)["x"];
#         toNode["y"] = this.network.getPosition(homeId)["y"];
#         this.nodes.update(toNode);
#       }
#     }
#     // Make edges visible, if both of the nodes are also visible
#     var edgeIds = this.network.getConnectedEdges(homeId);
#     for (let i = 0; i < edgeIds.length; i++) {
#       var edgeId = edgeIds[i];
#       var edge = this.edges.get(edgeId);
#       var fromNode = this.nodes.get(edge.from);
#       var toNode = this.nodes.get(edge.to);
#       if ((! fromNode["hidden"]) && (! toNode["hidden"])) {
#         edge["hidden"] = false;
#         edge["physics"] = true;
#         this.edges.update(edge);
#       }
#     }
#   }
# };
#
#     </script>
#     <script type="text/javascript">
#         //js
#     var nodes_local = new vis.DataSet([{ id: 0, label: `init,0,(0, 0)`, group: "states", x: 1463, y: -590 },
# { id: 1, label: `1,(1, 0)`, group: "states", x: 1275, y: -696 },
# { id: 2, label: `12,(0, 2)`, group: "states", x: 940, y: -682 },
# { id: 3, label: `2,(2, 0)`, group: "states", x: 1241, y: -162 },
# { id: 4, label: `13,(1, 2)`, group: "states", x: 851, y: -811 },
# { id: 5, label: `24,(0, 4)`, group: "states", x: 402, y: -674 },
# { id: 6, label: `3,(3, 0)`, group: "states", x: 1134, y: 321 },
# { id: 7, label: `14,(2, 2)`, group: "states", x: 863, y: -317 },
# { id: 8, label: `25,(1, 4)`, group: "states", x: 359, y: -804 },
# { id: 9, label: `36,(0, 6)`, group: "states", x: -34, y: -319 },
# { id: 10, label: `4,(4, 0)`, group: "states", x: 864, y: 735 },
# { id: 11, label: `15,(3, 2)`, group: "states", x: 814, y: 97 },
# { id: 12, label: `26,(2, 4)`, group: "states", x: 453, y: -418 },
# { id: 13, label: `5,(5, 0)`, group: "states", x: 452, y: 1010 },
# { id: 14, label: `16,(4, 2)`, group: "states", x: 624, y: 438 },
# { id: 15, label: `27,(3, 4)`, group: "states", x: 455, y: -119 },
# { id: 16, label: `6,(0, 1)`, group: "states", x: -33, y: 1097 },
# { id: 17, label: `17,(5, 2)`, group: "states", x: 319, y: 653 },
# { id: 18, label: `28,(4, 4)`, group: "states", x: 349, y: 114 },
# { id: 19, label: `7,(1, 1)`, group: "states", x: -510, y: 991 },
# { id: 20, label: `18,(0, 3)`, group: "states", x: -45, y: 713 },
# { id: 21, label: `29,(5, 4)`, group: "states", x: 164, y: 247 },
# { id: 22, label: `8,(2, 1)`, group: "states", x: -914, y: 723 },
# { id: 23, label: `19,(1, 3)`, group: "states", x: -403, y: 617 },
# { id: 24, label: `30,(0, 5)`, group: "states", x: -50, y: 276 },
# { id: 25, label: `9,(3, 1)`, group: "states", x: -1207, y: 347 },
# { id: 26, label: `20,(2, 3)`, group: "states", x: -704, y: 385 },
# { id: 27, label: `31,(1, 5)`, group: "states", x: -266, y: 207 },
# { id: 28, label: `10,(4, 1)`, group: "states", x: -1399, y: -70 },
# { id: 29, label: `21,(3, 3)`, group: "states", x: -918, y: 53 },
# { id: 30, label: `32,(2, 5)`, group: "states", x: -451, y: 36 },
# { id: 31, label: `11,(5, 1)`, group: "states", x: -1540, y: -462 },
# { id: 32, label: `22,(4, 3)`, group: "states", x: -1061, y: -328 },
# { id: 33, label: `33,(3, 5)`, group: "states", x: -575, y: -219 },
# { id: 34, label: `23,(5, 3)`, group: "states", x: -1188, y: -702 },
# { id: 35, label: `34,(4, 5)`, group: "states", x: -658, y: -521 },
# { id: 36, label: `35,(5, 5)`, group: "states", x: -772, y: -875 },
# { id: 37, label: `47,(5, 7),target,done`, group: "states", x: -366, y: -888 },
# { id: 10000000000, label: `←
# €	R: -1`, group: "actions", x: 1621, y: -603 },
# { id: 10000000001, label: `↓
# €	R: -1`, group: "actions", x: 1465, y: -756 },
# { id: 10000000002, label: `→
# €	R: -1`, group: "actions", x: 1206, y: -657 },
# { id: 10000000003, label: `↑
# €	R: -1`, group: "actions", x: 1537, y: -462 },
# { id: 10000000004, label: `←
# €	R: -1`, group: "actions", x: 1314, y: -846 },
# { id: 10000000005, label: `↓
# €	R: -1`, group: "actions", x: 1313, y: -404 },
# { id: 10000000006, label: `→
# €	R: -1`, group: "actions", x: 1086, y: -786 },
# { id: 10000000007, label: `↑
# €	R: -1`, group: "actions", x: 1419, y: -692 },
# { id: 10000000008, label: `←
# €	R: -1`, group: "actions", x: 1205, y: -592 },
# { id: 10000000009, label: `↓
# €	R: -1`, group: "actions", x: 937, y: -849 },
# { id: 10000000010, label: `→
# €	R: -1`, group: "actions", x: 665, y: -638 },
# { id: 10000000011, label: `↑
# €	R: -1`, group: "actions", x: 1002, y: -573 },
# { id: 10000000012, label: `←
# €	R: -1`, group: "actions", x: 1373, y: -121 },
# { id: 10000000013, label: `↓
# €	R: -1`, group: "actions", x: 1182, y: 80 },
# { id: 10000000014, label: `→
# €	R: -1`, group: "actions", x: 1073, y: -274 },
# { id: 10000000015, label: `↑
# €	R: -1`, group: "actions", x: 1241, y: -419 },
# { id: 10000000016, label: `←
# €	R: -1`, group: "actions", x: 1099, y: -862 },
# { id: 10000000017, label: `↓
# €	R: -1`, group: "actions", x: 822, y: -562 },
# { id: 10000000018, label: `→
# €	R: -1`, group: "actions", x: 609, y: -841 },
# { id: 10000000019, label: `↑
# €	R: -1`, group: "actions", x: 875, y: -846 },
# { id: 10000000020, label: `←
# €	R: -1`, group: "actions", x: 665, y: -716 },
# { id: 10000000021, label: `↓
# €	R: -1`, group: "actions", x: 252, y: -807 },
# { id: 10000000022, label: `→
# €	R: -1`, group: "actions", x: 153, y: -537 },
# { id: 10000000023, label: `↑
# €	R: -1`, group: "actions", x: 500, y: -754 },
# { id: 10000000024, label: `←
# €	R: -1`, group: "actions", x: 1258, y: 387 },
# { id: 10000000025, label: `↓
# €	R: -1`, group: "actions", x: 997, y: 527 },
# { id: 10000000026, label: `→
# €	R: -1`, group: "actions", x: 962, y: 251 },
# { id: 10000000027, label: `↑
# €	R: -1`, group: "actions", x: 1258, y: 101 },
# { id: 10000000028, label: `←
# €	R: -1`, group: "actions", x: 1048, y: -195 },
# { id: 10000000029, label: `↓
# €	R: -1`, group: "actions", x: 813, y: -114 },
# { id: 10000000030, label: `→
# €	R: -1`, group: "actions", x: 654, y: -331 },
# { id: 10000000031, label: `↑
# €	R: -1`, group: "actions", x: 888, y: -544 },
# { id: 10000000032, label: `←
# €	R: -1`, group: "actions", x: 603, y: -914 },
# { id: 10000000033, label: `↓
# €	R: -1`, group: "actions", x: 354, y: -592 },
# { id: 10000000034, label: `→
# €	R: -100`, group: "actions", x: 117, y: -616 },
# { id: 10000000035, label: `↑
# €	R: -1`, group: "actions", x: 397, y: -869 },
# { id: 10000000036, la

# %%
from stormvogel.model_checking import model_checking
target = get_target_state(env)
res = model_checking(sv_model, f'Pmax=? [F "target"]')
embed_video(create_video_scheduler(sv_model, env, "./video", res.scheduler))
# Out:
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#                 </video>

# %% [markdown]
# ## Taxi
# In the Taxi scenario, a taxi has to pick up passengers and transport them to the hotel.

# %%
import gymnasium as gym
from stormvogel.extensions.gym_grid import *

env = gym.make("Taxi-v3", render_mode="rgb_array")  # Set `is_slippery=True` for stochastic behavior
initial_state, _ = env.reset()
print(initial_state)
# Out:
# 168

# %% [markdown]
# For the Taxi scenario, the initial state is randomly chosen. It is important that it is the same for the stormvogel model and the video.

# %%
sv_model = gymnasium_to_stormvogel(env, initial_state=initial_state)
# This model is so big that it is better not to display it.
sv_model.summary()
# Out:
# 'ModelType.MDP model with name None, 126 states, 6 actions, and 252 distinct labels.'

# %%
from stormvogel.model_checking import model_checking

target = get_target_state(env)
res = model_checking(sv_model, f'Rmax=? [S]')
embed_video(create_video_scheduler(sv_model, env, "./video", res.scheduler, limit=20, initial_state=initial_state))
# Out:
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#                 </video>
