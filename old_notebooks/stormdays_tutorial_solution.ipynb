# %% [markdown]
# # Stormdays Tutorial

# %%
from stormvogel import bird
from stormvogel.model import EmptyAction, ModelType
from stormvogel.show import show
from stormvogel.layout import Layout

init = "init"

def available_actions(s: str):
    if s == "init": # If we are in the initial state, we have a choice.
        return [bird.Action(["study"]), bird.Action(["don't study"])]
    else: # Otherwise, we don't have any choice, we are just a Markov chain. 
        return [bird.Action([])]

def delta(s: str, a: bird.Action):
    if "study" in a.labels:
        return [(1, "studied")]
    elif "don't study" in a.labels:
        return [(1, "didn't study")]
    elif s == "studied":
        return [(9/10, "pass test"), (1/10, "fail test")]
    elif s == "didn't study":
        return [(2/5, "pass test"), (3/5, "fail test")]
    else:
        return [(1, "end")]

def labels(s):
    return [s]

# For rewards, you have to provide a list. This enables multiple reward models if you use a non-singleton list.
def rewards(s: str, a: bird.Action):
    if s == "pass test":
        return {"r1":100}
    if s == "didn't study":
        return {"r1":15}
    else:
        return {"r1":0}

bird_study = bird.build_bird(
    delta=delta,
    init=init,
    available_actions=available_actions,
    labels=labels,
    modeltype=ModelType.MDP,
    rewards=rewards
)
vis = show(bird_study)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <title>Network</title>
#     <script
#       type="text/javascript"
#       src="https://unpkg.com/vis-network/standalone/umd/vis-network.min.js"
#     ></script>
#     <style type="text/css">
#       #modeldOWaSqSzVn {
#         width: 800px;
#         height: 600px;
#         border: 1px solid lightgray;
#       }
#     </style>
#   </head>
#   <body>
#     <div id="modeldOWaSqSzVn"></div>
#     <script type="text/javascript">
#
# class NetworkWrapper_modeldOWaSqSzVn{//js
#   constructor(nodes, edges, options, container) {
#     this.nodes = nodes;
#     this.edges = edges;
#     this.options = options;
#     this.container = container;
#     this.data = {
#       nodes: nodes,
#       edges: edges,
#     };
#     this.network = new vis.Network(container, this.data, options);
#     var this_ = this; // Events will not work if you use 'this' directly :))))) No idea why.
#
#     // Set user-triggered events.
#     this.network.on( 'click', function(properties) {
#       var nodeId = this_.network.getNodeAt({x:properties.event.srcEvent.offsetX, y:properties.event.srcEvent.offsetY});
#       this_.makeNeighborsVisible(nodeId);
#     });
#     this.network.on( 'doubleClick', function(properties) {
#         this_.network.setData(this_.data);
#     });
#   }
#
#   setNodeColor(id, color) {
#     var node = this.nodes.get(id);
#     node["x"] = this.network.getPosition(id)["x"];
#     node["y"] = this.network.getPosition(id)["y"];
#     node["color"] = color;
#     this.nodes.update(node);
#   }
#
#   makeNeighborsVisible(homeId) {
#     if (homeId === undefined) {
#       return;
#     }
#     var homeNode = this.nodes.get(homeId);
#
#     // Make outgoing nodes visible
#     var nodeIds = this.network.getConnectedNodes(homeId, "to");
#     for (let i = 0; i < nodeIds.length; i++) {
#       var toNodeId = nodeIds[i];
#       var toNode = this.nodes.get(toNodeId);
#       if (toNode["hidden"]) {
#         toNode["hidden"] = false;
#         toNode["physics"] = true;
#         toNode["x"] = this.network.getPosition(homeId)["x"];
#         toNode["y"] = this.network.getPosition(homeId)["y"];
#         this.nodes.update(toNode);
#       }
#     }
#     // Make edges visible, if both of the nodes are also visible
#     var edgeIds = this.network.getConnectedEdges(homeId);
#     for (let i = 0; i < edgeIds.length; i++) {
#       var edgeId = edgeIds[i];
#       var edge = this.edges.get(edgeId);
#       var fromNode = this.nodes.get(edge.from);
#       var toNode = this.nodes.get(edge.to);
#       if ((! fromNode["hidden"]) && (! toNode["hidden"])) {
#         edge["hidden"] = false;
#         edge["physics"] = true;
#         this.edges.update(edge);
#       }
#     }
#   }
# };
#
#     </script>
#     <script type="text/javascript">
#         //js
#     var nodes_local = new vis.DataSet([{ id: 0, label: `init`, group: "states" },
# { id: 1, label: `studied
# €	rewardmodel: 0: r1`, group: "states" },
# { id: 2, label: `didn't study
# €	rewardmodel: 0: r1`, group: "states" },
# { id: 3, label: `pass test
# €	rewardmodel: 0: r1`, group: "states" },
# { id: 4, label: `fail test
# €	rewardmodel: 0: r1`, group: "states" },
# { id: 5, label: `end
# €	rewardmodel: 0: r1`, group: "states" },
# { id: 10000000000, label: `study
# €	rewardmodel: 0: r1`, group: "actions" },
# { id: 10000000001, label: `don't study
# €	rewardmodel: 0: r1`, group: "actions" },
# ]);
#     var edges_local = new vis.DataSet([{ from: 0, to: 10000000000 },
# { from: 10000000000, to: 1, label: "1" },
# { from: 0, to: 10000000001 },
# { from: 10000000001, to: 2, label: "1" },
# { from: 1, to: 3, label: "9/10" },
# { from: 1, to: 4, label: "1/10" },
# { from: 2, to: 3, label: "2/5" },
# { from: 2, to: 4, label: "3/5" },
# { from: 3, to: 5, label: "1" },
# { from: 4, to: 5, label: "1" },
# { from: 5, to: 5, label: "1" },
# ]);
#     var options_local = {
#   "__fake_macros": {
#     "__group_macro": {
#       "borderWidth": 1,
#       "color": {
#         "background": "white",
#         "border": "black",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "ellipse",
#       "mass": 1,
#       "font": {
#         "color": "black",
#         "size": 14
#       }
#     }
#   },
#   "edit_groups": {
#     "groups": [
#       "states",
#       "actions"
#     ]
#   },
#   "groups": {
#     "actions": {
#       "borderWidth": 1,
#       "color": {
#         "background": "lightblue",
#         "border": "black",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "box",
#       "mass": 1,
#       "font": {
#         "color": "black",
#         "size": 14
#       }
#     },
#     "scheduled_actions": {
#       "shape": "box",
#       "color": {
#         "background": "pink",
#         "border": "red"
#       }
#     },
#     "states": {
#       "borderWidth": 1,
#       "color": {
#         "background": "white",
#         "border": "black",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "ellipse",
#       "mass": 1,
#       "font": {
#         "color": "black",
#         "size": 14
#       }
#     }
#   },
#   "reload_button": false,
#   "edges": {
#     "arrows": "to",
#     "font": {
#       "color": "black",
#       "size": 14,
#       "strokeColor": "white",
#       "strokeWidth": 2
#     },
#     "color": {
#       "color": "black"
#     },
#     "width": 1
#   },
#   "numbers": {
#     "fractions": true,
#     "digits": 5
#   },
#   "state_properties": {
#     "show_results": true,
#     "result_symbol": "\u2606",
#     "show_rewards": true,
#     "reward_symbol": "\u20ac",
#     "show_zero_rewards": true,
#     "show_observations": true,
#     "observation_symbol": "\u0298"
#   },
#   "layout": {
#     "randomSeed": 5
#   },
#   "misc": {
#     "enable_physics": true,
#     "width": 800,
#     "height": 600,
#     "explore": false
#   },
#   "saving": {
#     "relative_path": true,
#     "filename": "layouts/NAME.json",
#     "save_button": false,
#     "load_button": false
#   },
#   "positions": {},
#   "physics": true,
#   "autoResize": true
# };
#     var container_local = document.getElementById("modeldOWaSqSzVn");
#     var nw_modeldOWaSqSzVn = new NetworkWrapper_modeldOWaSqSzVn(nodes_local, edges_local, options_local, container_local)
#
#     </script>
#   </body>
# </html>

# %%
from stormvogel import bird
from stormvogel.model import EmptyAction, ModelType
from stormvogel.show import show
from stormvogel.layout import Layout

init = "init"

def available_actions(s: str):
    if s == "init": # If we are in the initial state, we have a choice.
        return [bird.Action(["study"]), bird.Action(["don't study"])]
    elif s == "fail test":
        return [bird.Action(["retry"]), bird.Action(["give up"])]
    else: # Otherwise, we don't have any choice, we are just a Markov chain. 
        return [bird.Action([])]

def delta(s: str, a: bird.Action):
    if "study" in a.labels:
        return [(1, "studied")]
    elif "don't study" in a.labels:
        return [(1, "didn't study")]
    elif s == "studied":
        return [(9/10, "pass test"), (1/10, "fail test")]
    elif s == "didn't study":
        return [(2/5, "pass test"), (3/5, "fail test")]
    elif "retry" in a.labels:
        return [(1, "init")]
    elif "give up" in a.labels:
        return [(1, "end")]
    else:
        return [(1, "end")]

def labels(s):
    return [s]

# For rewards, you have to provide a list. This enables multiple reward models if you use a non-singleton list.
def rewards(s: str, a: bird.Action):
    if s == "pass test":
        return {"r1":100}
    if s == "didn't study":
        return {"r1":15}
    else:
        return {"r1":0}

def rewards(s: str, a: bird.Action):
    if s == "pass test":
        return [100]
    if s == "didn't study":
        return [15]
    else:
        return [0]

bird_study = bird.build_bird(
    delta=delta,
    init=init,
    available_actions=available_actions,
    labels=labels,
    modeltype=ModelType.MDP,
    rewards=rewards
)
vis = show(bird_study)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <title>Network</title>
#     <script
#       type="text/javascript"
#       src="https://unpkg.com/vis-network/standalone/umd/vis-network.min.js"
#     ></script>
#     <style type="text/css">
#       #modelJVwkCPwIET {
#         width: 800px;
#         height: 600px;
#         border: 1px solid lightgray;
#       }
#     </style>
#   </head>
#   <body>
#     <div id="modelJVwkCPwIET"></div>
#     <script type="text/javascript">
#
# class NetworkWrapper_modelJVwkCPwIET{//js
#   constructor(nodes, edges, options, container) {
#     this.nodes = nodes;
#     this.edges = edges;
#     this.options = options;
#     this.container = container;
#     this.data = {
#       nodes: nodes,
#       edges: edges,
#     };
#     this.network = new vis.Network(container, this.data, options);
#     var this_ = this; // Events will not work if you use 'this' directly :))))) No idea why.
#
#     // Set user-triggered events.
#     this.network.on( 'click', function(properties) {
#       var nodeId = this_.network.getNodeAt({x:properties.event.srcEvent.offsetX, y:properties.event.srcEvent.offsetY});
#       this_.makeNeighborsVisible(nodeId);
#     });
#     this.network.on( 'doubleClick', function(properties) {
#         this_.network.setData(this_.data);
#     });
#   }
#
#   setNodeColor(id, color) {
#     var node = this.nodes.get(id);
#     node["x"] = this.network.getPosition(id)["x"];
#     node["y"] = this.network.getPosition(id)["y"];
#     node["color"] = color;
#     this.nodes.update(node);
#   }
#
#   makeNeighborsVisible(homeId) {
#     if (homeId === undefined) {
#       return;
#     }
#     var homeNode = this.nodes.get(homeId);
#
#     // Make outgoing nodes visible
#     var nodeIds = this.network.getConnectedNodes(homeId, "to");
#     for (let i = 0; i < nodeIds.length; i++) {
#       var toNodeId = nodeIds[i];
#       var toNode = this.nodes.get(toNodeId);
#       if (toNode["hidden"]) {
#         toNode["hidden"] = false;
#         toNode["physics"] = true;
#         toNode["x"] = this.network.getPosition(homeId)["x"];
#         toNode["y"] = this.network.getPosition(homeId)["y"];
#         this.nodes.update(toNode);
#       }
#     }
#     // Make edges visible, if both of the nodes are also visible
#     var edgeIds = this.network.getConnectedEdges(homeId);
#     for (let i = 0; i < edgeIds.length; i++) {
#       var edgeId = edgeIds[i];
#       var edge = this.edges.get(edgeId);
#       var fromNode = this.nodes.get(edge.from);
#       var toNode = this.nodes.get(edge.to);
#       if ((! fromNode["hidden"]) && (! toNode["hidden"])) {
#         edge["hidden"] = false;
#         edge["physics"] = true;
#         this.edges.update(edge);
#       }
#     }
#   }
# };
#
#     </script>
#     <script type="text/javascript">
#         //js
#     var nodes_local = new vis.DataSet([{ id: 0, label: `init`, group: "states" },
# { id: 1, label: `studied
# €	rewardmodel: 0: 0`, group: "states" },
# { id: 2, label: `didn't study
# €	rewardmodel: 0: 15`, group: "states" },
# { id: 3, label: `pass test
# €	rewardmodel: 0: 100`, group: "states" },
# { id: 4, label: `fail test`, group: "states" },
# { id: 5, label: `end
# €	rewardmodel: 0: 0`, group: "states" },
# { id: 10000000000, label: `study
# €	rewardmodel: 0: 0`, group: "actions" },
# { id: 10000000001, label: `don't study
# €	rewardmodel: 0: 0`, group: "actions" },
# { id: 10000000002, label: `retry
# €	rewardmodel: 0: 0`, group: "actions" },
# { id: 10000000003, label: `give up
# €	rewardmodel: 0: 0`, group: "actions" },
# ]);
#     var edges_local = new vis.DataSet([{ from: 0, to: 10000000000 },
# { from: 10000000000, to: 1, label: "1" },
# { from: 0, to: 10000000001 },
# { from: 10000000001, to: 2, label: "1" },
# { from: 1, to: 3, label: "9/10" },
# { from: 1, to: 4, label: "1/10" },
# { from: 2, to: 3, label: "2/5" },
# { from: 2, to: 4, label: "3/5" },
# { from: 3, to: 5, label: "1" },
# { from: 4, to: 10000000002 },
# { from: 10000000002, to: 0, label: "1" },
# { from: 4, to: 10000000003 },
# { from: 10000000003, to: 5, label: "1" },
# { from: 5, to: 5, label: "1" },
# ]);
#     var options_local = {
#   "__fake_macros": {
#     "__group_macro": {
#       "borderWidth": 1,
#       "color": {
#         "background": "white",
#         "border": "black",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "ellipse",
#       "mass": 1,
#       "font": {
#         "color": "black",
#         "size": 14
#       }
#     }
#   },
#   "edit_groups": {
#     "groups": [
#       "states",
#       "actions"
#     ]
#   },
#   "groups": {
#     "actions": {
#       "borderWidth": 1,
#       "color": {
#         "background": "lightblue",
#         "border": "black",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "box",
#       "mass": 1,
#       "font": {
#         "color": "black",
#         "size": 14
#       }
#     },
#     "scheduled_actions": {
#       "shape": "box",
#       "color": {
#         "background": "pink",
#         "border": "red"
#       }
#     },
#     "states": {
#       "borderWidth": 1,
#       "color": {
#         "background": "white",
#         "border": "black",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "ellipse",
#       "mass": 1,
#       "font": {
#         "color": "black",
#         "size": 14
#       }
#     }
#   },
#   "reload_button": false,
#   "edges": {
#     "arrows": "to",
#     "font": {
#       "color": "black",
#       "size": 14,
#       "strokeColor": "white",
#       "strokeWidth": 2
#     },
#     "color": {
#       "color": "black"
#     },
#     "width": 1
#   },
#   "numbers": {
#     "fractions": true,
#     "digits": 5
#   },
#   "state_properties": {
#     "show_results": true,
#     "result_symbol": "\u2606",
#     "show_rewards": true,
#     "reward_symbol": "\u20ac",
#     "show_zero_rewards": true,
#     "show_observations": true,
#     "observation_symbol": "\u0298"
#   },
#   "layout": {
#     "randomSeed": 5
#   },
#   "misc": {
#     "enable_physics": true,
#     "width": 800,
#     "height": 600,
#     "explore": false
#   },
#   "saving": {
#     "relative_path": true,
#     "filename": "layouts/NAME.json",
#     "save_button": false,
#     "load_button": false
#   },
#   "positions": {},
#   "physics": true,
#   "autoResize": true
# };
#     var container_local = document.getElementById("modelJVwkCPwIET");
#     var nw_modelJVwkCPwIET = new NetworkWrapper_modelJVwkCPwIET(nodes_local, edges_local, options_local, container_local)
#
#     </script>
#   </body>
# </html>

# %%
from stormvogel.model_checking import model_checking

# %%
result = model_checking(bird_study, "Rmax=? [F \"end\"]", scheduler=True)

# %%
vis = show(bird_study, result=result)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <title>Network</title>
#     <script
#       type="text/javascript"
#       src="https://unpkg.com/vis-network/standalone/umd/vis-network.min.js"
#     ></script>
#     <style type="text/css">
#       #modelhjuaBWkFEE {
#         width: 800px;
#         height: 600px;
#         border: 1px solid lightgray;
#       }
#     </style>
#   </head>
#   <body>
#     <div id="modelhjuaBWkFEE"></div>
#     <script type="text/javascript">
#
# class NetworkWrapper_modelhjuaBWkFEE{//js
#   constructor(nodes, edges, options, container) {
#     this.nodes = nodes;
#     this.edges = edges;
#     this.options = options;
#     this.container = container;
#     this.data = {
#       nodes: nodes,
#       edges: edges,
#     };
#     this.network = new vis.Network(container, this.data, options);
#     var this_ = this; // Events will not work if you use 'this' directly :))))) No idea why.
#
#     // Set user-triggered events.
#     this.network.on( 'click', function(properties) {
#       var nodeId = this_.network.getNodeAt({x:properties.event.srcEvent.offsetX, y:properties.event.srcEvent.offsetY});
#       this_.makeNeighborsVisible(nodeId);
#     });
#     this.network.on( 'doubleClick', function(properties) {
#         this_.network.setData(this_.data);
#     });
#   }
#
#   setNodeColor(id, color) {
#     var node = this.nodes.get(id);
#     node["x"] = this.network.getPosition(id)["x"];
#     node["y"] = this.network.getPosition(id)["y"];
#     node["color"] = color;
#     this.nodes.update(node);
#   }
#
#   makeNeighborsVisible(homeId) {
#     if (homeId === undefined) {
#       return;
#     }
#     var homeNode = this.nodes.get(homeId);
#
#     // Make outgoing nodes visible
#     var nodeIds = this.network.getConnectedNodes(homeId, "to");
#     for (let i = 0; i < nodeIds.length; i++) {
#       var toNodeId = nodeIds[i];
#       var toNode = this.nodes.get(toNodeId);
#       if (toNode["hidden"]) {
#         toNode["hidden"] = false;
#         toNode["physics"] = true;
#         toNode["x"] = this.network.getPosition(homeId)["x"];
#         toNode["y"] = this.network.getPosition(homeId)["y"];
#         this.nodes.update(toNode);
#       }
#     }
#     // Make edges visible, if both of the nodes are also visible
#     var edgeIds = this.network.getConnectedEdges(homeId);
#     for (let i = 0; i < edgeIds.length; i++) {
#       var edgeId = edgeIds[i];
#       var edge = this.edges.get(edgeId);
#       var fromNode = this.nodes.get(edge.from);
#       var toNode = this.nodes.get(edge.to);
#       if ((! fromNode["hidden"]) && (! toNode["hidden"])) {
#         edge["hidden"] = false;
#         edge["physics"] = true;
#         this.edges.update(edge);
#       }
#     }
#   }
# };
#
#     </script>
#     <script type="text/javascript">
#         //js
#     var nodes_local = new vis.DataSet([{ id: 0, label: `init
# ☆ 275/2`, group: "states" },
# { id: 1, label: `studied
# €	rewardmodel: 0: 0
# ☆ 415/4`, group: "states" },
# { id: 2, label: `didn't study
# €	rewardmodel: 0: 15
# ☆ 275/2`, group: "states" },
# { id: 3, label: `pass test
# €	rewardmodel: 0: 100
# ☆ 100`, group: "states" },
# { id: 4, label: `fail test
# ☆ 275/2`, group: "states" },
# { id: 5, label: `end
# €	rewardmodel: 0: 0
# ☆ 0`, group: "states" },
# { id: 10000000000, label: `study
# €	rewardmodel: 0: 0`, group: "actions" },
# { id: 10000000001, label: `don't study
# €	rewardmodel: 0: 0`, group: "scheduled_actions" },
# { id: 10000000002, label: `retry
# €	rewardmodel: 0: 0`, group: "scheduled_actions" },
# { id: 10000000003, label: `give up
# €	rewardmodel: 0: 0`, group: "actions" },
# ]);
#     var edges_local = new vis.DataSet([{ from: 0, to: 10000000000 },
# { from: 10000000000, to: 1, label: "1" },
# { from: 0, to: 10000000001, color: "red" },
# { from: 10000000001, to: 2, label: "1", color: "red" },
# { from: 1, to: 3, label: "9/10" },
# { from: 1, to: 4, label: "1/10" },
# { from: 2, to: 3, label: "2/5" },
# { from: 2, to: 4, label: "3/5" },
# { from: 3, to: 5, label: "1" },
# { from: 4, to: 10000000002, color: "red" },
# { from: 10000000002, to: 0, label: "1", color: "red" },
# { from: 4, to: 10000000003 },
# { from: 10000000003, to: 5, label: "1" },
# { from: 5, to: 5, label: "1" },
# ]);
#     var options_local = {
#   "__fake_macros": {
#     "__group_macro": {
#       "borderWidth": 1,
#       "color": {
#         "background": "white",
#         "border": "black",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "ellipse",
#       "mass": 1,
#       "font": {
#         "color": "black",
#         "size": 14
#       }
#     }
#   },
#   "edit_groups": {
#     "groups": [
#       "states",
#       "actions",
#       "scheduled_actions"
#     ]
#   },
#   "groups": {
#     "actions": {
#       "borderWidth": 1,
#       "color": {
#         "background": "lightblue",
#         "border": "black",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "box",
#       "mass": 1,
#       "font": {
#         "color": "black",
#         "size": 14
#       }
#     },
#     "scheduled_actions": {
#       "borderWidth": 1,
#       "color": {
#         "background": "pink",
#         "border": "red",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "box",
#       "mass": 1,
#       "font": {
#         "color": "black",
#         "size": 14
#       }
#     },
#     "states": {
#       "borderWidth": 1,
#       "color": {
#         "background": "white",
#         "border": "black",
#         "highlight": {
#           "background": "white",
#           "border": "red"
#         }
#       },
#       "shape": "ellipse",
#       "mass": 1,
#       "font": {
#         "color": "black",
#         "size": 14
#       }
#     }
#   },
#   "reload_button": false,
#   "edges": {
#     "arrows": "to",
#     "font": {
#       "color": "black",
#       "size": 14,
#       "strokeColor": "white",
#       "strokeWidth": 2
#     },
#     "color": {
#       "color": "black"
#     },
#     "width": 1
#   },
#   "numbers": {
#     "fractions": true,
#     "digits": 5
#   },
#   "state_properties": {
#     "show_results": true,
#     "result_symbol": "\u2606",
#     "show_rewards": true,
#     "reward_symbol": "\u20ac",
#     "show_zero_rewards": true,
#     "show_observations": true,
#     "observation_symbol": "\u0298"
#   },
#   "layout": {
#     "randomSeed": 5
#   },
#   "misc": {
#     "enable_physics": true,
#     "width": 800,
#     "height": 600,
#     "explore": false
#   },
#   "saving": {
#     "relative_path": true,
#     "filename": "layouts/NAME.json",
#     "save_button": false,
#     "load_button": false
#   },
#   "positions": {},
#   "physics": true,
#   "autoResize": true
# };
#     var container_local = document.getElementById("modelhjuaBWkFEE");
#     var nw_modelhjuaBWkFEE = new NetworkWrapper_modelhjuaBWkFEE(nodes_local, edges_local, options_local, container_local)
#
#     </script>
#   </body>
# </html>

# %%
import stormvogel.simulator
path = stormvogel.simulator.simulate_path(bird_study, scheduler=result.scheduler, steps=100)
vis.highlight_path(path, "purple")
